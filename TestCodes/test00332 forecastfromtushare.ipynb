# %%
import tushare as ts
import pandas as pd
# import os
import matplotlib.pyplot as plt
import seaborn as sns
# import seaborn.linearmodels as snsl
from datetime import datetime
import talib

# %%
token='f20927201ecc20e3cea9279abacfbb1d39a9624820d9b2f94613f722'

pro=ts.pro_api(token)

# %%
pro.forecast(ann_date='20191030', fields='ts_code,ann_date,end_date,type,p_change_min,p_change_max,net_profit_min,summary,change_reason')
# Out:
#        ts_code  ann_date  end_date type  p_change_min  p_change_max  \
# 0    002318.SZ  20191030  20191231   预增       60.0000       80.0000
# 1    300080.SZ  20191030  20191231   预减      -68.1700      -56.6000
# 2    300270.SZ  20191030  20191231   扭亏      105.0000      135.0000
# 3    002597.SZ  20191030  20191231   略减      -12.2400       -6.7600
# 4    000985.SZ  20191030  20191231   扭亏     1801.3900     2113.8900
# 5    002210.SZ  20191030  20191231   续亏       34.3314       48.8238
# 6    002472.SZ  20191030  20191231   预减      -60.0000      -30.0000
# 7    002766.SZ  20191030  20191231   续亏       42.6700       49.0400
# 8    002292.SZ  20191030  20191231   扭亏      107.9745      109.2014
# 9    002707.SZ  20191030  20191231   预增      218.2500      377.3800
# 10   002498.SZ  20191030  20191231   预增       71.6600      116.8300
# 11   002850.SZ  20191030  20191231   预增      160.0000      210.0000
# 12   601099.SH  20191030  20191231  不确定           NaN           NaN
# ...
