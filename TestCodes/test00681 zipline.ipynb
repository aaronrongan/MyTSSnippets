# %% [markdown]
# * 参考文件
# - https://pythonprogramming.net/zipline-backtest-visualization-python-programming-for-finance/?completed=/zipline-local-install-python-programming-for-finance/
# - 遇到问题解决 Exception has occurred: JSONDecodeError
# https://stackoverflow.com/questions/56957791/getting-jsondecodeerror-expecting-value-line-1-column-1-char-0-with-python （成功。修改benmarks.py/loaders.py,不要用文中提到的第3步）

# %%
# %load_ext zipline

# %%
from zipline.api import order, record, symbol


def initialize(context):
    pass


def handle_data(context, data):
    order(symbol('AAPL'), 10)
    record(AAPL=data.current(symbol('AAPL'), 'price'))

# %%
# %zipline --bundle quantopian-quandl --start 2008-1-1 --end 2012-1-1 -o dma.pickle
# Out:
# c:\users\aaron\appdata\local\programs\python\python35\scripts\env_zipline\lib\site-packages\empyrical\stats.py:1289: RuntimeWarning: Mean of empty slice
#   nanmean(alpha_series, axis=0, out=out),
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2008-01-02 21:00:00+00:00  194.840              NaN             0.000000e+00
# 2008-01-03 21:00:00+00:00  194.930         0.000001            -9.846500e-08
# 2008-01-04 21:00:00+00:00  180.050         0.000137            -1.506949e-05
# 2008-01-07 21:00:00+00:00  177.640         0.000112            -1.997931e-05
# 2008-01-08 21:00:00+00:00  171.250         0.000140            -3.923593e-05
# 2008-01-09 21:00:00+00:00  179.400         0.000290            -6.726635e-06
# 2008-01-10 21:00:00+00:00  178.020         0.000267            -1.371664e-05
# 2008-01-11 21:00:00+00:00  172.690         0.000299            -4.578399e-05
# 2008-01-14 21:00:00+00:00  178.780         0.000379            -3.244380e-06
# ...

# %%
# %zipline --bundle quantopian-quandl --start 2000-1-1 --end 2012-1-1 -o backtest.pickle
# Out:
#                               AAPL  algo_volatility  algorithm_period_return  \
# 2000-01-03 21:00:00+00:00  111.940              NaN             0.000000e+00
# 2000-01-04 21:00:00+00:00  102.500     5.865048e-07            -5.225000e-08
# 2000-01-05 21:00:00+00:00  104.000     1.350778e-05             1.394750e-06
# 2000-01-06 21:00:00+00:00   95.000     1.473588e-04            -1.665375e-05
# 2000-01-07 21:00:00+00:00   99.500     1.786638e-04            -3.204500e-06
# 2000-01-10 21:00:00+00:00   97.750     1.651115e-04            -1.025437e-05
# 2000-01-11 21:00:00+00:00   92.750     2.057353e-04            -3.530175e-05
# 2000-01-12 21:00:00+00:00   87.190     2.482341e-04            -6.870634e-05
# 2000-01-13 21:00:00+00:00   96.750     4.619211e-04            -1.835720e-06
# 2000-01-14 21:00:00+00:00  100.440     4.602723e-04             2.763306e-05
# 2000-01-18 21:00:00+00:00  103.940     4.577254e-04             5.908009e-05
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style

# %matplotlib inline

style.use('ggplot')

backtest_df = pd.read_pickle("backtest.pickle")
backtest_df.portfolio_value.plot()
plt.show()

# %%
from zipline.api import order, record, symbol
import matplotlib.pyplot as plt
from matplotlib import style

style.use('ggplot')


def initialize(context):
    pass


def handle_data(context, data):
    order(symbol("GE"), 10)
    record(AAPL=data.current(symbol('GE'), 'price'))


def analyze(context, perf):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    perf.portfolio_value.plot(ax=ax1)
    ax1.set_ylabel('portfolio $ value')
    plt.legend(loc=0)
    plt.show()

# %%
# %zipline --bundle quantopian-quandl --start 2005-1-1 --end 2015-1-1 -o backtest.pickle
# Out:
# c:\users\aaron\appdata\local\programs\python\python35\scripts\env_zipline\lib\site-packages\empyrical\stats.py:1289: RuntimeWarning: Mean of empty slice
#   nanmean(alpha_series, axis=0, out=out),
#                             AAPL  algo_volatility  algorithm_period_return  \
# 2005-01-03 21:00:00+00:00  36.59              NaN             0.000000e+00
# 2005-01-04 21:00:00+00:00  36.15     2.141163e-07            -1.907500e-08
# 2005-01-05 21:00:00+00:00  35.93     2.108181e-06            -2.580400e-07
# 2005-01-06 21:00:00+00:00  36.22     5.415483e-06             3.028500e-07
# 2005-01-07 21:00:00+00:00  36.00     7.120601e-06            -3.761500e-07
# 2005-01-10 21:00:00+00:00  35.91     6.666095e-06            -7.551050e-07
# 2005-01-11 21:00:00+00:00  35.40     1.587014e-05            -3.323805e-06
# 2005-01-12 21:00:00+00:00  35.68     1.896310e-05            -1.662645e-06
# 2005-01-13 21:00:00+00:00  35.23     2.366654e-05            -4.831260e-06
# ...

# %%
# Out:
# UsageError: Line magic function `%zipline` not found.

# %%
import zipline
# %load_ext zipline
# Out:
# The zipline extension is already loaded. To reload it, use:
#   %reload_ext zipline

# %%
import zipline

import matplotlib.pyplot as plt
# imports

from zipline.api import order, symbol, record, set_benchmark

# %matplotlib inline
# parameters

selected_stock = 'ABN'

n_stocks_to_buy = 10



def initialize(context):

    set_benchmark(symbol('AEX'))

    context.asset = symbol('ABN')

    context.has_ordered = False  



def handle_data(context, data):

    # record price for further inspection

    record(price=data.current(symbol(selected_stock), 'price'))

    print('handle_data')

    # trading logic

    if not context.has_ordered:

        # placing order, negative number for sale/short

        order(symbol(selected_stock), n_stocks_to_buy)

        # setting up a flag for holding a position

        context.has_ordered = True


def analyze(context, perf):
    fig = plt.figure()
    ax1 = fig.add_subplot(111)
    perf.portfolio_value.plot(ax=ax1)
    ax1.set_ylabel('portfolio $ value')
    plt.legend(loc=0)
    plt.show()
