# %% [markdown]
# # 要点
#
# * url=url[0]+'api/columns'+url[1]
#
# * url='https://zhuanlan.zhihu.com/api/columns/cutehand/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2Cupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10'
#
# * 读取内容保存到本地html
#
# * 将网页保存为PDF
#
# * https://www.jianshu.com/p/4d65857ffe5e/ wkhtmltopdf参数设置，
#     * 页边距
#     * 页面大小
#     pdfkit.from_file(sorted(htmls),HtmlSavePath + '.pdf',configuration=config,options=options)
#
# * 安装wkhtmltopdf
#
# * 创建和写入文件出现乱码的解决方法
#      with open(file_name, 'w', encoding="utf-8") as f: #,encoding="utf-8"
#             f.write(content)
#
# * 增加封面 pdfkit.from_file(cover='1.txt')
#
# * 如何改变字体？如何增加索引？否则300多页没法看
#     查看安装wkhtmltopdf的文档，不是pdfkit，后者参数较少
#     options: zoom=3
#
# * https://pypi.org/project/pdfkit/ PDFKit设置
# option 横向
# 'orientation':'Landscape',#横向
# 'encoding': "UTF-8",
# 'no-outline': None,
# 'footer-right':'[page]' 设置页码
#
# * 爱德华•索普 中间这个点•会造成OSError: wkhtmltopdf exited with non-zero code 1. error:错误，解决：去除文件名中的•

# %% [markdown]
# 需要安装库：requests、bs4、pdfkit（可选，导出pdf需要）
#
# 抓取时需输入专栏url的路径，如我的专栏 https://zhuanlan.zhihu.com/crossin ，需输入 crossin
#
# 如需程序自动导出pdf，除通过pip安装pdfkit外，还需要手动安装 wkhtmltopdf，具体参见：
#
# https://github.com/JazzCore/python-pdfkit/wiki/Installing-wkhtmltopdf
#
# https://wkhtmltopdf.org/downloads.html
#
# 输出示例：Crossin的编程教室-知乎专栏pdf版：https://pan.baidu.com/s/18rds2VK-TzZ5pLs_MHE6LQ
#
# 更多实用有趣的例程
#
# 欢迎关注“Crossin的编程教室”及同名 知乎专栏

# %%
import time
import re
import os
import requests
from bs4 import BeautifulSoup
import pdfkit
# import wkhtmltopdf

headers = {
        'origin': 'https://zhuanlan.zhihu.com',
        'referer': 'https://zhuanlan.zhihu.com/%s' % 'cutehand',
        'User-Agent': ('Mozilla/5.0'),
    }

HtmlSavePath='I:/TradingSystemTempFiles/Tmp/'

path_wk = r'C:\Program Files\wkhtmltopdf\bin\wkhtmltopdf.exe' #安装位置

options = {
        'page-size': 'A4',
        'margin-top': '0.5in',
        'margin-right': '0.5in',
        'margin-bottom': '0.5in',
        'margin-left': '0.5in',
        'encoding': "UTF-8",
        'no-outline': None,
        'orientation':'Landscape',
        'minimum-font-size':15,
        'footer-right':'[page]',
        'zoom':1.2
    }

# %%
# url = 'https://www.zhihu.com/api/v4/columns/%s/articles?include=data[*].topics&limit=20 % 'cutehand'
# url = 'htts://zhuanlan.zhihu.com/api/columns/cutehand/articles'
# url = 'https://zhuanlan.zhihu.com/api/columns/cutehand/articles'

# url='https://zhuanlan.zhihu.com/api/columns/cutehand/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2Cupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10'
# article_dict = {}
# resp = requests.get(url, headers=headers)
# resp.text.encode('gb2312')
# j = resp.json()
# # print(j)

# # if j['paging']['is_end']:
# #    print('end')

# url = j['paging']['next']
# url=url.split('columns')
# # url

# url=url[0]+'api/columns'+url[1]
# print(url)

# resp = requests.get(url, headers=headers)
# resp

# resp.text.encode('utf-8')
# j = resp.json()
# print(j)

# %%
# while True:
#     print('fetching', url)
#     try:
#         resp = requests.get(url, headers=headers)
#         j = resp.json()
#         data = j['data']
#     except:
#         print('get list failed')
    
#     for article in data:
#         aid = article['id']
#         akeys = article_dict.keys()
#         if aid not in akeys:
#             article_dict[aid] = article['title']

#     if j['paging']['is_end']:
#         break
#     url = j['paging']['next']
    
#     url=url.split('columns')
#     url=url[0]+'api/columns'+url[1] 
    
#     time.sleep(2)

# %%
# while True:
#     print('fetching', url)
#     try:
#         resp = requests.get(url, headers=headers)
#         j = resp.json()
#         data = j['data']
#     except:
#         print('get list failed')

#     for article in data:
#         aid = article['id']
#         akeys = article_dict.keys()
#         if aid not in akeys:
#             article_dict[aid] = article['title']

#     if j['paging']['is_end']:
#         break
#     url = j['paging']['next']
#     time.sleep(2)

# %%
# with open('zhihu_ids.txt', 'w') as f:
#     items = sorted(article_dict.items())
#     for item in items:
#         f.write('%s %s\n' % item)

# author='cutehand'

# url='https://zhuanlan.zhihu.com/api/columns/%s/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info&limit=10&offset=10' % author

articlelistfilename='00_zhihu_ids.txt'

# %%
def get_list(author1):
#     url = 'https://www.zhihu.com/api/v4/columns/%s/articles?include=data[*].topics&limit=10' % author
#     url='https://zhuanlan.zhihu.com/api/columns/%s/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2Cupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10' % author
#     url='https://zhuanlan.zhihu.com/api/columns/%s/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info&limit=10&offset=10' % author1
    
    #不用后缀&limit=10&offset=10
    url='https://zhuanlan.zhihu.com/api/columns/%s/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info' % author1
    article_dict = {}
    
    ###################################
    while True:
        print('fetching', url)
        try:
            resp = requests.get(url, headers=headers)
            j = resp.json()
            data = j['data']
            print(j)
        except:
            print('get list failed')

        for article in data:
            aid = article['id']
            akeys = article_dict.keys()
            if aid not in akeys:
                article_dict[aid] = article['title']

        if j['paging']['is_end']:
            break
        url = j['paging']['next']

        url=url.split('columns')
        url=url[0]+'api/columns'+url[1] 

        time.sleep(2)
    ###################################
    
    with open(HtmlSavePath + articlelistfilename, 'w',encoding='utf-8') as f:
        items = sorted(article_dict.items())
        for item in items:
            f.write('%s %s\n' % item)

# %%
def get_html(aid, title, index):
    title = title.replace('/', '／')
    title = title.replace('\\', '＼')
    file_name = HtmlSavePath + '%03d. %s.html' % (index, title)
    
    file_name=file_name.replace('•','.')
    
    if os.path.exists(file_name):
        print(title, 'already exists.')
        return
    else:
        print('saving', title)
    try:
        url = 'https://zhuanlan.zhihu.com/p/' + aid
#         print('url is:' + url)
        html = requests.get(url, headers=headers).text
        soup = BeautifulSoup(html, 'lxml')
        content = soup.find(class_='Post-RichText').prettify()
        content = content.replace('data-actual', '')
        content = content.replace('h1>', 'h2>')
        content = re.sub(r'<noscript>.*?</noscript>', '', content)
        content = re.sub(r'src="data:image.*?"', '', content)
        content = '<!DOCTYPE html><html><head><meta charset="utf-8"></head><body><h1>%s</h1>%s</body></html>' % (
            title, content)
        with open( file_name, 'w', encoding="utf-8") as f: #,encoding="utf-8"
#             f.write(content, encoding="utf-8")
            f.write(content)
    except:
        print('get %s failed', title)
    time.sleep(2)

# %%
def get_details():
    with open(HtmlSavePath + articlelistfilename,encoding='utf-8-sig') as f: #
        i = 1
        for line in f:
            lst = line.strip().split(' ')
            aid = lst[0]
            title = '_'.join(lst[1:])
            get_html(aid, title, i)
            i += 1

# %%
# pdfkit.from_url(url, r'D:\are you coding\pdf\taobao.pdf', configuration=config)

# htmls = []
# print(HtmlSavePath)
# for root, dirs, files in os.walk(HtmlSavePath):
# #     print(files)
#     htmls += [HtmlSavePath + name for name in files if name.endswith(".html")]
# print(htmls)
# pdfkit.from_file(sorted(htmls), HtmlSavePath + '1.pdf',configuration=config)
# pdfkit.from_file(HtmlSavePath + htmls, '1.pdf')

# %%
def to_pdf(author1):
    import pdfkit
    print('exporting PDF...')
#     htmls = [HtmlSavePath + articlelistfilename]

    htmls=[]
    cover=HtmlSavePath + articlelistfilename
    
    for root, dirs, files in os.walk(HtmlSavePath):
        htmls += [HtmlSavePath + name for name in files if name.endswith(".html")]
#     print(HtmlSavePath+ author + '.pdf')
    
#     print(htmls)
    config = pdfkit.configuration(wkhtmltopdf = path_wk)
    
    if not os.path.exists(HtmlSavePath+ '知乎专栏_' +author1 + '.pdf'):
        pdfkit.from_file(sorted(htmls),HtmlSavePath+ '知乎专栏_' + author1 + '.pdf',configuration=config,options=options,cover=cover)
        return True
    else:
        print('PDF已存在')
        return False
        #     pdfkit.from_file(htmls,HtmlSavePath+ '知乎专栏_' +author + '.pdf',configuration=config,options=options)

# %%
def clean_alltemphtmlfiles():
    for root, dirs, files in os.walk(HtmlSavePath):
        for each in files:
            if ".pdf" not in each:
                os.remove(HtmlSavePath+each)

# %%
def ParseUrlDirect():
# 对网页进行解析，而不是Json文件

#     url='https://zhuanlan.zhihu.com/api/columns/%s/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info&limit=10&offset=10' % author1
#     url='https://zhuanlan.zhihu.com/c_60716992'
    url='https://zhuanlan.zhihu.com/api/columns/c_60716992/articles?include=data%5B*%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2Cupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info'
    
    article_dict = {}
    
    ###################################
#     while True:
    print('fetching', url)
    try:
        resp = requests.get(url, headers=headers)
#         j = resp
        soup=BeautifulSoup(resp.text,'lxml')
#         print(soup)
#         data = j['data']
#         articles=soup.find(class_='Column-ArticleList')
        articles=soup.find_all('li',class_='ArticleItem')
#         print(articles)
    except:
        print('get list failed')

    for article in articles:
        aid = article['a']
        akeys = article_dict.keys()
        if aid not in akeys:
            article_dict[aid] = article['title']
    
#     article_dict
#     if j['paging']['is_end']:
#         break
#     url = j['paging']['next']

#     url=url.split('columns')
#     url=url[0]+'api/columns'+url[1] 

#     time.sleep(2)
    ###################################
    
    with open(HtmlSavePath + articlelistfilename, 'w',encoding='utf-8') as f:
        items = sorted(article_dict.items())
        for item in items:
            f.write('%s %s\n' % item)

# %%
if __name__ == '__main__':
    
    #2种解析方式Case：
    #  1). 输入authors 列表；
    #  2). 直接对网址解析
    
    case=1 #input('请输入解析方式：1 or 2:')
    
    if case==1:
    
        authors=[]
        #通过键盘输入单个author
    #     author = input('Please input author name:(default crossin)')
    #     authors=['c_160091697'] 
    #     authors=['cutehand']
    #     authors+=['c_215446519']
#         authors+=['quanttech'] 
#         authors+=['c_60716992'] 
#         authors+=['c_1146746635093647360'] #文件为空？
#         authors+=['c_1180423060312866816']
#         authors+=['kuanke']
#         authors+=['yutiansut']
# 'quicklib','DigQuant',

# 'programtrader',导出pdf有问题，疑似文件名问题
# 'Lhtz-Jqxx',导出pdf有问题，疑似文件名问题
        authors+=['quantinvestment','ailabx','quanttech','c_215446519',]
#         authors+=['zzzzzzzz']
        
        print(authors)

        for eachauthor in authors:
            if not eachauthor:
                author = 'crossin'
            headers = {
                'origin': 'https://zhuanlan.zhihu.com',
                'referer': 'https://zhuanlan.zhihu.com/%s' % eachauthor,
                'User-Agent': ('Mozilla/5.0'),
            }
            get_list(eachauthor)
            get_details()
            if to_pdf(eachauthor)==True:
                print('成功创建PDF')
            else:
                print('未创建PDF')
            clean_alltemphtmlfiles()
        
    elif case==2:
        ParseUrlDirect()
# Out:
# ['quantinvestment', 'ailabx', 'quanttech', 'c_215446519', 'DigQuant', 'Lhtz-Jqxx']
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=0', 'totals': 51, 'is_start': True, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10'}, 'data': [{'image_url': 'https://pic4.zhimg.com/v2-82b25b95d36dab6d43d4555acb0eb39e_b.jpg', 'author': {'is_org': False, 'name': '发财老博士', 'url_token': 'merman-15', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'd579eb86142c5e8cf284aeb396e99e92', 'gender': 1, 'headline': '关注微信公众号richdoctor，带你站着把钱挣了！', 'is_advertiser': False, 'url': '/people/d579eb86142c5e8cf284aeb396e99e92', 'avatar_url_template': 'https://pic4.zhimg.com/v2-bb61b84c68a7b883f6f3def568ea55bc_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/v2-bb61b84c68a7b883f6f3def568ea55bc_l.jpg', 'description': '游历半个地球的北欧老博士，浮沉半生，阅历无数。\n会赚钱，懂投资，最善于站着把钱挣了。', 'badge': [{'type': 'identity', 'topics': [], 'description': '南丹麦大学 机器人专业博士'}], 'uid': '1025313756368207873', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 5, 'is_labeled': False, 'title_image': 'https://pic4.zhimg.com/v2-82b25b95d36dab6d43d4555acb0eb39e_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 92838157, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/92838157', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic1.zhimg.com/v2-e83398eb7b8c33d963088f6313d31a98_200x112.webp" data-caption="" data-size="normal" data-rawwidth="649" data-rawheight="419" data-watermark="watermark" data-original-src="v2-e83398eb7b8c33d963088f6313d31a98" data-watermark-src="v2-ee1d19b490af8c14b2444fde0439227f" data-private-watermark-src="" data-original="https://pic1.zhimg.com/v2-e83398eb7b8c33d963088f6313d31a98_r.webp" class="origin_image inline-img zh-lightbox-thumb"/><a href="https://link.zhihu.com/?target=https%3A//mp.weixin.qq.com/s%3F__biz%3DMzI5NzgxMzM4NA%3D%3D%26mid%3D2247485751%26idx%3D1%26sn%3De70fdc488cc57ef54a15521d30386b07%26chksm%3Decae1dd0dbd994c6a5eaf48f65798feb72a68889c21e251ef9e77dbe4e3691976b33685730d1%26token%3D1932817977%26lang%3Dzh_CN%23rd" class=" wrap external" target="_blank" rel="nofollow noreferrer">发财老博士</a> 今日主要内容： 贷款基准利率LPR下调5个基点。 外围乱哄哄，大盘第1001次骗炮。5G炒作逻辑开始透支，意味着什么？ 今天上午10点，银行贷款基准利率LPR报价出炉，1年期LPR为4.15%，5年期LPR为4.8%，均较上月下降5个基点，符合市场预期......<b>的下限</b>…', 'type': 'article', 'created': 1574251280, 'updated': 1574251280, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': '大盘第1001次骗炮'}, {'image_url': '', 'author': {'is_org': False, 'name': '今何在', 'url_token': 'jin-he-zai-12-77', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'e1c0e747d4ec5819d9ca54b61a4f34bc', 'gender': 1, 'headline': '大盘分析，个股精选，可以关注我的头像或查找“每天牛股”', 'is_advertiser': False, 'url': '/people/e1c0e747d4ec5819d9ca54b61a4f34bc', 'avatar_url_template': 'https://pic3.zhimg.com/v2-a739c03934fc335ca31131794beda983_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-a739c03934fc335ca31131794beda983_l.jpg', 'description': '', 'badge': [], 'uid': '1095816840055435264', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 90186522, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/90186522', 'admin_closed ...
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=0', 'totals': 51, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 89685658, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/89685658', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic1.zhimg.com/v2-80405e5adef1904701a59a4a6949fa28_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="300" data-rawheight="241" data-watermark="watermark" data-original-src="v2-80405e5adef1904701a59a4a6949fa28" data-watermark-src="v2-15582d2bbe7844e9280be96dcc9bf0f8" data-private-watermark-src="" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic1.zhimg.com/v2-80405e5adef1904701a59a4a6949fa28_r.jpg"/>尽管现在已经推出了不少的宝宝类产品，但余额宝几乎仍然是老大哥的地位，主要原因还在于它是开创者或先行者，在大家心目中已经建立了比较牢固的印象，大家愿意相信支付宝。 宝宝类现金管理产品为什么能随时随地用来支付呢？也就是余额宝为什么能够想买就买…', 'type': 'article', 'created': 1572602327, 'updated': 1572602327, 'state': 'published', 'voteup_count': 0, 'voting': 0, 'reason': '', 'title': '买买买怎么能少得了它'}, {'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 89684617, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/89684617', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic4.zhimg.com/v2-c7b312e9b9d0f834e874b91f63ba71bb_200x112.png" data-caption="" data-size="normal" data-rawwidth="640" data-rawheight="640" data-watermark="watermark" data-original-src="v2-c7b312e9b9d0f834e874b91f63ba71bb" data-watermark-src="v2-6d0f4cc91ca8ca3702bbe221283aa5f3" data-private-watermark-src="" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic4.zhimg.com/v2-c7b312e9b9d0f834e874b91f63ba71bb_r.png"/>第一，我的收入太少了，但绝不是因为买不起所以才不参加双十一活动的，而是花费了大量时间和精力最多能节省下来的钱特别有 ...
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10', 'totals': 51, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=30'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 86561782, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/86561782', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic2.zhimg.com/v2-648180e253ee4576caa8caf29f49b13d_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="387" data-rawheight="240" data-watermark="watermark" data-original-src="v2-648180e253ee4576caa8caf29f49b13d" data-watermark-src="v2-8dd563d821bad0809038a7946f3cd4e6" data-private-watermark-src="" data-original="https://pic2.zhimg.com/v2-648180e253ee4576caa8caf29f49b13d_r.jpg" class="origin_image inline-img zh-lightbox-thumb"/>首先要分清存量资金和增量资金，就是我们不少人做基金定投并不是不纯粹的将每个月的工资拿出一部分，更多的情况是还有一笔资金是没有其它用处的，也想用作基金定投。 其实，不管是什么资金，一般都是建议最少做两手准备的，就是波动大的基金要投，波动小的…', 'type': 'article', 'created': 1571028368, 'updated': 1571028368, 'state': 'published', 'voteup_count': 1, 'voting': 0, 'reason': '', 'title': '定投基金到底要怎么分配资金比较好'}, {'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 86561231, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/86561231', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic3.zhimg.com/v2-f98cc07d0a0b3e35daa847e87f2db882_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="600" data-rawheight="361" data-watermark="watermark" data-original-src="v2-f98cc07d0a0b3e35daa847e87f2db882" data-watermark-src="v2-78590237e56413b6a7344e5878468d78" data-private-watermark-src="" data-original="https://pic3.zhimg.com/v2-f98cc07d0a0b3e35daa847e87f2db882_r.jpg" class="origin_image inline-img zh-lightbox-thumb"/>第一，长期坚持基金定投，这是根本和基础，如果无法长期坚持投资，那其它的也就不复存在了。 而且首先要做 ...
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=30
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20', 'totals': 51, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=40'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 83480401, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/83480401', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic4.zhimg.com/v2-b07cef9cd0a120a07a4b4c8b820efbef_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="280" data-rawheight="286" data-watermark="watermark" data-original-src="v2-b07cef9cd0a120a07a4b4c8b820efbef" data-watermark-src="v2-2c4947a809437ab788d69e33cbef2e69" data-private-watermark-src="" data-original="https://pic4.zhimg.com/v2-b07cef9cd0a120a07a4b4c8b820efbef_r.jpg" class="origin_image inline-img zh-lightbox-thumb"/>我们经常买的指数基金对应的指数又叫成分指数，就是在上交所或深交所选择一些特定的成分股组成的指数。但成分指数在计算各个股票的权重时，一般只考虑流通股，不考虑非流通股。 中国股市在建立以后的很长一段时间内，主要目的为了给国企融资，帮国企脱困，…', 'type': 'article', 'created': 1569045113, 'updated': 1569045113, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': '成分指数的一点基础知识'}, {'image_url': '', 'author': {'is_org': False, 'name': '番茄番茄', 'url_token': 'zhu-guo-dong-97', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '66c3693504eb513f5b1f195d027e31fa', 'gender': 1, 'headline': '9年实战投资经验，专注基金定投。', 'is_advertiser': False, 'url': '/people/66c3693504eb513f5b1f195d027e31fa', 'avatar_url_template': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/v2-b07243e39a7915e0d06bfc28da8e019f_l.jpg', 'description': '9年实战投资经验，专注基金定投。三流高中毕业之后就开始了，所以靠基金定投赚钱不需要学历要求。主要是要坚持。', 'badge': [], 'uid': '643699283262574592', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 83479333, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/83479333', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic4.zhimg.com/v2-5ae49d22741168feb5d9baba5f89f1fb_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="400" data-rawheight="265" data-watermark="watermark" data-original-src="v2-5ae49d22741168feb5d9baba5f89f1fb" data-watermark-src="v2-fb54774b0535d42801d8fca8b161d602" data-private-watermark-src="" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic4.zhimg.com/v2-5ae49d22741168feb5d9baba5f89f1fb_r.jpg"/>2005年，上交所和深交所共同成立了中证指数有限公司，专门从事指数的开发和管理，目前已开发不少指数供市场进行选 ...
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=40
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=30', 'totals': 51, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=50'}, 'data': [{'image_url': 'https://pic4.zhimg.com/v2-d6f5139354de2df9b54c6f9a350983ae_b.jpg', 'author': {'is_org': False, 'name': '窦福成', 'url_token': 'doufucheng', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '3aedd28dfe81a4340e4b1e9fe42f6d5e', 'gender': 1, 'headline': 'Quant', 'is_advertiser': False, 'url': '/people/3aedd28dfe81a4340e4b1e9fe42f6d5e', 'avatar_url_template': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_l.jpg', 'description': 'Quant', 'badge': [{'type': 'identity', 'topics': [], 'description': '泰达宏利基金管理有限公司 金融工程研究员'}], 'uid': '34103307010048', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': 'https://pic4.zhimg.com/v2-d6f5139354de2df9b54c6f9a350983ae_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 72706642, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/72706642', 'admin_closed_comment': False, 'excerpt': '这本书是我仔细阅读的第一本投资书籍，也反反复复读了五六遍，每次阅读都会有点新的体会，在这里分享给大家。<b>投资理念篇</b><b>1 以实业的眼光做投资</b>这章阐述了一个非常重要的问题，就是资产管理行业的本质就是代客理财，基金经理首先要解决的是客户的<b>信任问题</b>本书…', 'type': 'article', 'created': 1562581477, 'updated': 1567409591, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': '【读书笔记】《投资中最简单的事》之投资理念篇'}, {'image_url': 'https://pic3.zhimg.com/v2-57f135c39fd52ed6eed0df2ba1bb64c6_b.jpg', 'author': {'is_org': False, 'name': '窦福成', 'url_token': 'doufucheng', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '3aedd28dfe81a4340e4b1e9fe42f6d5e', 'gender': 1, 'headline': 'Quant', 'is_advertiser': False, 'url': '/people/3aedd28dfe81a4340e4b1e9fe42f6d5e', 'avatar_url_template': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_l.jpg', 'description': 'Quant', 'badge': [{'type': 'identity', 'topics': [], 'description': '泰达宏利基金管理有限公司 金融工程研究员'}], 'uid': '34103307010048', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': 'https://pic3.zhimg.com/v2-57f135c39fd52ed6eed0df2ba1bb64c6_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 72648316, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/72648316', 'admin_closed_comment': False, 'excerpt': '很多人不明白量化选股究竟在干什么，其实，量化选股很简单，只是包含的一点数学给人一种很复杂难懂的感觉，下面举个例子说明量化选股和行业基本面选股的不同之处。<b>面临的问题</b>假如你是知乎中学的校长，要在学校500名学生中选出20名学生参加马拉松比赛，如何…', 'type': 'article', 'created': 1562563409, 'updated': 1567410162, 'state': 'published', 'voteup_count': 4, 'voting': 0, 'reason': '', 'title': '【投资心得】量化投资和行业研究有什么区别'}, {'image_url': 'https://pic4.zhimg.com/v2-d6f5139354de2df9b54c6f9a350983ae_b.jpg', 'author': {'is_org': False, 'name': '窦福成', 'url_token': 'doufucheng', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '3aedd28dfe81a4340e4b1e9fe42f6d5e', 'gender': 1, 'headline': 'Quant', 'is_advertiser': False, 'url': '/people/3aedd28dfe81a4340e4b1e9fe42f6d5e', 'avatar_url_template': 'h ...
# fetching https://zhuanlan.zhihu.com/api/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=50
# {'paging': {'is_end': True, 'previous': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=40', 'totals': 51, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/quantinvestment/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=60'}, 'data': [{'image_url': 'https://pic3.zhimg.com/v2-b59cfed8537464a9291981a92f5b6902_b.jpg', 'author': {'is_org': False, 'name': '窦福成', 'url_token': 'doufucheng', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '3aedd28dfe81a4340e4b1e9fe42f6d5e', 'gender': 1, 'headline': 'Quant', 'is_advertiser': False, 'url': '/people/3aedd28dfe81a4340e4b1e9fe42f6d5e', 'avatar_url_template': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_{size}.jpg', 'avatar_url': 'https://pic3.zhimg.com/13c152736a5bba65305158b9d93f08f3_l.jpg', 'description': 'Quant', 'badge': [{'type': 'identity', 'topics': [], 'description': '泰达宏利基金管理有限公司 金融工程研究员'}], 'uid': '34103307010048', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 1, 'is_labeled': False, 'title_image': 'https://pic3.zhimg.com/v2-b59cfed8537464a9291981a92f5b6902_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 36877346, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/36877346', 'admin_closed_comment': False, 'excerpt': '多因子模型分主要分为alpha模型和风险模型，alpha模型主要预测股票下期的超额收益，风险模型主要预测股票下期波动率和样本协方差矩阵，预测样本协方差矩阵主要有以下几种方法<b>1、样本协方差矩阵</b>，直接利用各个股票时间序列估计，需要每只股票时间序列要很长…', 'type': 'article', 'created': 1526374717, 'updated': 1567410504, 'state': 'published', 'voteup_count': 13, 'voting': 0, 'reason': '', 'title': '【数学工具系列】为什么不能直接用样本协方差矩阵来估计股票风险？'}]}
# saving 【数学工具系列】为什么不能直接用样本协方差矩阵来估计股票风险？
# saving 【数学工具系列】如何将Lasso回归转化为二次规划
# saving 【股票多因子系列】如何计算因子收益率
# saving 【股票多因子系列】Barra风格因子收益率
# saving 【投资心得】从凯利公式的角度看股票的投资逻辑
# saving 【股票多因子系列】股票池的筛选
# saving 【股票多因子系列】投资总结篇
# saving 【股票多因子系列】barra非线性市值计算方式
# saving 【读书笔记】芒格的10个心理学倾向
# saving 【投资心得】量化投资和行业研究有什么区别
# saving 【读书笔记】《投资中最简单的事》之投资理念篇
# saving 如何挑选股票基金（一）
# saving 如何挑选股票基金（二）
# saving 如何筛选股票基金（三）
# saving 如何筛选股票基金（四）
# saving 如何筛选股票基金（五）
# saving 如何筛选股票基金（六）
# saving 基金投资要知道点内幕情况
# saving 上证综指基金和深圳综指基金的两大问题
# saving 五花八门的指数
# saving 成分指数的一点基础知识
# saving 分级基金由两部分组成
# saving 分级A的净值走势就像爬楼梯
# saving 套利分级A
# saving 分级B基金之三个杠杠
# saving 分级基金之定期折算
# saving 分级基金之不定期折算
# saving 支付宝的慧定投怎么样
# saving 确定自己风险承受能力的最好方法
# saving 基金定投的四大原则
# saving 定投基金到底要怎么分配资金比较好
# saving 基金定投前必须要准备的三点
# saving 估值方法为资产配置打辅助
# saving 制作几份基金定投清单就能帮你赚大钱
# saving 借钱投资造成的悲哀
# saving 选择适合自己的投资工具
# saving 现金流方式才是致富之本
# saving 记账存钱之“一箭双雕”
# saving 为什么知道了那么多存钱方法却依然存不到钱？
# saving 我从来不过“双十一”的原因
# saving 买买买怎么能少得了它
# saving 多因子系列篇五_--_当我们说单因子分析的时候，意味着什么
# saving 2019年11月4日_股票推荐_牛股精选
# saving 看起来高大上的国债逆回购
# saving 只有发挥基金的优势才能赚钱
# saving 基金投资本来就是“没有把握的事情”
# saving 我为什么鼓励大家买纯债基金
# saving 股票知识丨股票V型反转如何捕捉？
# saving 股票知识丨细数八大经典炒股补仓技巧
# saving 股票知识丨如何控制仓位躲过市场大跌？
# saving 大盘第1001次骗炮
# exporting PDF...
# PDF已存在
# 未创建PDF
# fetching https://zhuanlan.zhihu.com/api/columns/ailabx/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=0', 'totals': 32, 'is_start': True, 'next': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 94509252, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/94509252', 'admin_closed_comment': False, 'excerpt': '1，docker pull libac/elasticsearch-rtf。安装es的rtf版本，这是2.2.1，与imooc的代码版本保持一致。<a href="https://link.zhihu.com/?target=https%3A//hub.docker.com/r/libac/elasticsearch-rtf" data-draft-node="block" data-draft-type="link-card" class=" external" target="_blank" rel="nofollow noreferrer"><span class="invisible">https://</span><span class="visible">hub.docker.com/r/libac/</span><span class="invisible">elasticsearch-rtf</span><span class="ellipsis"></span></a>使用这个docker的启动命令为：docker run -d -p 9200:9200 -p 9300:9300 --name es libac/elasticsearch-rtf两个-v把本地目录挂上。…', 'type': 'article', 'created': 1575201914, 'updated': 1575506169, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': '智能投顾系统开发日志'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 60753858, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/60753858', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic3.zhimg.com/v2-c312da99151142e49d1f15e762e545de_200x112.png" data-caption="" data-size="normal" data-rawwidth="640" data-rawheight="480" data-watermark="watermark" data-original-src="v2-c312da99151142e49d1f15e762e545de" data-watermark-src="v2-19707700bbceb2896705048c2f2ed768" data-private-watermark-src="" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic3.zhimg.com/v2-c312da99151142e49d1f15e762e545de_r.png"/>一般讲量化组合，会讲一个经典的投资组合——<b>股债二八平衡</b>。大致的思路就是80%的债券，20%的股票。然后每隔一段时间，检查占比。如果占比偏离一定的值，比如5%。那么，重新把权重还原成80：2 ...
# fetching https://zhuanlan.zhihu.com/api/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=0', 'totals': 32, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 47924746, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/47924746', 'admin_closed_comment': False, 'excerpt': '本篇我们将对比经典量化回测框架pyalgotrade与ailabx，二者同时实现均线策略。先看pyalgotrade的代码实现：from pyalgotrade import strategy\nfrom pyalgotrade.technical import ma\nfrom pyalgotrade.technical import cross\nfrom pyalgotrade.tools impor…', 'type': 'article', 'created': 1540791673, 'updated': 1540791673, 'state': 'published', 'voteup_count': 1, 'voting': 0, 'reason': '', 'title': '从零实现”搭积木式实现策略“的回测系统 part VI'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 47605403, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/47605403', 'admin_closed_comment': False, 'excerpt': '前面系列文章，我们把回测系统的主要部件作了详细的说明，这些部件构成了回测引擎的主体。如果把回测引擎比作一台机器，那么数据就是生产原料，而策略就是加工方法。策略需要对原始数据进行计算，得到各种中间指标，比如均线，MACD,布林带等等。我们基于tal…', 'type': 'article', 'created': 1540433658, 'updated': 1540433658, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': '从零实现”搭积木式实现策略“的回测系统 part V'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid':  ...
# fetching https://zhuanlan.zhihu.com/api/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10', 'totals': 32, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=30'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 38823341, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/38823341', 'admin_closed_comment': False, 'excerpt': '传统机器学习，其中有一项重要的工作就是”特征工程“，所谓”特征工程“就是提取基础数据的”特征“。比如图像识别，需要对图片进行灰度、二值化处理等。金融时间序列也可以做相应的特征提取，比如收益率，波动率，各种技术指标：均线，动量等，当然也可以…', 'type': 'article', 'created': 1530513476, 'updated': 1530513476, 'state': 'published', 'voteup_count': 1, 'voting': 0, 'reason': '', 'title': '金融数据特征提取与自动标注'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 38471655, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/38471655', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic3.zhimg.com/v2-c9c3eeeea7283c0f7baeb0268a182f92_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="268" data-rawheight="320" data-watermark="watermark" data-original-src="v2-c9c3eeeea7283c0f7baeb0268a182f92" data-watermark-src="v2-c84b58a7c867ece6346d5350034e2805" data-private-watermark-src="" data-original="https://pic3.zhimg.com/v2-c9c3eeeea7283c0f7baeb0268a182f92_r.jpg" class="origin_image inline-img zh-lightbox-thumb"/>尽管pytorch已经足够易用，但是仍然有一个模板化的代码，比如循环迭代训练网络。参考keras的api封装理念，我们可以把常用的pytorch的代码片断，也封装起来。BaseModel的实现继承自nn.Modulecompile传入优化器，损失函数。注意，我们在调用compile的时候再初…', 'type': 'article', 'created': 1529912327, 'updated': 1529912327, 'state': 'published', 'voteup_count': 0, 'voting': 0, 'reason': '', 'title': 'pytorch结构化封装：线性与逻辑回归'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headli ...
# fetching https://zhuanlan.zhihu.com/api/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=30
# {'paging': {'is_end': True, 'previous': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=20', 'totals': 32, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/ailabx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=40'}, 'data': [{'image_url': 'https://pic1.zhimg.com/v2-fb4fad51774df31150e5715cd012b8b7_b.jpg', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': 'https://pic1.zhimg.com/v2-fb4fad51774df31150e5715cd012b8b7_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 36962086, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/36962086', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic2.zhimg.com/v2-aa93f3aeef4f6fb22b91b5fd60bc7879_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="640" data-rawheight="480" data-watermark="watermark" data-original-src="v2-aa93f3aeef4f6fb22b91b5fd60bc7879" data-watermark-src="v2-b504296719f8d59590c99ebab26d4d32" data-private-watermark-src="" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic2.zhimg.com/v2-aa93f3aeef4f6fb22b91b5fd60bc7879_r.jpg"/>前文说过，有监督学习，如果label离散的问题称为“分类”，而label连续的问题称为回称。回归问题里，线性回归自然是最简单的。（knn严格来 讲不太算一个机器学习算法，它很直观，很好理解，就是计算欧氏距离，没有训练过程）。单变量的线性模型，其实就是一…', 'type': 'article', 'created': 1526540119, 'updated': 1526541251, 'state': 'published', 'voteup_count': 2, 'voting': 0, 'reason': '', 'title': 'sklearn线性回归模型'}, {'image_url': '', 'author': {'is_org': False, 'name': '魏佳斌', 'url_token': 'weijiabin', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': 'f144c6bbef58f3adfced551dd736a611', 'gender': 1, 'headline': '产品/技术总监，关注人工智能技术前沿并推动产品化。', 'is_advertiser': False, 'url': '/people/f144c6bbef58f3adfced551dd736a611', 'avatar_url_template': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/6047823c89ab49b6fc3966eeed0eedf8_l.jpg', 'description': '机器学习，深度学习，人工智能。关注技术边界与商业模式。\n跟踪前沿技术，理解它能解决的问题，并推动其产品化、商业化。', 'badge': [], 'uid': '768011338235539456', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 36922029, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/36922029', 'admin_closed_comment': False, 'excerpt': '后续文章的风格，都改成先应用，再理论。就是先给读者一个直观的感受，怎么用，解决什么问题，有什么样的产出，然后再来解释模型的理论，应用的边界等。HMM在python有一个实现：hmmlearn。但pip直接安装是不成功的，可以从这里下载编译好的包：…', 'type': 'article', 'created': 1526457448, 'updated': 1526457479, 'state': 'published', 'voteup_count': 0, 'voting': 0, 'reason': '', 'title': '隐马尔可夫模型(HMM)在金融量化中的应用'}]}
# saving 隐马尔可夫模型(HMM)在金融量化中的应用
# saving sklearn线性回归模型
# saving “功历型”学习不可取
# saving 深度强化学习在A股市场的量化应用
# saving 人人都是产品经理？
# saving 产品经理战略分析框架：点线面体
# saving Pytorch深度学习基础之Tensor
# saving 基于Pyqt5打造量化系统GUI
# saving 深度学习与量化投资
# saving AI量化：Python基础
# saving pytorch结构化封装：线性与逻辑回归
# saving 金融数据特征提取与自动标注
# saving 梯度提升树（GBDT）
# saving 深度强化学习的交易环境构建
# saving 深度强化学习交易环境构建（二）
# saving 想财富自由？先搞清楚个人商业模式
# saving 从零实现”搭积木式实现策略“的回测系统_part_I
# saving 从零实现”搭积木式实现策略“的回测系统_part_II
# saving 从零实现”搭积木式实现策略“的回测系统_part_III
# saving 从零实现”搭积木式实现策略“的回测系统_part_IV
# saving 从零实现”搭积木式实现策略“的回测系统_part_V
# saving 从零实现”搭积木式实现策略“的回测系统_part_VI
# saving 工程师思维看投资理财
# saving 余额宝不等于货基，你真的了解货币基金吗？
# saving 其实你每天都处在风险之中而不自知
# saving 算法PK_|_人工智能对指数涨跌预测
# get %s failed 算法PK_|_人工智能对指数涨跌预测
# saving 实用干货：手把手教你选债券基金
# saving 宏观视角看全球股市
# saving 基金定投的那些谎言
# saving 【一键提取】量化投资干货集
# saving 量化实证：破解那些大V的谎言
# saving 智能投顾系统开发日志
# exporting PDF...
# PDF已存在
# 未创建PDF
# fetching https://zhuanlan.zhihu.com/api/columns/quanttech/articles?include=data[*].admin_closed_comment,comment_count,suggest_edit,is_title_image_full_screen,can_comment,Cupvoted_followees,can_open_tipjar,can_tip,voteup_count,voting,topics,review_info,author.is_following,is_labeled,label_info
# {'paging': {'is_end': False, 'previous': 'https://zhuanlan.zhihu.com/columns/quanttech/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=0', 'totals': 62, 'is_start': True, 'next': 'https://zhuanlan.zhihu.com/columns/quanttech/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=10'}, 'data': [{'image_url': '', 'author': {'is_org': False, 'name': '量化汪', 'url_token': 'lianghuawang', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '65baa4a5ad72b1058666af2b4412b879', 'gender': 1, 'headline': '财经', 'is_advertiser': False, 'url': '/people/65baa4a5ad72b1058666af2b4412b879', 'avatar_url_template': 'https://pic4.zhimg.com/v2-8879444416f1f012c71ccb0d60688111_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/v2-8879444416f1f012c71ccb0d60688111_l.jpg', 'description': '欢迎来到量化投资大家学，我们搜罗顶尖量化资讯，发表专业量化见解，祝您成就宽客梦想，仗剑量化江湖。', 'badge': [], 'uid': '703560856205541376', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 2, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 28792216, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/28792216', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic2.zhimg.com/v2-65c71ed686b3d1771ef0a6bf2839d8cd_200x112.png" data-rawwidth="652" data-rawheight="144" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic2.zhimg.com/v2-65c71ed686b3d1771ef0a6bf2839d8cd_r.png"/>导读：今天想跟大家做的分享主要是从两个不同的维度来解释量化投资。第一个维度是时间维度，我想从这个维度跟大家探讨一下国内外量化投资的历史现状，然后我们来探讨一下未来大概会是一个什么情况。第二个维度是策略维度，其实我们如果看整个国际上，不仅仅…', 'type': 'article', 'created': 1503654486, 'updated': 1503654486, 'state': 'published', 'voteup_count': 3, 'voting': 0, 'reason': '', 'title': '【量化小科普】兴业量化投资研讨会议纪要之量化投资的历史现状和未来'}, {'image_url': '', 'author': {'is_org': False, 'name': '量化汪', 'url_token': 'lianghuawang', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '65baa4a5ad72b1058666af2b4412b879', 'gender': 1, 'headline': '财经', 'is_advertiser': False, 'url': '/people/65baa4a5ad72b1058666af2b4412b879', 'avatar_url_template': 'https://pic4.zhimg.com/v2-8879444416f1f012c71ccb0d60688111_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/v2-8879444416f1f012c71ccb0d60688111_l.jpg', 'description': '欢迎来到量化投资大家学，我们搜罗顶尖量化资讯，发表专业量化见解，祝您成就宽客梦想，仗剑量化江湖。', 'badge': [], 'uid': '703560856205541376', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': '', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 28792049, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/28792049', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic2.zhimg.com/v2-aa37ccf44966fcc1e61856359a4e5e65_200x112.jpg" data-rawwidth="640" data-rawheight="985" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic2.zhimg.com/v2-aa37ccf44966fcc1e61856359a4e5e65_r.jpg"/>导读： 近年来，海外的对冲基金开始在人工智能上进行布局。Citadel、Two Sigma、桥水基金、文艺复兴科技公司等公司都已经建立自己的人工智能团队。我们在2014年发布的深度学习选股交易策略的基础上，精选股票特征，采用深度学习领域的最新技术，建立预测模…', 'type': 'article', 'created': 1503654108, 'updated': 1503654107, 'state': 'published', 'voteup_count': 1, 'voting': 0, 'reason': '', 'title': '【天天阿尔法】深度学习新进展：Alpha因子再挖掘'}, {'image_url': 'https://pic2.zhimg.com/v2-0766e18b8ae145283c68c6cd2d64e808_b.jpg', 'author': {'is_org': False, 'name': '量化汪', 'url_token': 'lianghuawang', 'type': 'people', 'is_followed': False, 'user ...
# ...
# fetching https://zhuanlan.zhihu.com/api/columns/Lhtz-Jqxx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=160
# {'paging': {'is_end': True, 'previous': 'https://zhuanlan.zhihu.com/columns/Lhtz-Jqxx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=150', 'totals': 163, 'is_start': False, 'next': 'https://zhuanlan.zhihu.com/columns/Lhtz-Jqxx/articles?include=data%5B%2A%5D.admin_closed_comment%2Ccomment_count%2Csuggest_edit%2Cis_title_image_full_screen%2Ccan_comment%2CCupvoted_followees%2Ccan_open_tipjar%2Ccan_tip%2Cvoteup_count%2Cvoting%2Ctopics%2Creview_info%2Cauthor.is_following%2Cis_labeled%2Clabel_info&limit=10&offset=170'}, 'data': [{'image_url': 'https://pic4.zhimg.com/v2-9b7f8c122624c0012b10d687b8c4ccd5_b.jpg', 'author': {'is_org': False, 'name': 'Quant最爱', 'url_token': 'zxlrs', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '5fcd0638adc2143b49d28bbbfbe6d5a1', 'gender': 0, 'headline': '', 'is_advertiser': False, 'url': '/people/5fcd0638adc2143b49d28bbbfbe6d5a1', 'avatar_url_template': 'https://pic4.zhimg.com/v2-08061080aa1bc018c9c3f44538863990_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/v2-08061080aa1bc018c9c3f44538863990_l.jpg', 'description': '', 'badge': [], 'uid': '645625260192567296', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 8, 'is_labeled': False, 'title_image': 'https://pic4.zhimg.com/v2-9b7f8c122624c0012b10d687b8c4ccd5_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 24617482, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/24617482', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic1.zhimg.com/v2-3c9c17a77c80b89bd6a3b19835c01ff8_200x112.png" data-rawwidth="1222" data-rawheight="305" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic1.zhimg.com/v2-3c9c17a77c80b89bd6a3b19835c01ff8_r.png"/><b>编辑部：</b>2016年就要结束啦！量化投资与机器学习公众号将给大家带来一篇关于量化投资总结性的推文。为<strong>微信公众号全网搜索排名前三</strong>的我们<strong>精心准备了这篇推文</strong>。希望2016年量化投资界有一个完美谢幕，并在2017年有新的展望。 谢谢你们的阅读！原文链接：<a href="https://link.zhihu.com/?target=http%3A//mp.weixin.qq.com/mp/getmasssendmsg%3F__biz%3DMzAxNTc0Mjg0Mg%3D%3D%23wechat_webview_type%3D1%26wechat_redirect" class=" wrap external" target="_blank" rel="nofollow noreferrer">2016年…</a>', 'type': 'article', 'created': 1482976540, 'updated': 1482976539, 'state': 'published', 'voteup_count': 80, 'voting': 0, 'reason': '', 'title': '2016年量化投资界的波澜壮阔'}, {'image_url': 'https://pic1.zhimg.com/v2-827d5a28f8ec17891ab4cf8ee2771968_b.jpg', 'author': {'is_org': False, 'name': 'Quant最爱', 'url_token': 'zxlrs', 'type': 'people', 'is_followed': False, 'user_type': 'people', 'id': '5fcd0638adc2143b49d28bbbfbe6d5a1', 'gender': 0, 'headline': '', 'is_advertiser': False, 'url': '/people/5fcd0638adc2143b49d28bbbfbe6d5a1', 'avatar_url_template': 'https://pic4.zhimg.com/v2-08061080aa1bc018c9c3f44538863990_{size}.jpg', 'avatar_url': 'https://pic4.zhimg.com/v2-08061080aa1bc018c9c3f44538863990_l.jpg', 'description': '', 'badge': [], 'uid': '645625260192567296', 'is_following': False}, 'comment_permission': 'all', 'comment_count': 0, 'is_labeled': False, 'title_image': 'https://pic1.zhimg.com/v2-827d5a28f8ec17891ab4cf8ee2771968_b.jpg', 'can_comment': {'reason': '', 'status': True}, 'suggest_edit': {'url': '', 'title': '', 'reason': '', 'status': False, 'tip': ''}, 'id': 22102519, 'excerpt_title': '', 'url': 'https://zhuanlan.zhihu.com/p/22102519', 'admin_closed_comment': False, 'excerpt': '<img src="https://pic4.zhimg.com/74b509bae4eee5eabc0857a91c995eaf_200x112.jpg" data-caption="" data-size="normal" data-rawwidth="1062" data-rawheight="519" class="origin_image inline-img zh-lightbox-thumb" data-original="https://pic4.zhimg.com/74b509bae4eee5eabc0857a91c995eaf_r.jpg"/>获取书籍链接：<a href="https://link.zhihu.com/?target=http%3A//m ...
# saving 『多因子系列』之新手必看_|_量化交易七宗罪
# get %s failed 『多因子系列』之新手必看_|_量化交易七宗罪
# saving 【书籍分享】国外近期深度学习与机器学习书籍电子版
# saving 2016年量化投资界的波澜壮阔
# saving 【Python量化投资】系列之SVR预测第二天开盘趋势和股价的正负统计分析
# saving 择时策略：在一天的何时进行交易
# saving 致敬赵雷：基于TensorFlow让机器生成赵雷曲风的歌词
# saving 数据分析（工具篇）——Boosting
# saving 【独家】周志华教授gcForest（多粒度级联森林）算法预测股指期货涨跌
# saving 2017量化投资界的波澜壮阔开始编写和征稿啦！
# saving 战斗民族开源神器ClickHouse：一款适合于构建量化回测研究系统的高性能列式数据库——Clickhouse入门指南
# saving 战斗民族开源神器ClickHouse：一款适合于构建量化回测研究系统的高性能列式数据库——Clickhouse是什么？
# saving 【精心解读】用pandas处理大数据——节省90%内存消耗的小贴士
# saving 【干货】最新有关_DL_&_ML_的_R_语言书籍
# saving 强化学习（Reinforcement_Learning）应用于量化投资系列专题（一）——在交易中的应用
# saving 强化学习（Reinforcement_Learning）应用于量化投资系列专题（二）——设计外汇交易系统基于自适应强化学习
# saving 使用RNN预测股票价格系列（一）
# saving 使用RNN预测股票价格系列（二）
# saving 用_PyMC3_进行贝叶斯统计分析（代码+实例）
# saving 在研究机构，如何应用贝叶方法论进行量化投资汇总
# saving 【干货】Deep_Learning_with_Python_终于等到你！
# saving 最全_LSTM_模型在量化交易中的应用汇总（代码+论文）
# saving 2017年“第15届新财富最佳分析师”金融工程前五获奖名单（附所有券商金融工程类研报汇总）
# saving 【解读】遗传基因程序二元机器代码自动归纳合成算法
# saving 【干货】Quantitative_Finance_杂志关于量化交易领域排名前十的文章
# saving 打下扎实的基本功——概率分布图​（一）
# saving 有关行为经济学的（10多本书籍）+（130多篇论文）致敬诺贝尔经济学奖！
# saving 【致敬高考】那些开设『量化投资』专业的大学
# saving 【重量级】模型校正在量化金融中的应用
# saving Jupyter_Notebooks里的TensorFlow图可视化
# saving 高效灵活的概率建模方法基于Python
# saving 高频交易（18篇论文）+（15本书籍）+（9篇研报）公众号精选的！
# saving CNN预测股票走势基于Tensorflow（思路+程序）
# saving 史上最全神经网络结构图画图工具介绍，没有之一！
# saving 【精选干货】近期有关机器学习、深度学习、数据科学方面的书籍
# saving 【解读】2017年ML／NLP论文发表情况
# saving 【重磅】2018年投资界十大猜想
# saving 【精选干货】2017年12月份机器学习排名前10名文章（论文+代码）
# saving 【精心解读】关于Jupyter_Notebook的28个技巧
# saving 【拥抱量化】当AI遇上智能投顾——公众号受邀参加万得3C中国财经会议
# saving 机器学习应用区块链系列（一）——如何开发一套自己的智能合约系统
# saving 【代码+论文】通过ML、Time_Series模型学习股价行为
# saving 模式识别在金融时间序列中的应用【系列五十】
# saving 2018年「金融平均脸」出炉，是不是要长这样才能做期货？
# saving 还是不靠谱！多维LSTM网络预测比特币价格【机器学习应用区块链系列二】
# saving 基于Python预测股价的那些人那些坑，请认真看完！【系列52】
# saving 请收下这份榜单：2017年最热门的50篇券商金工研报（附下载）
# saving 『量化投资』冲顶大会第一场！
# saving 将海外量化资源一网打尽！
# saving 【顶级资源】掌握线性代数为机器学习打下坚实基础！
# saving 基于XGBoost的量化金融实战【系列53】
# saving 【必看】机器学习应用量化投资必须要踩的那些坑！
# saving 特征重要性在量化投资中的深度应用【系列56】
# saving 【重磅】起薪50万，人才缺口20万的量化研究岗最深入调研！（文末专栏福利）
# saving 【精选】使用Cryptory分析影响加密货币价格的因素（区块链系列3）
# saving 因子的有效性分析基于7种机器学习算法【系列54】
# saving 小猪佩奇_×_全网量化平台_|_圣杯的开始！
# get %s failed 小猪佩奇_×_全网量化平台_|_圣杯的开始！
# saving 比较13种算法在165个数据集上的表现，你猜哪个最好？
# saving 【深入解读】为什么机器学习在投资领域并不是那么好用（系列57）
# saving 【重磅】一个基于机器学习的纯量化框架出世，助力风险投资！
# saving 全网就我们一家_|_宽客的成长之路_（规划+资料）
# get %s failed 全网就我们一家_|_宽客的成长之路_（规划+资料）
# saving 上海见！机器学习与量化投资论坛
# saving 母上大人，儿臣给您推荐一些用量化赚钱的好东西！
# saving 【干货】5月机器学习、深度学习好书分享（打包带走）
# saving MATLAB_EXPO_|_北京现场+微信直播，精彩不错过
# get %s failed MATLAB_EXPO_|_北京现场+微信直播，精彩不错过
# saving 【干货】近期最受欢迎的券商金工研报汇总（文末彩蛋）
# saving 【全球第一帖】全面解读吴恩达新书（上）
# saving 基于风险中性的深度学习选股策略
# saving 【HFT系列】利用强化学习构建高频交易模型
# saving 【HFT系列】基于机器学习的动态高频限价订单簿框架（Tick数据）
# saving 【独家重磅】来自华尔街的量化金融面试Q&A（第一期）
# saving 【独家前沿策略】机器学习应用投资组合系列（代码+论文）
# saving 【独家重磅】来自华尔街的量化金融面试Q&A（第二期）
# saving 【最新解读】Ray_Dalio——中美之间的误解、争议和战争
# saving 比特币高频交易策略（文章+代码）
# saving 世界头号私募桥水基金正式入华割韭菜（附投资策略详解）
# saving 【全球第一帖】全面解读吴恩达新书（中）
# saving 策略篇——残差项的均值回归
# saving 研报复现初探—华泰金工人工智能选股系列之随机森林模型
# saving 【干货】桥水基金掌舵人达里奥又出新书啦！（文末下载）
# saving 深度强化学习模型的研究与应用
# saving Andrew_Ng_机器学习课程的Python实现
# saving 【价值投资逻辑】高质量、低估值选股模型（代码+报告）
# saving 基于阻力支撑相对强度（RSRS）的市场择时
# saving 【深度分享】经过多年交易之后你应该学到的东西
# saving 从Seq2seq到Attention模型到Self_Attention（一）
# saving 从Seq2seq到Attention模型到Self_Attention（二）
# saving 【精选】卡尔曼滤波及其在配对交易中的应用
# saving 股市风起云涌，我用Python分析周期之道
# saving 使用LSTM预测股票市场基于Tensorflow
# saving 手把手教你用Numpy构建神经网络！（附代码）
# saving 一招鲜，判断哪些输入特征对神经网络是重要的！
# saving ESG策略有超额收益吗？
# saving 精心为大家整理了一些超级棒的机器学习资料（附链接）
# saving 机器学习、深度学习、量化金融、Python等最新书籍汇总（打包带走）
# saving 层次聚类资产配置
# saving 夏普率有效前沿
# saving 收缩夏普率(Deflated_Sharpe_Ratio)
# saving 【重磅】年度宽客（2000_-_2019），全球Q-quant精英都在研究什么？
# saving 各大卖方2019年A股策略报告，都是有故事的人！
# saving 京东量化平台宣告下线，其他平台该何去何从？
# saving 一命二运三风水_|_2019年投资风水报告，信命不？
# get %s failed 一命二运三风水_|_2019年投资风水报告，信命不？
# saving 深度_|_强化学习应用金融投资组合优化（附代码）
# get %s failed 深度_|_强化学习应用金融投资组合优化（附代码）
# saving 严谨解决5种机器学习算法在预测股价的应用（代码+数据）
# saving 【2万字干货】利用深度学习最新前沿预测股价走势
# saving 【干货】教你如何鉴别那些用深度学习预测股价的花哨模型？
# saving 【跳槽必备】全球最知名的十五大高频交易公司大揭秘！
# saving 高频交易已经竞争到纳秒级！！！（附HFT的18篇论文+15本书籍+9篇研报）
# saving 独家_|_搭建入门级高频交易系统（架构细节分享）
# get %s failed 独家_|_搭建入门级高频交易系统（架构细节分享）
# saving 独家_|_9位全球顶尖学者，研讨因子投资和Smart_Beta
# get %s failed 独家_|_9位全球顶尖学者，研讨因子投资和Smart_Beta
# saving 策略篇：残差项的均值回归——实证部分
# saving 独家_|_全球_AI_量化金融机构全景图（附完整分析）
# get %s failed 独家_|_全球_AI_量化金融机构全景图（附完整分析）
# saving 久等了_|_WorldQuant_101_Alpha、国泰君安_191_Alpha（源码分享）
# get %s failed 久等了_|_WorldQuant_101_Alpha、国泰君安_191_Alpha（源码分享）
# saving 3.14特别纪念_|_π_的第100000000000000···
# get %s failed 3.14特别纪念_|_π_的第100000000000000···
# saving 金融界都该看的华尔街风云美剧：Billions（附全季资源）
# saving Fama-French，让我们重新认识你！
# saving 必须收藏_|_手把手教你几分钟内搭建自己强大的深度学习环境
# get %s failed 必须收藏_|_手把手教你几分钟内搭建自己强大的深度学习环境
# saving 干货_|_如何用一行代码在多CPU环境下高效并行Pandas
# get %s failed 干货_|_如何用一行代码在多CPU环境下高效并行Pandas
# saving 使用Prophet预测股价并进行多策略交易（附代码）
# saving 算法交易系统开发，揭开Developer的神秘面纱（代码+核心思路）
# saving 干货_|_Python优化技巧：bowl、plate_和valley函数（附代码）
# get %s failed 干货_|_Python优化技巧：bowl、plate_和valley函数（附代码）
# saving 打造新一代高频交易_|_MIT才女Christina_Qi专访
# get %s failed 打造新一代高频交易_|_MIT才女Christina_Qi专访
# saving 超级干货_|_ML、DL预测股市模型汇总（史上最全，没有之一）
# get %s failed 超级干货_|_ML、DL预测股市模型汇总（史上最全，没有之一）
# saving 独家_|_定制股票交易OpenAI_Gym强化学习环境（附代码）
# get %s failed 独家_|_定制股票交易OpenAI_Gym强化学习环境（附代码）
# saving ​机器学习分类算法在因子投资中的应用
# saving 详细报道_|_关于高盛在Github开源背后的真相！
# get %s failed 详细报道_|_关于高盛在Github开源背后的真相！
# saving 真的！独家！_|_关于Quant／Trader求职分享（附真实试题）
# get %s failed 真的！独家！_|_关于Quant／Trader求职分享（附真实试题）
# saving 小姐姐的传奇蜕变！从丑小鸭到Developer
# saving 作为Python中级程序员，有句话不知当讲不当讲_(￣へ￣)
# saving 拿起Python，防御特朗普的Twitter！
# saving 用深度强化学习打造不亏钱的交易机器人（附代码）
# saving 手把手教你建立交易机器人（超强文档+超强代码）
# saving 吐血干货_|_量化、算法、机器学习交易书单完整目录
# get %s failed 吐血干货_|_量化、算法、机器学习交易书单完整目录
# saving 最新_|_Microsoft发布可视化托拉拽机器学习工具
# get %s failed 最新_|_Microsoft发布可视化托拉拽机器学习工具
# saving AQR最最最新_|_计量经济学应用投资失败的7个原因
# get %s failed AQR最最最新_|_计量经济学应用投资失败的7个原因
# saving AQR最新研究_|_机器能“学习”金融吗？
# get %s failed AQR最新研究_|_机器能“学习”金融吗？
# saving 交易员是这么好当的吗？呵呵~
# saving π_的美丽！
# saving 配对交易千千万，强化学习最给力！（附文档+代码讲解）
# saving 机器学习在量化金融领域的误用！
# saving 所有模型都是错的，但其中有些是有用的！
# saving 2019最新西蒙斯访谈：量化策略、职业与交易（全网独家）
# saving 买鞋都要看K线，量化模型来看看！
# saving 锐天，校招！
# saving 史上最全的顶级对冲基金名单和工资
# saving 另类Alpha：基于产业节点联动效应的量化交易策略
# saving 你能在千禧年赚多少钱？
# saving CuPy：将Numpy提速700倍！
# saving 71803倍！超强Pandas循环提速攻略
# saving 九坤，校招！
# saving 风险平价这10年！
# saving 量化学术论文常：数据滥用严重、程序Bug泛滥！
# saving 仓位管理：超越凯利公式，梦回华尔街！
# saving 大爱！编程语言创意海报，每一幅都好喜欢！
# saving 高盛花了1个亿！为减少股票交易的毫秒数
# saving 服不服！数据科学语言鄙视链
# saving 超火动态排序图：代码不到40行，手把手教你！
# saving 2008年以来Stack_Overflow上最流行的编程语言
# saving 200秒=1万年，量子计算：对冲基金的未来！
# saving 可视化：58年GDP见证大国崛起！
# saving 想去Citadel？凭本事你能拿多少薪水！
# saving 认知交易系统模型！
# saving Smart_Beta__VS__Alpha+Beta
# saving 新书！了解文艺复兴的一手资料（附下载，手慢无）
# exporting PDF...
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-16-6ce9d9c53dcc> in <module>()
#      40             get_list(eachauthor)
#      41             get_details()
# ---> 42             if to_pdf(eachauthor)==True:
#      43                 print('成功创建PDF')
#      44             else:
#
# <ipython-input-10-07fcdb35ff89> in to_pdf(author1)
#      15
#      16     if not os.path.exists(HtmlSavePath+ '知乎专栏_' +author1 + '.pdf'):
# ---> 17         pdfkit.from_file(sorted(htmls),HtmlSavePath+ '知乎专栏_' + author1 + '.pdf',configuration=config,options=options,cover=cover)
#      18         return True
#      19     else:
#
# C:\Program Files\Anaconda3\lib\site-packages\pdfkit\api.py in from_file(input, output_path, options, toc, cover, css, configuration, cover_first)
#      47                configuration=configuration, cover_first=cover_first)
#      48
# ---> 49     return r.to_pdf(output_path)
#      50
#      51
#
# C:\Program Files\Anaconda3\lib\site-packages\pdfkit\pdfkit.py in to_pdf(self, path)
#     157
#     158         if exit_code != 0:
# --> 159             raise IOError("wkhtmltopdf exited with non-zero code {0}. error:\n{1}".format(exit_code, stderr))
#     160
#     161         # Since wkhtmltopdf sends its output to stderr we will capture it
#
# OSError: wkhtmltopdf exited with non-zero code 1. error:
