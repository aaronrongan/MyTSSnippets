# %% [markdown]
# # 要点：
#
# * 对0day的数据进行合并，并做为pandas的练习
# * 合并删除，将pagenumber，如17101 作为索引
# * 类别做多个column?
# * 统计
#     * 各年的article量
#     * Solidworks、音乐、pandas各有多少，排序？
# * 做一GUI，如果需要哪些，自动出现，能粘贴密码、链接
# * 后期的数据维护，添加新月份的（以后再说）
# * data.drop(['Unnamed: 0'],inplace=True, axis=1) #删除第一列，重新用pagenumber做索引
# * data.drop([0],inplace=True, axis=0) 删除第一行
# * 给列重命名：data.rename(columns={'OldName.' : 'NewName'})
# * 列的数目len(data.columns)
# * 获取某种的指定长度字段 data['IndexNumber']=data['PageLink'].apply(lambda x: x[-5:])
# * 找出有多少重复项
# * 将pagelink中根据p=10000的长度来抓出作为Index
#     data['IndexNumber']=data['PageLink'].apply(lambda x: x[-len(x.split('=')[1]):])
# * 将一列字符串改为数字，在上面的lambda前加一个int()即可
#     data['IndexNumber']=data['PageLink'].apply(lambda x: int(x[-len(x.split('=')[1]):]))
# * 选择包含某个字符串 df[df['colname'].str.contains('somestring')]
# * 将DataFrame groupby转为DataFrame格式，只要指定as_index=False即可
#     grouped=data.groupby('UploadTime',as_index=False).count()
# * **如何将无法读取的那些网页列出来，手动加入？** 如83230 、 84676这些无法连接的

# %%
import glob
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-182-4b5655f984c3> in <module>
#       2 import pandas as pd
#       3
# ----> 4 import matplotlib.pyplot as plt
#       5 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ImportError: No module named 'matplotlib'

# %%
'''
将分散的csv文件合并
https://blog.csdn.net/u012735708/article/details/83989842
注意文件在导入导出时，header的处理，什么时候要True，什么时候要None
'''

# csvPath='C:/Users/Administrator/Documents/MyMobileBooks_800_Reading/0DayFileList/test/'
csvPath='C:/LocalTempFiles/'

Columns1=['Category','UploadTime','ArticalName','PageLink','BaiduLink','BaiduPwd']
header1=['number','Category','UploadTime','ArticalName','PageLink','BaiduLink','BaiduPwd']
outputfile=csvPath + '0daytown_1_50000.csv' 

def CombineCSV():
    
#     for inputfile in os.walk(HtmlSavePath):
    csv_list=glob.glob(csvPath + '*.csv')
                       
    print(u'共发现%s个CSV文件'% len(csv_list))
    
    print(u'正在处理............')
    
    for inputfile in  glob.glob(csvPath + '/*.csv'):
        
#         csvfilenames += [csvPath + name for name in files if name.endswith(".csv")]
        print(inputfile)                        
        f=open(inputfile,encoding='utf-8')        
        data=pd.read_csv(f)

#         data.drop['index']
#         data.drop(data['index']==0)
        
        
#         data.drop([7],inplace=True, axis=1) 
#         print("Before Drop:" )
#         print(data.columns)
#         print(data.head(2))
        data.drop(['Unnamed: 0'],inplace=True, axis=1) #删除第一列，重新用pagenumber做索引
#         data.drop([0],inplace=True, axis=0)

#         print("After Drop:" )
#         print(data.head(2))
#         print(data.columns)
#         print(len(data.columns))
#         ColLen=len(data.columns)

        #11001~12000 文件中有第7列冗余
        if len(data.columns)==7: 
            print('7')
            data.drop(['Unnamed: 7'],inplace=True, axis=1)
            print(data.head(2))
        elif len(data.columns)==6: 
            print('6')
        data.to_csv(outputfile,mode='a',index=True,encoding='utf-8-sig',header=None)
        f.close()
#         data.close()
        
    print('完成合并') 

def CleanDuplicates(file):    
    df = pd.read_csv(file,header=0)   
    datalist = df.drop_duplicates()    
    datalist.to_csv(file)    
    print('完成去重') 
    
if __name__ == '__main__':  
    print(1)
    CombineCSV()    
#     CleanDuplicates(outputfile)
# Out:
# 1
# 共发现57个CSV文件
# 正在处理............
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# 6
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-192-6441bae0f301> in <module>
#      66 if __name__ == '__main__':
#      67     print(1)
# ---> 68     CombineCSV()
#      69 #     CleanDuplicates(outputfile)
#
# <ipython-input-192-6441bae0f301> in CombineCSV()
#      26
#      27         f=open(inputfile,encoding='utf-8')
# ---> 28         data=pd.read_csv(f)
#      29
#      30 #         data.drop['index']
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._get_header()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xcb in position 74: invalid continuation byte

# %%
ColName=['No.','Category','UploadTime','ArticalName','PageLink','BaiduLink','BaiduPwd']
data=pd.read_csv("C:/LocalTempFiles/Test/0daytown_1_50000.csv",encoding='utf-8-sig',header=None)
data.columns=ColName
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-185-aad64293c3d7> in <module>
#       1 ColName=['No.','Category','UploadTime','ArticalName','PageLink','BaiduLink','BaiduPwd']
# ----> 2 data=pd.read_csv("C:/LocalTempFiles/Test/0daytown_1_50000.csv",encoding='utf-8-sig',header=None)
#       3 data.columns=ColName
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# --> 702         return _read(filepath_or_buffer, kwds)
#     703
#     704     parser_f.__name__ = name
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     427
#     428     # Create the parser.
# --> 429     parser = TextFileReader(filepath_or_buffer, **kwds)
#     430
#     431     if chunksize or iterator:
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     893             self.options['has_index_names'] = kwds['has_index_names']
#     894
# --> 895         self._make_engine(self.engine)
#     896
#     897     def close(self):
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1120     def _make_engine(self, engine='c'):
#    1121         if engine == 'c':
# -> 1122             self._engine = CParserWrapper(self.f, **self.options)
#    1123         else:
#    1124             if engine == 'python':
#
# c:\users\administrator\appdata\local\programs\python\python35\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1851         kwds['usecols'] = self.usecols
#    1852
# -> 1853         self._reader = parsers.TextReader(src, **kwds)
#    1854         self.unnamed_cols = self._reader.unnamed_cols
#    1855
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File b'C:/LocalTempFiles/Test/0daytown_1_50000.csv' does not exist: b'C:/LocalTempFiles/Test/0daytown_1_50000.csv'

# %%
data.head(3)
# Out:
#   IndexNumber                       Category  UploadTime  \
# 0       =1002  0daytown->Software->CAX/EDA->  2014-06-25
# 1       =1003  0daytown->Software->Windows->  2014-06-25
# 2       =1004  0daytown->Software->Windows->  2014-06-25
#
#                               ArticalName                         PageLink  \
# 0                        Oasys 11.0 Suite  http://www.0daytown.com/?p=1002
# 1  CoolUtils PDF Combine 3.1.24 PDF文件合并工具  http://www.0daytown.com/?p=1003
# 2        MetaRaw 1.0c for Adobe Photoshop  http://www.0daytown.com/?p=1004
#
#                                            BaiduLink BaiduPwd
# 0                                                NaN      NaN
# 1  http://pan.baidu.com/share/link?shareid=745564...      NaN
# 2  http://pan.baidu.com/share/link?shareid=755236...      NaN

# %%
data.rename(columns={'No.' : 'IndexNumber'},inplace=True) 

# data['IndexNumber']=data['PageLink'].apply(lambda x: x[-5:])

# print(data['PageLink'][0].strip('='))


data['IndexNumber']=data['PageLink'].apply(lambda x: int(x[-len(x.split('=')[1]):]))

# data.reset_index(inplace=True)
data.set_index('IndexNumber',inplace=True)
data.head(3)
data.tail(3)
# Out:
#                          Category  UploadTime  \
# IndexNumber
# 49998        0daytown->教程->其他教程->  2017-01-09
# 49999        0daytown->教程->其他教程->  2017-01-09
# 50000        0daytown->教程->其他教程->  2017-01-09
#
#                                                    ArticalName  \
# IndexNumber
# 49998        Benny Greb – The Language of Drumming: A Syste...
# 49999        Lynda – Outlook 2013: Prepare for the Microsof...
# 50000        Lynda – Excel 2013: Prepare for the Microsoft ...
#
#                                      PageLink  \
# IndexNumber
# 49998        http://www.0daytown.com/?p=49998
# 49999        http://www.0daytown.com/?p=49999
# 50000        http://www.0daytown.com/?p=50000
#
#                                    BaiduLink BaiduPwd
# IndexNumber
# 49998        http://pan.baidu.com/s/1eRMSv78     uuau
# 49999        http://pan.baidu.com/s/1nvMovI5     wdt7
# 50000        http://pan.baidu.com/s/1dE5Zzvr     p2dg

# %%
data.sort_index()
# Out:
#                                         Category  UploadTime  \
# IndexNumber
# 1                  0daytown->Software->Windows->  2014-06-06
# 2                           0daytown->教程->吉他技术->  2014-06-06
# 3                  0daytown->Software->Windows->  2014-06-06
# 4                                 0daytown->教程->  2014-06-06
# 5                    0daytown->教程->Photoshop教程->  2014-06-06
# 6                       0daytown->教程->ZBrush教程->  2014-06-06
# 7            0daytown->Software->Windows->应用软件->  2014-06-06
# 8                  0daytown->Software->CAX/EDA->  2014-06-06
# 9                  0daytown->Software->Windows->  2014-06-06
# 10                 0daytown->Software->CAX/EDA->  2014-06-06
# 11                 0daytown->Software->Windows->  2014-06-06
# 12                             0daytown->Games->  2014-06-07
# 13                  0daytown->Software->MacOSX->  2014-06-07
# 14                         0daytown->教程->Unity->  2014-06-07
# 15                0daytown->素材->3D模型/3D Models->  2014-06-07
# 16                                0daytown->教程->  2014-06-07
# 17                                0daytown->教程->  2014-06-07
# 18                  0daytown->Software->MacOSX->  2014-06-07
# 19                                0daytown->教程->  2014-06-07
# 20                  0daytown->Software->MacOSX->  2014-06-07
# 21                  0daytown->Software->MacOSX->  2014-06-07
# 22           0daytown->Software->Windows->媒体处理->  2014-06-07
# 23           0daytown->Software->Windows->应用软件->  2014-06-07
# 24           0daytown->Software->Windows->媒体处理->  2014-06-07
# 25                  0daytown->Software->MacOSX->  2014-06-07
# 26                 0daytown->Software->CAX/EDA->  2014-06-07
# 27                                0daytown->教程->  2014-06-07
# 28                  0daytown->Software->MacOSX->  2014-06-07
# 29           0daytown->Software->Windows->媒体处理->  2014-06-07
# 30           0daytown->Software->Windows->图形图像->  2014-06-07
# ...                                          ...         ...
# 49971                    0daytown->教程->移动App开发->  2017-01-09
# 49972                       0daytown->教程->网络技术->  2017-01-09
# 49973                       0daytown->教程->其他教程->  2017-01-09
# 49974                       0daytown->教程->网络技术->  2017-01-09
# 49975                    0daytown->教程->移动App开发->  2017-01-09
# 49976                             0daytown->教程->  2017-01-09
# 49977               0daytown->Software->MacOSX->  2017-01-09
# 49978               0daytown->Software->MacOSX->  2017-01-09
# 49979               0daytown->Software->MacOSX->  2017-01-09
# 49980                  0daytown->素材->音色/Timbre->  2017-01-09
# 49981                  0daytown->素材->音色/Timbre->  2017-01-09
# 49982                  0daytown->素材->音色/Timbre->  2017-01-09
# 49983                  0daytown->素材->音色/Timbre->  2017-01-09
# 49984                  0daytown->素材->音色/Timbre->  2017-01-09
# 49985              0daytown->Software->Windows->  2017-01-09
# 49986                         0daytown->Ebooks->  2017-01-09
# 49987                         0daytown->Ebooks->  2017-01-09
# 49988                         0daytown->Ebooks->  2017-01-09
# 49989                         0daytown->Ebooks->  2017-01-09
# 49990                         0daytown->Ebooks->  2017-01-09
# 49991                         0daytown->Ebooks->  2017-01-09
# 49992               0daytown->Software->MacOSX->  2017-01-09
# 49993              0daytown->Software->Windows->  2017-01-09
# 49994               0daytown->Software->MacOSX->  2017-01-09
# 49995               0daytown->Software->MacOSX->  2017-01-09
# 49996               0daytown->Software->MacOSX->  2017-01-09
# 49997                  0daytown->素材->音色/Timbre->  2017-01-09
# 49998                       0daytown->教程->其他教程->  2017-01-09
# 49999                       0daytown->教程->其他教程->  2017-01-09
# 50000                       0daytown->教程->其他教程->  2017-01-09
#
#                                                    ArticalName  \
# IndexNumber
# 1                                              CW Skimmer 1.91
# 2            Lick Library – Stuart Bull’s Electric Blues In...
# 3                                 IBM ILOG CPLEX for AMPL 12.6
# 4                                                      socks 5
# 5            Corel Roxio Creator NXT 2 15.0.5.2 Build 15080...
# 6                                    WinRAR 5.00 beta 2|压缩解压软件
# 7               Bee IT Service Sesame v1.0 and Portable|文件加密程序
# 8            CSI SAP2000 v15.2.1 Ultimate-LAV (2013)|结构通用有限...
# 9                                   Windows 8.1 build 9385 泄露版
# 10           Embarcadero RAD Studio XE4 18.0.4854.59655|终极应...
# 11           Nuke and NukeX 7.0 V6 Stable Version Win64 wit...
# 12                      Call of Duty: Ghosts(使命召唤10：幽灵)预告片霸气登场
# 13           Adobe Premiere Elements v.11.0 Updated 2 Portable
# 14                   QQ2013 Beta4 What’s new|QQ2013 Beta4诚邀您体验
# 15                            Windows 8.1 Build 9385 编译版泄露操作视频
# 16                          FlashFXP v4.3.1 build 1956|FTP上传下载
# 17                 uTorrent v3.3 Build 29625 Stable|内网加速迷你BT软件
# 18                              百度输入法 v3.0 For Mac|最好单Mac中文输入法
# 19           MetaProducts Portable Offline Browser v6.6.392...
# 20           GraphicConverter v8.6 Multilingual MacOSX Incl...
# 21                      Serial Box 05-2013 MAC OSX-P2P|序列号查询工具
# 22           Cockos REAPER v4.402 Incl Keygen and Patch-BRD...
# 23                  XYplorer v12.40.0000 Incl Keygen-P2P 资源管理器
# 24           4Videosoft Blu-ray Ripper v5.0.38 Multilanguag...
# 25           Teorex PhotoStitcher v1.2 MacOSX Incl Keymaker...
# 26                                  UEStudio v13.00.0.1008 编译器
# 27                              Google Chrome v28.0.1496.0 Dev
# 28           FxFactory 4.0.5 build 3806 (MacOSX/2013)影片后期视觉...
# 29                Korg Legacy Collection M1 v1.7.0 WIN 音色软件合成器
# 30           E-on Vue 9.5 xStream 9.50-04 9505072 x86+x64 三...
# ...                                                        ...
# 49971                                 iOS Animation with Swift
# 49972        SEO Course -Start Your Search Engine Optimizat...
# 49973        Meteor js – Marketplace Site + Amazon S3 +Payp...
# 49974        JavaScript Tricks how to create code projects ...
# 49975        The Complete Android Developer Course: Beginne...
# 49976        Digital Forensics Tools in Kali Linux: Imaging...
# 49977        Red Giant Complete Suite 2016 for Adobe & FCP ...
# 49978                                      Graphics 2.1 MacOSX
# 49979          StudioLinkedVST OvO RnB 2 Workstation Win / OSX
# 49980        Future Loops Nebula Progressive Trance Kits WA...
# 49981        SonicCouture Bowed Piano for Ableton Live v9.x...
# 49982        SonicCouture eBow Guitar for Ableton Live v9.x...
# 49983        Chocolate Audio The 88 Series Pianos Steinbach...
# 49984                       StudioLinkedVST Future Pop KONTAKT
# 49985                            OrCAD Library Builder 16.6.62
# 49986                                Esquire UK – May 2016-P2P
# 49987                         Techlife News – 3 April 2016-P2P
# 49988                         New Scientist – 2 April 2016-P2P
# 49989        American Monsters: A History of Monster Lore, ...
# 49990        The 6-Pack Checklist: A Step-by-Step Guide to ...
# 49991                   Extreme How-To Magazine – May 2016-P2P
# 49992                    Geekbench Pro 3.4.1 Build 1047 MacOSX
# 49993                jv16 PowerTools X 4.0.0.1513 Multilingual
# 49994                      AppDelete 4.2.5 Multilingual MacOSX
# 49995                          Serviio Pro 1.6.1 Win/Mac/Linux
# 49996              StudioLinkedVST Vocal Runs Module WiN / OSX
# 49997        Audio Imperia Trailer Guitars Tensions and Mot...
# 49998        Benny Greb – The Language of Drumming: A Syste...
# 49999        Lynda – Outlook 2013: Prepare for the Microsof...
# 50000        Lynda – Excel 2013: Prepare for the Microsoft ...
#
# UploadTime     209
# ArticalName    209
# PageLink       209
# BaiduLink      196
# BaiduPwd       122
# dtype: int64

# %%
data[data['UploadTime'].str.contains('2014-06-06')]
# Out:
#                                         Category  UploadTime  \
# IndexNumber
# 1                  0daytown->Software->Windows->  2014-06-06
# 2                           0daytown->教程->吉他技术->  2014-06-06
# 3                  0daytown->Software->Windows->  2014-06-06
# 4                                 0daytown->教程->  2014-06-06
# 5                    0daytown->教程->Photoshop教程->  2014-06-06
# 6                       0daytown->教程->ZBrush教程->  2014-06-06
# 7            0daytown->Software->Windows->应用软件->  2014-06-06
# 8                  0daytown->Software->CAX/EDA->  2014-06-06
# 9                  0daytown->Software->Windows->  2014-06-06
# 10                 0daytown->Software->CAX/EDA->  2014-06-06
# 11                 0daytown->Software->Windows->  2014-06-06
#
#                                                    ArticalName  \
# IndexNumber
# 1                                              CW Skimmer 1.91
# 2            Lick Library – Stuart Bull’s Electric Blues In...
# 3                                 IBM ILOG CPLEX for AMPL 12.6
# 4                                                      socks 5
# 5            Corel Roxio Creator NXT 2 15.0.5.2 Build 15080...
# 6                                    WinRAR 5.00 beta 2|压缩解压软件
# 7               Bee IT Service Sesame v1.0 and Portable|文件加密程序
# 8            CSI SAP2000 v15.2.1 Ultimate-LAV (2013)|结构通用有限...
# 9                                   Windows 8.1 build 9385 泄露版
# 10           Embarcadero RAD Studio XE4 18.0.4854.59655|终极应...
# 11           Nuke and NukeX 7.0 V6 Stable Version Win64 wit...
#
#                                   PageLink  \
# IndexNumber
# 1             http://www.0daytown.com/?p=1
# 2             http://www.0daytown.com/?p=2
# 3             http://www.0daytown.com/?p=3
# 4             http://www.0daytown.com/?p=4
# 5             http://www.0daytown.com/?p=5
# 6             http://www.0daytown.com/?p=6
# 7             http://www.0daytown.com/?p=7
# 8             http://www.0daytown.com/?p=8
# 9             http://www.0daytown.com/?p=9
# 10           http://www.0daytown.com/?p=10
# 11           http://www.0daytown.com/?p=11
#
#                                                      BaiduLink   BaiduPwd
# IndexNumber
# 1                                                          NaN        NaN
# 2                                                          NaN        NaN
# 3            http://pan.baidu.com/s/1kTfX2Wf;http://pan.bai...        NaN
# 4                                                          NaN        NaN
# 5            http://pan.baidu.com/s/1i3hyiih;http://pan.bai...  ry7l;71ji
# 6                                                          NaN        NaN
# 7                                                          NaN        NaN
# 8                                http://pan.baidu.com/s/1Fwni0        NaN
# 9                                                          NaN        NaN
# 10                                                         NaN        NaN
# 11                                                         NaN        NaN

# %%
# grouped=data.groupby('UploadTime').sum()
grouped=data.groupby('UploadTime',as_index=False).count()
smalldata=data[data['UploadTime'].between('2014-06-06', '2014-06-10')]
smalldata.count()
# smalldata['UploadTime'].plot.hist()
grouped=smalldata.groupby('UploadTime',as_index=False).count()
grouped['ArticalName'].plot(x='UploadTime')

# %%
smalldata
# Out:
#                                         Category  UploadTime  \
# IndexNumber
# 101                               0daytown->教程->  2014-06-08
# 102                0daytown->Software->Android->  2014-06-08
# 103          0daytown->Software->Windows->图形图像->  2014-06-08
# 104                               0daytown->教程->  2014-06-08
# 105                0daytown->Software->Android->  2014-06-08
# 106                0daytown->Software->Windows->  2014-06-08
# 107                               0daytown->教程->  2014-06-08
# 108          0daytown->Software->Windows->媒体处理->  2014-06-08
# 109          0daytown->Software->Windows->媒体处理->  2014-06-08
# 110                               0daytown->教程->  2014-06-08
# 111          0daytown->Software->Windows->媒体处理->  2014-06-08
# 112                0daytown->Software->Windows->  2014-06-08
# 113          0daytown->Software->Windows->图形图像->  2014-06-08
# 114                 0daytown->Software->MacOSX->  2014-06-08
# 115                               0daytown->教程->  2014-06-08
# 116          0daytown->Software->Windows->图形图像->  2014-06-08
# 117                0daytown->Software->Windows->  2014-06-09
# 118          0daytown->Software->Windows->媒体处理->  2014-06-09
# 119                0daytown->Software->Windows->  2014-06-09
# 120                               0daytown->教程->  2014-06-09
# 121                0daytown->Software->Windows->  2014-06-09
# 122                0daytown->Software->CAX/EDA->  2014-06-09
# 123          0daytown->Software->Windows->应用软件->  2014-06-09
# 124          0daytown->Software->Windows->图形图像->  2014-06-09
# 125          0daytown->Software->Windows->媒体处理->  2014-06-09
# 126                0daytown->Software->CAX/EDA->  2014-06-09
# 127                0daytown->Software->CAX/EDA->  2014-06-09
# 128                0daytown->Software->Windows->  2014-06-09
# 129                 0daytown->Software->MacOSX->  2014-06-09
# 130          0daytown->Software->Windows->应用软件->  2014-06-09
# ...                                          ...         ...
# 93           0daytown->Software->Windows->媒体处理->  2014-06-08
# 94           0daytown->Software->Windows->媒体处理->  2014-06-08
# 95                                0daytown->教程->  2014-06-08
# 96                                0daytown->教程->  2014-06-08
# 97                  0daytown->Software->MacOSX->  2014-06-08
# 98           0daytown->Software->Windows->图形图像->  2014-06-08
# 99                          0daytown->Software->  2014-06-08
# 100          0daytown->Software->Windows->媒体处理->  2014-06-08
# 201                            0daytown->Games->  2014-06-10
# 202                            0daytown->Games->  2014-06-10
# 203                            0daytown->Games->  2014-06-10
# 204                            0daytown->Games->  2014-06-10
# 205                            0daytown->Games->  2014-06-10
# 206                               0daytown->教程->  2014-06-10
# 207          0daytown->Software->Windows->应用软件->  2014-06-10
# 208          0daytown->Software->Windows->应用软件->  2014-06-10
# 209                0daytown->Software->Windows->  2014-06-10
# 210          0daytown->Software->Windows->媒体处理->  2014-06-10
# 211                0daytown->Software->Windows->  2014-06-10
# 212          0daytown->Software->Windows->图形图像->  2014-06-10
# 213          0daytown->Software->Windows->图形图像->  2014-06-10
# 214                0daytown->Software->CAX/EDA->  2014-06-10
# 215                 0daytown->Software->MacOSX->  2014-06-10
# 216          0daytown->Software->Windows->应用软件->  2014-06-10
# 217                               0daytown->教程->  2014-06-10
# 218                0daytown->Software->Windows->  2014-06-10
# 219          0daytown->Software->Windows->应用软件->  2014-06-10
# 220                0daytown->Software->Windows->  2014-06-10
# 221          0daytown->Software->Windows->应用软件->  2014-06-10
# 222          0daytown->Software->Windows->图形图像->  2014-06-10
#
#                                                    ArticalName  \
# IndexNumber
# 101                    CoolwareMax WebcamMax v7.7.4.2 网络视频特效软件
# 102                     Mikrosonic RoboVox v1.6.3 Android 语音转换
# 103                     CoolwareMax Face Off Max v3.5.2.2 变脸工具
# 104                Active Undelete Enterprise 8.6.11 数据恢复软件企业版
# 105          Team 17 Digital Limited Worms 2A rmageddon v1....
# 106                                              GEOPoint 3.05
# 107                          FlashFXP 4.3.1 Build 1969 FTP上传下载
# 108                               AnyDVD HD 7.1.9.5 Beta DVD解密
# 109                       JRiver Media Center 18.0.188 播放器多机方案
# 110               Gmail Notifier Pro v5.­0 Multilingual 邮件提醒软件
# 111                    Audials One 10.2.20811.1100 音乐播放下载的综合软件
# 112                     Unity3D Mini Collection 2013 综合型游戏开发工具
# 113                                Face Off Max 3.5.2.2 搞怪图片工具
# 114                        Frogatto v1.3.2 Multilingual MacOSX
# 115              NETGATE Registry Cleaner v5.0.405 多国语言 系统清理专家
# 116                                SecurityCam 1.6.0.0 摄像头监控工具
# 117                              DeskSoft EarthTime 4.2.4 世界时钟
# 118                             Mp3 Audio Editor 8.0.1 MP3编辑软件
# 119              Adobe Reader XI Professional v11.0.3 多国语言含中文版
# 120          WinZip System Utilities Suite 2.0.648.14990 系统...
# 121                        phpDesigner 8.1.2 + Portable PHP编程器
# 122                            Siemens NX V8.5.0 X32/X64 CAX软件
# 123                            Take Command 15.01.44 (x86/x64)
# 124                       ThumbsPlus Pro 9.0 Build 3926 图形编辑管理
# 125                              Virtual DJ Studio 6.4 DJ电脑混音器
# 126                      CATIA V5-6R2012 P2 GA x86/x64 达索CAX软件
# 127                Altair HyperWorks 12.0 x86/x64 最全面的计算机CAE平台
# 128           ATRIS Stahlgruber 1Q.2013 + Technik 12.2.Q3.2012
# 129          PS插件终极收藏包 Adobe Photoshop Plugins Ultimate Col...
# 130                           Desktop iCalendar 2.0.0.273 桌面日历
# ...                                                        ...
# 93                       Extreme Movie Manager v8.0.5.7 影片收藏工具
# 94              DivX Plus Pro v9.1.1 Build 11.0.1.41 视频播放格式转换器
# 95           GlarySoft Glary Utilities PRO v2.55.0.1790 系统清...
# 96                                FlashFXP v4.3.1.1966 FTP上传下载
# 97                          Aperture V3.4.4 Update MACOSX 升级补丁
# 98           DxO Optics Pro Elite Edition v8.1.6.340 Incl P...
# 99                                                   百度云旋风下载速度
# 100                  AVS Video Recorder v2.5.4.84 Cracked 视频编辑
# 201             Airline Tycoon 2 Gold Edition RIP Multi3 航空大亨2
# 202                                        Pinball FX2-SK 三维弹球
# 203                      Aliens Colonial Marines v1.2.0 异形：殖民军
# 204                        I Am Vegend Zombiegeddon v1.0 僵尸终结者
# 205          Love Chronicles Salvation Collectors Edition v...
# 206                 Glary Utilities PRO v2.56.0.1822 系统清理优化工具集
# 207          e-PDF Converter and Creator Printer 2.1 PDF转换Word
# 208                  e-PDF Document Converter 2.1 Office文档转换软件
# 209             Advanced Installer 10.2 Build 51488 MSI安装包制作工具
# 210                               AnyDVD HD 7.2.0.2 Beta DVD解密
# 211          ThePluginSite Elements XXL 1.0.1 for Adobe Pho...
# 212                   HyperTyle 2.0 Retail for Adobe Photoshop
# 213                              KoolMoves 8.5.1 Retail 动画制作软件
# 214                                     ProfiCAD 7.5.2 CAD图形工具
# 215          CoolUtils Total Audio Converter 5.2.73 音频文件格式转换工具
# 216          Universal Extractor 1.7.3 Build 73 Beta Portab...
# 217                 Advanced Registry Clear 2.3.3.8 注册表清理和优化系统
# 218                                         EquiBase Pro 1.7.6
# 219            OPKF Office Product Key Finder 1.2.0.0 检索微软序列密钥
# 220                         Nsasoft SpotAuditor 4.6.2 恢复IE缓存密码
# 221                         FlashBoot 2.2c Portable usb启动盘制作工具
# 222          Digital Film Tools EZ Mask 2.002 (x32/x64) 去除图像背景
#
#                                    PageLink BaiduLink BaiduPwd
# IndexNumber
# 101          http://www.0daytown.com/?p=101       NaN      NaN
# 102          http://www.0daytown.com/?p=102       NaN      NaN
# 103          http://www.0daytown.com/?p=103       NaN      NaN
# 104          http://www.0daytown.com/?p=104       NaN      NaN
# 105          http://www.0daytown.com/?p=105       NaN      NaN
# 106          http://www.0daytown.com/?p=106       NaN      NaN
# 107          http://www.0daytown.com/?p=107       NaN      NaN
# 108          http://www.0daytown.com/?p=108       NaN      NaN
# 109          http://www.0daytown.com/?p=109       NaN      NaN
# 110          http://www.0daytown.com/?p=110       NaN      NaN
# 111          http://www.0daytown.com/?p=111       NaN      NaN
# 112          http://www.0daytown.com/?p=112       NaN      NaN
# 113          http://www.0daytown.com/?p=113       NaN      NaN
# 114          http://www.0daytown.com/?p=114       NaN      NaN
# 115          http://www.0daytown.com/?p=115       NaN      NaN
# 116          http://www.0daytown.com/?p=116       NaN      NaN
# 117          http://www.0daytown.com/?p=117       NaN      NaN
# 118          http://www.0daytown.com/?p=118       NaN      NaN
# 119          http://www.0daytown.com/?p=119       NaN      NaN
# 120          http://www.0daytown.com/?p=120       NaN      NaN
# 121          http://www.0daytown.com/?p=121       NaN      NaN
# 122          http://www.0daytown.com/?p=122       NaN      NaN
# 123          http://www.0daytown.com/?p=123       NaN      NaN
# 124          http://www.0daytown.com/?p=124       NaN      NaN
# 125          http://www.0daytown.com/?p=125       NaN      NaN
# 126          http://www.0daytown.com/?p=126       NaN      NaN
# 127          http://www.0daytown.com/?p=127       NaN      NaN
# 128          http://www.0daytown.com/?p=128       NaN      NaN
# 129          http://www.0daytown.com/?p=129       NaN      NaN
# 130          http://www.0daytown.com/?p=130       NaN      NaN
# ...                                     ...       ...      ...
# 93            http://www.0daytown.com/?p=93       NaN      NaN
# 94            http://www.0daytown.com/?p=94       NaN      NaN
# 95            http://www.0daytown.com/?p=95       NaN      NaN
# 96            http://www.0daytown.com/?p=96       NaN      NaN
# 97            http://www.0daytown.com/?p=97       NaN      NaN
# 98            http://www.0daytown.com/?p=98       NaN      NaN
# 99            http://www.0daytown.com/?p=99       NaN      NaN
# 2016-12-23        52           52        52         42        31
# 2016-12-24        53           53        53         48        28
# 2016-12-25        53           53        53         43        21
# 2016-12-26        53           53        53         45        24
# 2016-12-27        52           52        52         47        20
# 2016-12-28        53           53        53         45        19
# 2016-12-29        53           53        53         46        28
# 2016-12-30        53           53        53         53        27
# 2016-12-31        52           52        52         43        22
# 2017-01-01        53           53        53         51        31
# 2017-01-02        53           53        53         53        30
# 2017-01-03        53           53        53         43        35
# 2017-01-04        52           52        52         43        15
# 2017-01-05        53           53        53         53        33
# 2017-01-06        53           53        53         52        38
# 2017-01-07        53           53        53         44        14
# 2017-01-08        52           52        52         48        33
# 2017-01-09        36           36        36         36        24
#
# [951 rows x 5 columns]

# %%
# dictgrouped=dict(list(grouped))
# dictgrouped

# %%
# grouped.hist(alpha=0.5)
data['UploadTime'].count()

# %%
#每个日期做直方图
data['UploadTime'].hist()

# %%
data.to_csv('c://0daytown_1_50000_organized.csv')

# %%
'''测试为什么有些页面无法连接
找到原因：“提取码”写成了“  提取码 ，导致
'''

import requests
import bs4
import time
from requests.adapters import HTTPAdapter
from bs4 import BeautifulSoup
import datetime

headers1={"User-Agent":"Mozilla/5.0 (Macintosh; Intel Mac OS X 10.13; rv:55.0) Gecko/20100101 Firefox/55.0",
         'Cookie': '__cfduid=d71bfdd08a3066b3a91e22850afd06bff1576705865; PHPSESSID=m42hfkvmhr26d2j6rp9aqs81l6; wordpress_test_cookie=WP+Cookie+check; wordpress_logged_in_d1bdccf8f22a41290379013c104952b6=aaronyinyong%7C1577971950%7Co5ISvGpK8eYBZVUk9PuKzXcgasandHEyNu93pybQ9FK%7C457fb1309b2853366c70b4ad57b418e14fd25873dd2fbbb91a3daa45928f38e2'}
# send_headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/61.0.3163.100 Safari/537.36",    "Connection": "keep-alive",    "Accept": "text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8",    "Accept-Language": "zh-CN,zh;q=0.8"    }


startpagenumber=84676
endpagenumber=84678

Columns1=['Category','UploadTime','ArticalName','PageLink','BaiduLink','BaiduPwd']

wholepd=pd.DataFrame(columns=Columns1)

print(wholepd)
baiduinfolist=[]

iTimeSleepCount=0

pagenumber=startpagenumber

maxtrynumber=0

while pagenumber<=endpagenumber:


    currentPageNumber=pagenumber

    iTimeSleepCount+=1

    #每抓100次休息30秒
    if iTimeSleepCount==100:
        time.sleep(30)
        iTimeSleepCount=0


    #除第一次以后，每抓一次休息2~5秒
    if pagenumber!=startpagenumber:
        time.sleep(0.5)

    urlpage='http://www.0daytown.com/?p=' + str(pagenumber)


    print(urlpage)

    try:
        s = requests.Session()
        s.mount('http://', HTTPAdapter(max_retries=10))

#         r = s.get(urlpage,timeout=10,headers=headers1)
        
        r = s.get(urlpage,timeout=10,headers=headers1)

        soup=BeautifulSoup(r.text,'lxml')
   

        categorynamelist=soup.find(class_='breadcrumbs').find_all('a')
        categoryname=''
        for each in categorynamelist:
            categoryname+=each.text + "->"
        print(categoryname)

        articlename=soup.find(class_='muted')
        articlename=articlename.text
        print(articlename)

        uploadtime=soup.find('time')
        uploadtime=uploadtime.text.strip()
        uploadtime=uploadtime.split('(')[1]
        uploadtime=uploadtime.split(')')[0]
        print(uploadtime)

        tarticle=soup.find(class_="article-content").find_all('p')

        baidulinklist=[]
        baidupwdlist=[]

        for each in tarticle:

            ahreflist=each.find_all('a')
            for each_a in ahreflist:
                if 'pan.baidu.com' in each_a.text:
#                     print(each.find('a').text)
                    baidulinklist.append(each_a.text)

#             print(each.text)
            #找出baidupan密码  如 ' 提取码: ituk</p> 
            if '提取码:' in each.text: 

                tempstr1=each.text.split('提取码:')[1]
                baidupwd=tempstr1.split('</p>')[0].strip()
#                     print(baidupwd)
                baidupwdlist.append(baidupwd)
            elif  '密码:' in each.text: 
                tempstr1=each.text.split('密码:')[1]
                baidupwd=tempstr1.split('</p>')[0].strip()
#                     print(baidupwd)
                baidupwdlist.append(baidupwd)


        #将List转为字符串
        baidulinkstr=';'.join(baidulinklist)
        baidupwdstr=';'.join(baidupwdlist)

        print(baidulinkstr + '   :    ' + baidupwdstr)

        insertRow = pd.DataFrame([[categoryname,uploadtime,articlename,urlpage,baidulinkstr,baidupwdstr]],columns =Columns1)

        wholepd=wholepd.append(insertRow,ignore_index=True)

        pagenumber+=1

    except requests.exceptions.ConnectTimeout:
        print('NETWORK_STATUS = False, please wait 5 seconds')
        time.sleep(10)
        pagenumber=currentPageNumber

    except requests.exceptions.Timeout:
        print('REQUEST_TIMEOUT = TRUE, please wait 8 seconds')
        time.sleep(10)
        pagenumber=currentPageNumber

    except Exception as ex:
        print("#############  Exceptions:" + str(ex))
        print('#############  Unknow error in Page: {}, please wait 10 seconds and retry'.format(str(pagenumber)))
        time.sleep(10)

        maxtrynumber+=1

        if maxtrynumber>10:
            print('*******************尝试超过10次无法连接，放弃该链接, PageNumber:' + str(pagenumber))
            maxtrynumber=0
            pagenumber+=1
        else:
            pagenumber=currentPageNumber


    time_stamp = datetime.datetime.now()
    print("当前时间：" + time_stamp.strftime('%Y.%m.%d-%H:%M:%S'))

downloadfilepathname='c:/0daydown_{0}_{1}.csv'.format(startpagenumber,endpagenumber)

wholepd.to_csv(downloadfilepathname,encoding='UTF-8-sig')
# Out:
# Empty DataFrame
# Columns: [Category, UploadTime, ArticalName, PageLink, BaiduLink, BaiduPwd]
# Index: []
# http://www.0daytown.com/?p=84676
# 0daytown->教程->
# SLR Lounge – Smoke Texture Pack + Tutorials
# 2018-10-29
# https://pan.baidu.com/s/1AjlfDfm4wTsZZg27YtCDvA   :    dfgu
# 当前时间：2019.12.31-10:47:09
# http://www.0daytown.com/?p=84677
# 0daytown->教程->
# Make Your Subjects Levitate
# 2018-10-29
# https://pan.baidu.com/s/19Ss59pNtXZv6vgNg1tg8Xw   :    8g1h
# 当前时间：2019.12.31-10:47:10
# http://www.0daytown.com/?p=84678
# 0daytown->素材->3D模型/3D Models->
# Cubebrush – Blocky Cliff
# 2018-10-29
# https://pan.baidu.com/s/14AmNe0dBA8Mk_tg_E-kd_g   :    jsqb
# 当前时间：2019.12.31-10:47:12
