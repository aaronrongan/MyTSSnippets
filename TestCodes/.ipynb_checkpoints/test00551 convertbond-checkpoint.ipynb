# %% [markdown]
# # 可转债信息
#
# ## 要点
#
# * 找出那些价格在80到110元之间的可转债
#
# * 绘制价格曲线和正股(字段名称：company_code)的对比曲线，找找规律
#
# * 主要字段：
#     id
#     code
#     short_name
#     full_name
#     list_status_id
#     list_status
#     issuer
#     company_code
#     issue_start_date
#     issue_end_date
#
# *

# %%
import pandas as pd
from jqdatasdk import *

print(auth('13651829783','aaronjoinquant'))
# Out:
# None

# %%
print(get_query_count())
# Out:
# {'total': 1000000, 'spare': 983053}

# %%
df=bond.run_query(query(bond.CONBOND_BASIC_INFO)) 
#.filter(bond.CONBOND_BASIC_INFO.code == '128016').limit(10)

# %%
# df[df['list_status']!='终止上市']
df_allinlist=df[df['list_status']!='终止上市']
series_conbond=df_allinlist['code']
# series_conbond
# df_allinlist.count()
df_allinlist.head(5)
# df[df['short_name']=='雨虹转债']
# Out:
#       id    code short_name                    full_name  list_status_id  \
# 4      5  123035       利德转债  2019年利亚德光电股份有限公司公开发行可转换公司债券          301099
# 133  134  113008       电气转债              上海电气公开发行可转换公司债券          301001
# 135  136  110031       航信转债              航天信息公开发行可转换公司债券          301001
# 138  139  132004     15国盛EB     2015年上海国盛(集团)有限公司可交换公司债券          301001
# 139  140  132005     15国资EB     2015年上海国有资产经营有限公司可交换公司债券          301001
#
#     list_status        issuer company_code issue_start_date issue_end_date  \
# 4            其他   利亚德光电股份有限公司  300296.XSHE       2019-11-14     2019-11-14
# 133        正常上市  上海电气集团股份有限公司  601727.XSHG       2015-02-02     2015-02-02
# 135        正常上市    航天信息股份有限公司  600271.XSHG       2015-06-12     2015-06-12
# 138        正常上市  上海国盛(集团)有限公司         None       2015-11-05     2015-11-09
# 139        正常上市  上海国有资产经营有限公司         None       2015-12-08     2015-12-10
#
#      ...  bond_type  bond_form_id  bond_form   list_date  delist_Date  \
# 4    ...        可转债        704001        记账式        None         None
# 133  ...        可转债        704001        记账式  2015-02-16   2021-02-02
# 135  ...        可转债        704001        记账式  2015-06-30   2021-06-12
# 138  ...       可交换债        704001        记账式  2015-11-25   2021-11-05
# 139  ...       可交换债        704001        记账式  2015-12-23   2020-12-08
#
#     interest_begin_date maturity_date interest_date  last_cash_date  \
# 4            2019-11-14    2025-11-14         11-14      2025-11-14
# 133          2015-02-02    2021-02-02    存续期内每年2月2日      2021-02-02
# 135          2015-06-12    2021-06-12   存续期内每年6月12日      2021-06-12
# 138          2015-11-05    2021-11-05   存续期内每年11月5日      2021-11-05
# 139          2015-12-08    2020-12-08   存续期内每年12月8日      2020-12-08
#
#     cash_comment
# 4           None
# 133         None
# 135         None
# 138         None
# 139         None
#
# [5 rows x 44 columns]

# %%
# 可转债日行情，从2018-9-13开始  CONBOND_DAILY_PRICE
df=bond.run_query(query(bond.CONBOND_DAILY_PRICE).filter(bond.CONBOND_DAILY_PRICE.code == '123035').limit(100))

# %%
df
# Out:
# Empty DataFrame
# Columns: [id, date, code, name, exchange_code, pre_close, open, high, low, close, volume, money, deal_number, change_pct]
# Index: []
