# %% [markdown]
# 集思录可转债页面的抓取
#
# 要点：
# *.通过Chrome找到正确的链接
# *.这里是Json格式，不是巨潮信息的html，所以需要解析json
# *.正则,bs4,jsonpath,xpath.的选择  json数据优先选择使用jsonpath. html页面个人比较喜欢使用xpath,若使用xpath较难提取的数据可以使用bs4进行辅助, 若二者都提取不到,这时再去考虑使用正则
# *. 用dict_json = json.loads(html) 转为字典

# %%
import urllib
import urllib.request
from bs4 import BeautifulSoup
import pandas as pd

#coding:utf8

# import urllib2

#json解析库,对应到lxml
import json

#json的解析语法，对应到xpath
# import jsonpath

# %%
#抓取表格的Headers
url='https://www.jisilu.cn/data/cbnew/#cb'
req = urllib.request.Request(url)
req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.2; rv:16.0) Gecko/20100101 Firefox/16.0')

page = urllib.request.urlopen(req)

html = page.read().decode('utf-8')

soup =BeautifulSoup(html, 'lxml')
# soup
# Out:
# <!DOCTYPE html>
# <html><head>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="Chrome=1,IE=edge" http-equiv="X-UA-Compatible"/>
# <title>可转债数据 - 集思录</title>
# <meta content="集思录,低风险理财,债券,公司债,国债,可转债,A类,新股," name="keywords"/>
# <meta content="集思录是一个低风险投资理财问答社区" name="description"/>
# <base href="https://www.jisilu.cn/"/>
# <link href="https://www.jisilu.cn/static/js/tablesorter/themes/blue/style.css?v=20190909" rel="stylesheet" type="text/css"/>
# <link href="https://www.jisilu.cn/static/css/default/bootstrap3/bootstrap.min.css?v=20190909" rel="stylesheet" type="text/css"/>
# <link href="https://www.jisilu.cn/static/css/default/jisilu_framework.css?v=20190909" rel="stylesheet" type="text/css"/>
# <link href="https://www.jisilu.cn/static/css/default/bootstrap3/bootstrap-datepicker3.min.css?v=20190909" rel="stylesheet" type="text/css"/>
# <script type="text/javascript">
# var _A12DD51E6A9FC4004A284D8808759E37='';
# var G_POST_HASH=_A12DD51E6A9FC4004A284D8808759E37;
# var G_INDEX_SCRIPT = '';
# var G_SITE_NAME = '集思录';
# var G_BASE_URL = 'https://www.jisilu.cn';
# var G_STATIC_URL = 'https://www.jisilu.cn/static';
# var G_UPLOAD_URL = 'https://www.jisilu.cn/uploads';
# var G_USER_ID = 0;
# var G_USER_NAME = '';
# var G_UPLOAD_ENABLE = 'N';
# var G_QUICK_PUBLISH_HUMAN_VALID = '';
# var G_UNREAD_NOTIFICATION = 0;
# var G_NOTIFICATION_INTERVAL = 180000;
# var G_CAN_CREATE_TOPIC = '';
# var G_USER_FORBIDDEN = 0;
#
# var _hmt = _hmt || [];
# (function() {
#     var hm = document.createElement("script");
#     hm.src = "//hm.baidu.com/hm.js?164fe01b1433a19b507595a43bf58262";
#     var s = document.getElementsByTagName("script")[0];
#     s.parentNode.insertBefore(hm, s);
# })();
# </script>
# <script src="https://www.jisilu.cn/static/js/jquery-3.4.1.min.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/jquery.form.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/jquery.browser.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/jquery.cookie.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/admin/js/jquery.autocomplete.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/bootstrap3/bootstrap3-typeahead.min.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/bootstrap3/bootstrap.min.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/tablesorter/tablesorter.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/hogan.min.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/jisilu_common.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/jisilu_hogan_template.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/bootstrap3/bootstrap-datepicker.js?v=20190909" type="text/javascript"></script>
# <script src="https://www.jisilu.cn/static/js/bootstrap3/bootstrap-datepicker.zh-CN.min.js?v=20190909" type="text/javascript"></script>
# <script src="/static/js/app/data.js?v=20191125" type="text/javascript"></script>
# <script src="/static/js/simpleTableBuilder.js?v=20191201" type="text/javascript"></script>
# <script type="text/javascript">
# 	UserDefaultSimpleTableConfig = {showIndexCol:false};
# 	UserDefineFundBColumns = {
# 		coupon_descr_s: true,
# 		fundb_unit_capital_rasising_rt:false,
# 	fundb_discount_rt2:false
# 	};
# </script>
# <style type="text/css">
# #flex_pre.tablesorter tbody tr td{
# 	vertical-align: middle;
# }
# .search_cnd_red{
# 	color: red;
# }
# .convert_bond_note{
# 	white-space: pre-wrap;       /* css-3 */
# 	white-space: -moz-pre-wrap;  /* Mozilla, since 1999 */
# 	white-space: -o-pre-wrap;    /* Opera 7 */
# 	word-wrap: break-word;       /* Internet Explorer 5.5+ */
# 	word-break:break-all;
# 	overflow:hidden;
# }
# .data_content {
# 	margin: auto;
# 	padding-bottom: 40px;
# 	padding-left:10px;
# 	padding-right:10px;
# 	max-width: 2000px;
# 	min-width: 1300px;
# }
# @media (min-width: 768px){
# 	#dataModal .modal-dialog {
# 		max-width: 500px;
# 		margin: 200px auto;
# 	}
#
# }
# .data_type_nav {
# 	display: flex;
# 	flex-flow: row nowrap;
# 	border-bottom: 1px solid #f1f1f1;
# 	padding: 10px 0;
# 	width: 100%;
# }
# .data_table_tabs{
# 	padding-top: 10px;
# }
# .data_table_tabs form{
# 	padding: 0 0 10px 0;
# 	margin: 0;
# }
# .data_table_tabs .tip{
# 	font-size: 12px;
# 	line-height: 20px;
# 	padding-bottom: 10px;
# }
# .topic_nav{
# 	width: 600px;
# }
# .topic_nav .nav>li>a {
# 	padding: 2px 20px;
# }
# .topic_nav .nav-pills>li.active>a, .topic_nav .nav-pills>li.active>a:focus, .topic_nav .nav-pills>li.active>a:hover{
# 	background-color: #006798;
# }
# .data_index{
# 	flex-grow: 1;
# 	line-height: 24px;
# }
# .data_index .index_quote_info{
# 	font-size:14px;
# 	width: 800px;
# }
# .jsl_cb_notes{
# 	cursor:pointer; float:right;margin-top:-5px;margin-right:-2px;width:10px;
# }
# #historySearch>span{
#     font-size: 13px;
#     vertical-align: middle;
# }
# #historySearch .input-xs {
# 	height: 24px;
# 	padding: 2px 5px;
# 	font-size: 12px;
# 	line-height: 1.5;
# 	border-radius: 3px;
# }
# #historySearch .btn-xs{
#     padding: 2px 5px;
#     line-height: 18px;
# }
# #historySearch .input-group-btn {
#     line-height: 0;
# }
# #historySearch .input-group input {
# 	border-top-right-radius: 0;
# 	border-bottom-right-radius: 0;
# }
# #convertBondSearchForm {
#
# }
# .datepicker table tr td.disabled, .datepicker table tr td.disabled:hover {
#     color: #FFF;
#     cursor: default;
#     background: 0px 0px;
# }
# </style>
# </head>
# <body>
# <!--[if lt IE 9]>
# <div class="browser_suggest">您的浏览器版本过低，建设使用最新版<a href="https://www.google.cn/chrome/" rel="noopener noreferrer" target="_blank">Chrome</a>或<a href="https://www.firefox.com.cn/" rel="noopener noreferrer" target="_blank">Firefox</a>浏览器。</div>
# <![endif]-->
# <div class="header_navbar_bg">
# <div class="grid header_navbar_content">
# <div class="grid-row">
# <div class="grid-col-3">
# <div class="logo">
# <a href="" target="_blank"><img alt="logo" src="/static/common/common/transparent.gif"/></a>
# </div>
# </div>
# <div class="grid-col-10 menu">
# <ul>
# <li><a href="/">首页</a></li>
# <li id="top_nav_menu_calendar"><a href="/data/calendar/">投资日历</a></li>
# <li class="active" id="top_nav_menu_data"><a href="/data/cbnew/">实时数据</a></li>
# <li><a href="/explore/">社区-知识库</a></li>
# <li><a href="/tyb/">投研帮</a></li>
# </ul>
# </div>
# <div class="grid-col-5">
# </div>
# <div class="grid-col-6">
# <div class="not_logged_in">
# <div aria-label="..." class="btn-group btn-group-sm" role="group">
# <a class="btn btn-default" href="/account/login/" role="button">登录</a>
# <a class="btn btn-default" href="/account/register/" role="button">注册</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <script type="application/javascript">
#
#     var document_title = '';
#
#     function check_notifications() {
#
#         if (G_USER_ID == 0) return false;
#
#         $.get(G_BASE_URL + '/home/ajax/notifications/', function (result) {
#             var unread = Number(result.rsm.inbox_num);
#
#             if(unread>0) $('#inbox_unread').text(unread>99?'...':unread).show();
#             else $('#inbox_unread').hide();
#
#             var last_unread_notification = G_UNREAD_NOTIFICATION;
#             G_UNREAD_NOTIFICATION = Number(result.rsm.notifications_num);
#             if (G_UNREAD_NOTIFICATION > 0)
#             {
#                 if (G_UNREAD_NOTIFICATION != last_unread_notification) $('#notifications_unread').html(G_UNREAD_NOTIFICATION>99?'...':G_UNREAD_NOTIFICATION);$('#notifications_unread').attr('data-unread',G_UNREAD_NOTIFICATION);
#                 $('#notifications_unread').show();
#             }else{
#                 if ($('.notification_popover .popover-content').length > 0) $('.notification_popover .popover-content').html('没有未读通知');
#                 $('#notifications_unread').hide();
#             }
#
#             if (((Number(result.rsm.notifications_num) + Number(result.rsm.inbox_num))) > 0)
#             {
#                 document.title = '(' + (Number(result.rsm.notifications_num) + Number(result.rsm.inbox_num)) + ') ' + document_title;
#             }
#         }, 'json');
#
#     }
#
#     function read_notification(id){
#         if (id) {
#             $('#notification_'+id).remove();
#         }
#         if ($("#notifications_unread").length > 0)
#         {
#             G_UNREAD_NOTIFICATION = Number($('#notifications_unread').attr('data-unread'))-1;
#             $("#notifications_unread").html(G_UNREAD_NOTIFICATION>99?'...':G_UNREAD_NOTIFICATION);
#         }
#         $.get(G_BASE_URL + '/notifications/ajax/read_notification/notification_id-' + id + '__read_type-1', function (respose)
#         {
#             check_notifications();
#         });
#     }
#
#     function formatDateTime(ns) {
#         return new Date(parseInt(ns) * 1000).format('yyyy-MM-dd h:m');
#     }
#
#     function searchInputInit(){
#         $('#search_input').data('active',{row:0,topicCol:0});
#     }
#     function searchInputUnactive() {
#         var active = $('#search_input').data('active');
#         var rowsList = $('.search_item');
#         if(rowsList.length && active) {
#             rowsList.eq(active.row).removeClass('active');
#
#             var topSearchItem = $('.topic>.search_item');
#             var colsList = $('.topic>.search_item>a');
#             if (topSearchItem.length) colsList.eq(active.topicCol).removeClass('active');
#         }
#     }
#     function searchInputActive(){
#         var active = $('#search_input').data('active');
#         if(active.row < 0) return;
#         var rowsList = $('.search_item');
#         if(rowsList.length) {
#             rowsList.eq(active.row).addClass('active');
#
#             var topSearchItem = $('.topic>.search_item.active');
#             var colsList = $('.topic>.search_item>a');
#             if (topSearchItem.length) colsList.eq(active.topicCol).addClass('active');
#         }
#     }
#     function searchInputEnter(){
#         var active = $('#search_input').data('active');
#         console.log(active);
#         if(active.row < 0){
#             $('#global_search_form').submit();//未选中条目跳转搜索页
#         }else {
#             var rowsList = $('.search_item');
#             if(rowsList.length) {
#                 var topSearchItem = $('.topic>.search_item.active');
#                 var colsList = $('.topic>.search_item>a');
#                 if (topSearchItem.length) {
#                     colsList.eq(active.topicCol)[0].click();
#                 }else{
#                     $('a',rowsList.eq(active.row))[0].click();
#                 }
#             }
#         }
#     }
#     function searchInputTopicIndex(){
#         var index = -1;
#         var rowsList = $('.search_item');
#         for(var i=0; i< $('.search_item').length;i++){
#             if(rowsList.eq(i).parent().hasClass('topic')){
#                 index = i;break;
#             }
#         }
#         return index;
#     }
#
#     function generateDataHtml(data){
#         var html = new Array();
#         var keyword = $('#search_input').val();
#         if(data && data.type==9 && data.data.length>0){
#             html.push('<div class="search_type data">');
#             html.push('<div class="title">数据</div><div class="more"><a href="javascript:void(0)" onclick="$(\'#search_type\').val(\'data\');$(\'#global_search_form\').submit()">更多数据&gt;&gt;</a></div>');
#             for(var i=0;i<data.data.length;i++) {
#                 html.push('<div class="search_item"><a href="'+data.data[i].uri+'"><div class="search_text">'+data.data[i].sname+' ('+ data.data[i].market.toUpperCase() + data.data[i].sid +')</div><div class="search_info">'+data.data[i].tname+'</div></a></div>');
#             }
#             html.push('</div>');
#         }
#         return html.join('');
#     }
#     function generateTopicHtml(data){
#         var html = new Array();
#         var keyword = $('#search_input').val();
#         if(data && data.type==2 && data.data.length>0){
#             html.push('<div class="search_type topic">');
#             html.push('<div class="title">标签</div><div class="more"><a href="javascript:void(0)" onclick="$(\'#search_type\').val(\'topics\');$(\'#global_search_form\').submit()">更多标签&gt;&gt;</a></div><div class="search_item">');
#             for(var i=0;i<data.data.length;i++) {
#                 html.push('<a href="'+data.data[i].url+'">'+data.data[i].name+'</a>');
#             }
#             html.push('</div></div>');
#         }
#         return html.join('');
#     }
#     function generateUserHtml(data){
#         var html = new Array();
#         var keyword = $('#search_input').val();
#         if(data && data.type==3 && data.data.length>0){
#             html.push('<div class="search_type user">');
#             html.push('<div class="title">用户</div><div class="more"><a href="javascript:void(0)" onclick="$(\'#search_type\').val(\'users\');$(\'#global_search_form\').submit()">更多用户&gt;&gt;</a></div>');
#             for(var i=0;i<data.data.length;i++) {
#                 html.push('<div class="search_item"><a href="'+data.data[i].url+'"><div class="search_info"><img src="'+data.data[i].detail.avatar_file+'" /></div><div class="search_text">'+data.data[i].name+'</div></a></div>');
#             }
#             html.push('</div>');
#         }
#         return html.join('');
#     }
#     function generateQuestionHtml(data){
#         var html = new Array();
#         var keyword = $('#search_input').val();
#         if(data && data.type==1 && data.data.length>0){
#             html.push('<div class="search_type question">');
#             html.push('<div class="title">问题</div><div class="more"><a href="javascript:void(0)" onclick="$(\'#search_type\').val(\'questions\');$(\'#global_search_form\').submit()">更多问题&gt;&gt;</a></div>');
#             for(var i=0;i<data.data.length;i++) {
#                 html.push('<div class="search_item"><a href="'+data.data[i].url+'"><div class="search_text">'+data.data[i].name+'</div><div class="search_info">'+data.data[i].detail.meta_percent+'%匹配</div></a></div>');
#             }
#             html.push('</div>');
#         }
#         return html.join('');
#     }
#     function generateAnswerHtml(data){
#         var html = new Array();
#         var keyword = $('#search_input').val();
#         if(data && data.type==4 && data.data.length>0){
#             html.push('<div class="search_type answer">');
#             html.push('<div class="title">回复</div><div class="more"><a href="javascript:void(0)" onclick="$(\'#search_type\').val(\'answers\');$(\'#global_search_form\').submit()">更多回复&gt;&gt;</a></div>');
#             for(var i=0;i<data.data.length;i++) {
#                 html.push('<div class="search_item"><a href="'+data.data[i].url+'"><div class="search_text">'+data.data[i].name+'</div><div class="search_info">'+data.data[i].detail.meta_percent+'%匹配</div></a></div>');
#             }
#             html.push('</div>');
#         }
#         return html.join('');
#     }
#
#     $(document).ready(function() {
#
#         document_title = document.title;
#
#         if (typeof (G_NOTIFICATION_INTERVAL) != 'undefined')
#         {
#             check_notifications();
#             setInterval('check_notifications()', G_NOTIFICATION_INTERVAL);
#         }
#
#         var debug_user = false;
#         $('#user_menu').popover({placement:"bottom auto",
#             trigger:"manual",
#             content:" ",
#             html:true,
#             template:'<div class="user_menu_popover popover" role="tooltip"><div class="popover-content"></div></div>'
#         }).on("mouseenter", function (){
#             var _this = this;
#             if(!$(this).parent().find('div.popover').length || $(this).parent().find('div.popover').is(':hidden')) $(this).popover("show");
#             $(".popover", $(this).parent()).on("mouseleave", function () {
#                 setTimeout(function () {if(!$(":hover",_this).length && !debug_user) $(_this).popover("hide");},300);
#             });
#         }).on("mouseleave", function () {
#             var _this = this;
#             setTimeout(function () {if (!$(_this).parent().find(".popover:hover").length && !debug_user) $(_this).popover("hide");}, 300);
#         }).on('shown.bs.popover', function () {
#             var _this = this;
#             var box = $(this).parent().find('div.popover');
#             var menu = $(this).parent().find('ul').clone();
#
#             $('.popover-content',box).html(menu);
#             menu.show();
#         });
#
#
#
#         $('#notification_btn').popover({
#             placement:"bottom auto",
#             trigger:"manual",
#             content:"没有未读通知",
#             html:true,
#             template:'<div class="notification_popover popover" role="tooltip"><div class="arrow"></div><div class="popover-content"></div></div>'
#         })
#         .on("mouseenter", function () {
#             var _this = this;
#             if(!$(this).parent().find('div.popover').length || $(this).parent().find('div.popover').is(':hidden')) $(this).popover("show");
#             $(".popover", $(this).parent()).on("mouseleave", function () {
#                 setTimeout(function () {if(!$(":hover",_this).length) $(_this).popover("hide");},300);
#             });
#         })
#         .on("mouseleave", function () {
#             var _this = this;
#             setTimeout(function () {if (!$(_this).parent().find(".popover:hover").length) $(_this).popover("hide");}, 300);
#         })
#         .on('shown.bs.popover', function () {
#             var _this = this;
#             var box = $(this).parent().find('div.popover');
#             var notifications_unread = Number($('#notifications_unread').text());
#             if(notifications_unread<=0) return;
#             $.ajax({
#                 type: "GET",
#                 url: G_BASE_URL + '/notifications/ajax/last/flag-0__limit-5',
#                 success: function (data, textStatus) {
#                     var html = new Array();
#                     for(var i=0; i<data.rsm.list.length;i++) {
#                         //data.rsm.list[i].extend_message = 'extend_message';
#                         var item = new Array();
#                         item.push('<div id="notification_'+data.rsm.list[i].notification_id+'">');
#                         item.push('<div class="message">'+data.rsm.list[i].message+'<a class="close" href="javascript:read_notification('+data.rsm.list[i].notification_id+')">×</a></div>');
#                         item.push('<div class="addtime">'+formatDateTime(data.rsm.list[i].add_time)+(data.rsm.list[i].extend_message?'<a class="extend" href="javascript:void(0)" onclick="$(\'#notification_'+data.rsm.list[i].notification_id+'\').find(\'.extend_message\').fadeIn();$(this).hide();">+</a>':'')+'</div>');
#                         if(data.rsm.list[i].extend_message)item.push('<div class="extend_message" style="display: none">'+data.rsm.list[i].extend_message+'</div>');
#                         item.push('</div>');
#                         html.push(item.join(''));
#
#                     }
#                     $('.popover-content',box).html(html.join(''));
#                 },
#                 error: function (jqXHR, textStatus, errorThrown) {
#                     alert(textStatus + "\n" + jqXHR.responseText);
#                 }
#             });
#
#         });
#
#         $('#search_input').popover({
#             placement:"bottom",
#             content:"<div class=\"no_content\">没有搜索到内容</div>",
#             trigger:"manual",
#             html:true,
#             template:'<div class="popover" role="tooltip"><div class="arrow"></div><div class="popover-content"></div></div>'
#         }).on('shown.bs.popover', function () {
#
#             var box = $(this).parent().find('div.popover');
#             var inputValue = $(this).val();
#             //console.log(inputValue);
#             if(inputValue.length < 2) {
#                 $('.popover-content',box).html('<div class="no_content">没有搜索到内容</div>');
#                 return;
#             }
#
#             $.get(G_BASE_URL + '/search/ajax/searchtype/?q='+inputValue, function (data) {
#                 if(data && data.length>0){
#                     var htmlArray = new Array(),htmlType9 = '',htmlType2 = '',htmlType3 = '',htmlType1 = '',htmlType4 = '';
#                     for(var i=0; i<data.length; i++){
#                         //1:questions 2:topics 3:users 4:answers 9:data
#                         if(data[i].type == 9) htmlType9 = generateDataHtml(data[i]);
#                         if(data[i].type == 2) htmlType2 = generateTopicHtml(data[i]);
#                         if(data[i].type == 3) htmlType3 = generateUserHtml(data[i]);
#                         if(data[i].type == 1) htmlType1 = generateQuestionHtml(data[i]);
#                         if(data[i].type == 4) htmlType4 = generateAnswerHtml(data[i]);
#                     }
#                     htmlArray.push(htmlType9);
#                     htmlArray.push(htmlType2);
#                     htmlArray.push(htmlType3);
#                     htmlArray.push(htmlType1);
#                     htmlArray.push(htmlType4);
#
#                     var htmlDom = $(htmlArray.join(''));
#
#                     var itemList = $('.search_item .search_text',htmlDom);
#
#                     for(var i = 0; i < itemList.length; i++){
#                         itemList.eq(i).html(itemList.eq(i).html().replace(inputValue,'<span class="match">'+inputValue+'</span>'));
#                     }
#                     var topicList = $('.topic>.search_item>a',htmlDom);
#                     for(var i = 0; i < topicList.length; i++){
#                         topicList.eq(i).html(topicList.eq(i).html().replace(inputValue,'<span class="match">'+inputValue+'</span>'));
#                     }
#                     $('.popover-content',box).html(htmlDom);
#                     searchInputInit();
#                     searchInputActive();
#                 }else{
#                     $('.popover-content',box).html('<div class="no_content">没有搜索到内容</div>');
#                 }
#             });
#         });
#         //$('#search_input').popover('show');
#
#         $('#search_input').on('input propertychange',function(event){
#             var _this = this;
#             var inputValue = $(this).val();
#             if (window.event && event.type == 'propertychange' && event.propertyName != 'value') return;
#
#             window.clearTimeout($(this).data('timeout'));
#             $(this).data('timeout', setTimeout(function () {
#                 if(inputValue.length > 0){
#                     $(_this).popover('show');
#                     //console.log('值改变了~输入值：' + inputValue);
#                 }else{
#                     $(_this).popover('hide');
#                 }
#             }, 500));
#         }).on('keydown',function(event){
#             if($.inArray(event.keyCode,[27,13,38,40,37,39]) === -1) return;
#             var rowsList = $('.search_item');
#             if(rowsList.length <=0) return;
#             var colsList = $('.topic>.search_item>a');
#             var topicIndex = searchInputTopicIndex();
#             var active =$(this).data('active');
#             searchInputUnactive();
#             switch (event.keyCode) {
#                 case 27://esc
#                     $(this).val('');
#                     searchInputInit();
#                     $(this).popover('hide');
#                     break;
#                 case 13://enter
#                     searchInputEnter();
#                     break;
#                 case 38://top
#                     active.row -= 1;
#                     if(active.row < 0) active.row = rowsList.length - 1;
#                     break;
#                 case 40://down
#                     active.row += 1;
#                     if(active.row >= rowsList.length) active.row = 0;
#                     break;
#                 case 37://left
#                     if(topicIndex==active.row && colsList.length > 0){
#                         active.topicCol -= 1;
#                         if(active.topicCol < 0) active.topicCol = colsList.length - 1;
#                         event.stopPropagation();
#                         event.preventDefault();
#                     }
#                     break;
#                 case 39://right
#                     if(topicIndex==active.row && colsList.length > 0){
#                         active.topicCol += 1;
#                         if(active.topicCol >= colsList.length) active.topicCol = 0;
#                         event.stopPropagation();
#                         event.preventDefault();
#                     }
#                     break;
#             }
#             searchInputActive();
#         }).on('blur',function (event) {
#             $(this).popover('hide');
#         });
#
#
#     });
#
# </script><div class="header_subnavbar_bg">
# <div class="grid header_subnavbar_content">
# <div class="grid-row">
# <div class="grid-col-3">
# <div class="subnavbar_left">
# <!--a href="/data/mine/" >自选</a-->
# <a class="beta" href="/data/p/">持仓</a>
# </div>
# </div>
# <div class="grid-col-21">
# <div class="subnavbar_right">
# <div>
# <a href="/data/new_stock/">新股</a>
# <a href="/data/stock/dividend_rate/">门票股</a>
# <a href="/data/taoligu/">套利股</a>
# <a href="/data/bond/">债券</a>
# <a class="on" href="/data/cbnew/">可转债</a>
# <a href="/data/sfnew/">分级基金</a>
# <a href="/data/cf/">封闭基金</a>
# <a href="/data/etf/">ETF</a>
# <a href="/data/lof/">LOF</a>
# </div>
# <div>
# <a href="/data/repo/">现金管理</a>
# <a href="/data/ha/">A/H比价</a>
# <a href="/data/qdii/">T+0 QDII</a>
# <a href="/data/uscef/">美股封基</a>
# <a href="/data/hkreits/">REITs</a>
# <a href="/data/idx_performance/">指数涨幅</a>
# <a href="/data/option/">期权</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="grid data_content">
# <div class="grid-row data_type_nav">
# <div class="topic_nav">
# <ul class="nav nav-pills" id="topic">
# <li role="presentation"><a alias="tlink_3" fname="showConvertBond" href="javascript:;" id="tlink_cb" tname="cb">可转债</a></li>
# <li role="presentation"><a alias="tlink_5" fname="showForceRedeem" href="javascript:;" id="tlink_redeem" tname="redeem">强赎</a></li>
# <li role="presentation"><a alias="tlink_2" fname="showHuishou" href="javascript:;" id="tlink_put" tname="put">回售</a></li>
# <li role="presentation"><a href="/data/cbnew/scatter/" style="color:red;" tname="scatter">藏宝图</a></li>
# <li role="presentation"><a alias="tlink_6" fname="showPreCB" href="javascript:;" id="tlink_pre" tname="pre">待发转债</a></li>
# <li role="presentation"><a alias="tlink_7" fname="showDelistedCB" href="javascript:;" id="tlink_delisted" tname="delisted">已退市转债</a></li>
# <li role="presentation"><a alias="tlink_0" fname="showConvertBondOwned" href="javascript:;" id="tlink_owned" tname="owned">自选</a></li>
# </ul>
# </div>
# <div class="data_index">
# <span class="index_quote_info"></span>
# </div>
# </div>
# <div class="grid-row data_table_tabs">
# <div id="topic_cb" style="display:none">
# <form class="form-inline" id="convertBondSearchForm" onsubmit="searchConvertBond();return false;">
#
# 		转债价格区间 <input class="form-control input-xs" name="fprice" style="width:55px;" value=""/>
# 			到 <input class="form-control input-xs" name="tprice" style="width:55px;" value=""/>元
# 		转债成交额 <input class="form-control input-xs" name="volume" style="width:55px;" value=""/>万元
# 		正股成交额 <input class="form-control input-xs" name="svolume" style="width:55px;" value=""/>万元
# 		溢价率≤ <input class="form-control input-xs" name="premium_rt" style="width:45px;" value=""/>%
# 		到期收益率≥ <input class="form-control input-xs" name="ytm_rt" style="width:45px;" value=""/>%
# 		评级 <select class="form-control input-xs" name="rating_cd" onchange="searchConvertBond()" style="width: 100px">
# <option value="">全部</option>
# <option value="AAA">AAA</option>
# <option value="AA+">AA+</option>
# <option value="AA">AA</option>
# <option value="AA-">AA-</option>
# <option value="A+">A+</option>
# </select>
# <button class="btn btn-primary btn-xs" type="submit">筛选</button>
# <button class="btn btn-default btn-xs" onclick="resetConvertBondSearch()" type="button">重置</button>
# </form>
# <div>
# <div class="tip pull-left" id="searchConvertBondTip">
# 								注：默认显示所有转债，如需按成交额筛选请使用筛选条件。
# 							</div>
# <div class="pull-right form-inline" id="historySearch">
# </div>
# </div>
# <table class="tablesorter" id="flex_cb" style="display:none;min-width:1300px;"></table>
# </div>
# <div id="topic_redeem" style="display:none">
# <table class="tablesorter" id="flex_redeem" style="display:none;min-width:1300px;"></table>
# </div>
# <div id="topic_put" style="display:none">
# <table class="tablesorter" id="flex_put" style="display:none;min-width:1300px;"></table>
# </div>
# <div id="topic_other" style="display:none;">
# <table class="tablesorter" id="flex_other" style="display:none;min-width:1300px;"></table>
# </div>
# <div id="topic_pre" style="display:none">
# <form class="form-inline" id="preSearchForm">
#
# 			类型: <label><input name="cb_type_Y" onclick="showPreCB();" type="checkbox" value="Y"/> 可转债</label>
# <label><input name="cb_type_N" onclick="showPreCB();" type="checkbox" value="N"/> 可交换债</label>
# <span style="margin-left: 200px;"></span>方案进展:
# 			<select class="form-control input-xs" name="progress" onchange="showPreCB()">
# <option value="">全部</option>
# <option value="90">证监会核准批文</option>
# <option value="80">证监会发审通过</option>
# <option value="20">股东大会通过</option>
# <option value="10">董事会预案</option>
# </select>
# <a href="/data/cbnew/pre/" style="margin-left: 300px;" target="_blank">待发转债历史</a>
# </form>
# <table class="tablesorter" id="flex_pre" style="display:none;min-width:1300px;"></table>
# <div class="tip">注：转股价灰色斜体部分为20日均价，请谨慎参考。</div>
# </div>
# <div id="topic_delisted" style="display:none;">
# <table class="tablesorter" id="flex_delisted" style="display:none;width:1200px;"></table>
# </div>
# <div id="topic_owned" style="display:none;">
# <table class="tablesorter" id="flex_owned" style="display:none;min-width:1300px;"></table>
# <div class="ui-widget">
# <form onsubmit="onSubmitAddOwnedConvertBond(); return false;">
# <label>请输入可转债代码</label>
# <input id="owned_convertbond_id" maxlength="20" name="owned_convertbond_id" size="20" type="text"/>
# <input type="submit" value="添加自选"/>
# </form>
# </div>
# </div>
# </div>
# <div style="display:none;">
# <div id="tableConvertBondTitle">
# 可转债(<a href="javascript:reloadConvertBondSearch();">手动刷新</a>   <input id="auto_reload" type="checkbox"/>30秒自动刷新)
# 行业<select id="cb_industry" onchange="reloadConvertBondSearch()" style="width: 120px; height: 24px; font-size: 12px; ">
# <option selected="" value="">【全部】</option>
# <option value="A">A    农、林、牧、渔业</option>
# <option value="A,01">  农业(1)</option>
# <option value="B">B    采矿业</option>
# <option value="B,07">  石油和天然气开采业(2)</option>
# <option value="B,09">  有色金属矿采选业(1)</option>
# <option value="C">C    制造业</option>
# <option value="C,13">  农副食品加工业(4)</option>
# <option value="C,14">  食品制造业(3)</option>
# <option value="C,15">  酒、饮料和精制茶制造业(1)</option>
# <option value="C,17">  纺织业(1)</option>
# <option value="C,18">  纺织服装、服饰业(2)</option>
# <option value="C,19">  皮革、毛皮、羽毛及其制品和制鞋业(1)</option>
# <option value="C,20">  木材加工及木、竹、藤、棕、草制品业(1)</option>
# <option value="C,21">  家具制造业(5)</option>
# <option value="C,22">  造纸及纸制品业(6)</option>
# <option value="C,25">  石油加工、炼焦及核燃料加工业(1)</option>
# <option value="C,26">  化学原料及化学制品制造业(16)</option>
# <option value="C,27">  医药制造业(11)</option>
# <option value="C,28">  化学纤维制造业(2)</option>
# <option value="C,29">  橡胶和塑料制品业(6)</option>
# <option value="C,30">  非金属矿物制品业(8)</option>
# <option value="C,31">  黑色金属冶炼及压延加工业(3)</option>
# <option value="C,32">  有色金属冶炼及压延加工业(8)</option>
# <option value="C,33">  金属制品业(8)</option>
# <option value="C,34">  通用设备制造业(6)</option>
# <option value="C,35">  专用设备制造业(5)</option>
# <option value="C,36">  汽车制造业(9)</option>
# <option value="C,37">  铁路、船舶、航空航天和其它运输设备制造业(2)</option>
# <option value="C,38">  电气机械及器材制造业(16)</option>
# <option value="C,39">  计算机、通信和其他电子设备制造业(19)</option>
# <option value="C,40">  仪器仪表制造业(4)</option>
# <option value="C,41">  其他制造业(1)</option>
# <option value="D">D    电力、热力、燃气及水的生产和供应业</option>
# <option value="D,44">  电力、热力生产和供应业(6)</option>
# <option value="D,46">  水的生产和供应业(1)</option>
# <option value="E">E    建筑业</option>
# <option value="E,48">  土木工程建筑业(5)</option>
# <option value="E,50">  建筑装饰和其他建筑业(3)</option>
# <option value="F">F    批发和零售业</option>
# <option value="F,51">  批发业(3)</option>
# <option value="F,52">  零售业(3)</option>
# <option value="G">G    交通运输、仓储和邮政业</option>
# <option value="G,54">  道路运输业(2)</option>
# <option value="G,56">  航空运输业(1)</option>
# <option value="G,58">  装卸搬运和其他运输代理业(1)</option>
# <option value="G,60">  邮政业(2)</option>
# <option value="I">I    信息传输、软件和信息技术服务业</option>
# <option value="I,63">  电信、广播电视和卫星传输服务(3)</option>
# <option value="I,64">  互联网和相关服务(4)</option>
# <option value="I,65">  软件和信息技术服务业(8)</option>
# <option value="J">J    金融业</option>
# <option value="J,66">  货币金融服务(8)</option>
# <option value="J,67">  资本市场服务(4)</option>
# <option value="J,68">  保险业(1)</option>
# <option value="L">L    租赁和商务服务业</option>
# <option value="L,72">  商务服务业(3)</option>
# <option value="N">N    水利、环境和公共设施管理业</option>
# <option value="N,77">  生态保护和环境治理业(9)</option>
# <option value="R">R    文化、体育和娱乐业</option>
# <option value="R,85">  新闻和出版业(3)</option>
# <option value="R,86">  广播、电视、电影和影视录音制作业(1)</option>
# </select>
# <label style="display: inline-block; margin-left: 40px;"><input checked="" id="ctype" onclick="reloadConvertBondSearch();" type="checkbox"/>可转债</label>
# <label style="display: inline-block; margin-left: 10px;"><input checked="" id="etype" onclick="reloadConvertBondSearch();" type="checkbox"/>可交换债</label>
# <label style="display: inline-block; margin-left: 20px;"><input checked="" id="listed" onclick="reloadConvertBondSearch();" type="checkbox"/>仅看已上市</label>
# <label style="display: inline-block; margin-left: 20px;"><input id="qflag" onclick="reloadConvertBondSearch();" type="checkbox"/>合格机构投资者可买</label>
# <label style="display: inline-block; margin-left: 20px;"><input id="owned" onclick="reloadConvertBondSearch();" type="checkbox"/>仅看自选</label>
# <span id="convertBondCount" style="float: right;"></span>
# </div>
# <div id="tableConvertBondOwnedTitle">
# 自选可转债(<a href="javascript:tableConvertBondOwned.reload();">刷新</a>)
# <label style="display:inline" title="打开或关闭分享转债自选到我的动态"><input checked="checked" id="convertbond_owned_notify2" onclick="changeOwnedNotifyStatus('#convertbond_owned_notify2', '转债', 'convertbond_owned_notify_fl')" type="checkbox"/>分享到我的动态</label>
# </div>
# </div>
# </div>
# <script type="text/javascript">
# var owned_user_id = "";
# var user_id = owned_user_id;
#
# function optionValueFormatter(nameVal, row){
# 	var option_value = row.option_value;
# 	if(row.adjust_tip){
# 		option_value = option_value + '<sup>*</sup>';
# 	}
# 	return option_value;
# }
#
# function redeemValueStyler(nameVal, row){
#     if('N' == row.redeem_style){
#         return ';color:#aaa;font-style:italic;';
#     }
# }
#
# function optionValueStyler(nameVal, row){
#     if(row.redeem_dt && row.real_force_redeem_price){
#         return ';color:#aaa;font-style:italic;';
#     }
#     if('N' == row.convert_price_valid){
#         return ';color:#aaaaaa;font-style:italic';
#     }
# }
#
# function theoryValueStyler(nameVal, row){
#     if('N' == row.convert_price_valid){
#         return ';color:#aaaaaa;font-style:italic';
#     }
# }
#
# function redeemStyler(nameVal, row){
# 	if(row.redeem_dt && row.real_force_redeem_price){
# 		return ';color:#aaa;font-style:italic;';
# 	}
# }
#
# function putStyler(nameVal, row){
# 	if(row.put_dt && row.put_notes){
# 		return '';
# 	}
# 	if(row.after_next_put_dt){
# 		if(row.put_convert_price && row.sprice && parseFloat(row.put_convert_price) > parseFloat(row.sprice)){
# 			return '';
# 		}
# 	}
# 	return ';color:#aaa;font-style:italic;';
# }
#
# function buyOptionValueFormatter(nameVal, row){
# 	return '<a target="_blank" title="收费数据，点击购买转债增强数据" href="/question/95518">购买</a>';
# }
#
# function convertBondPriceStyler(nameVal, row){
# 	if(row.last_time == null || row.last_time == 'null'){
# 		return ';color:#aaaaaa;font-style:italic';
# 	}
# }
#
# function premiumRtStyler(nameVal, row){
# 	if('未到转股期' == row.convert_cd){
# 		return ';color:#aaaaaa;font-style:italic';
# 	}
#     if('N' == row.convert_price_valid){
#         return ';color:#aaaaaa;font-style:italic';
#     }
# }
#
# function cbFundRtFormatter(nameVal, row){
# 	if('buy' == row.fund_rt){
# 		return '<a href="/setting/member/" title="会员数据，点击购买会员" target="_blank">会员</a>';
# 	}else if('-' != row.fund_rt){
# 		return row.fund_rt + '%';
# 	}else{
# 		return row.fund_rt;
# 	}
# }
#
# function convertPriceFormatter(nameVal, row){
# 	if(row.adj_cnt > 0){
#         var cnt = parseInt(row.adj_scnt);
#         var starts = '<span style="color:red;">';
#         for(var i=0; i<cnt; i++){
#             starts += '*';
#         }
#         starts += '</span>';
#         var title = '转股价下修' + row.adj_cnt + '次，成功下修' + row.adj_scnt + '次，点击查看详情';
#         var style = '';
#         if('N' == row.convert_price_valid){
#             style = 'style="color:#ccc;font-style:italic;"';
#             if(row['convert_price_valid_from']){
#                 title += "\n" + '转股价 '+row.convert_price+' 生效日期 '+row['convert_price_valid_from'];
#             }
#         }
#         return '<a '+style+' title="'+title+'" class="adj_cnt_tips"  bond_nm="' + row.bond_nm + '" bond_id="' + row.bond_id + '">' + row.convert_price + starts + '</a>';
# 	}else{
# 		return row.convert_price;
# 	}
# }
#
# function convertPriceStyler(nameVal, row){
#     if('N' == row.convert_price_valid){
#         return ';color:#aaaaaa;font-style:italic';
#     }
# }
#
# function bindAdjCntTip(data){
# 	if('Y' == is_cb_search){
# 		if(!$('.search_cnd').hasClass('search_cnd_red')){
# 			$('.search_cnd').addClass('search_cnd_red');
# 		}
# 	}else{
# 		if($('.search_cnd').hasClass('search_cnd_red')){
# 			$('.search_cnd').removeClass('search_cnd_red');
# 		}
# 	}
#     var total_orig_iss_amt = 0;
#     var total_curr_iss_amt = 0;
#     $(data['rows']).each(function(idx, row) {
#         var orig_iss_amt = 0;
#         if(!isNaN(parseFloat(row['cell']['orig_iss_amt']))){
#             orig_iss_amt = parseFloat(row['cell']['orig_iss_amt']);
#         }
#         var curr_iss_amt = orig_iss_amt;
#         if(row['cell']['curr_iss_amt'] && !isNaN(parseFloat(row['cell']['curr_iss_amt']))){
#             curr_iss_amt = parseFloat(row['cell']['curr_iss_amt']);
#         }
#         total_orig_iss_amt += orig_iss_amt;
#         total_curr_iss_amt += curr_iss_amt;
#     });
#
# 	var rowCount = data['rows'].length;
# 	$('#convertBondCount').text('数量:' + rowCount + '个；规模:' + total_orig_iss_amt.toFixed(2) + '亿；存量:' + total_curr_iss_amt.toFixed(2) + '亿');
#
#     $('.adj_cnt_tips').each(function() {
#         var $el = $(this);
#         var bond_id = $el.attr('bond_id');
#         var bond_nm = $el.attr('bond_nm');
#         $el.click(function(){
# 			$.ajax({
# 				type: "GET",
# 				url: G_BASE_URL + '/data/cbnew/adj_logs/?bond_id=' + bond_id,
# 				success: function(data,textStatus) {
# 					if (data != null)
# 					{
# 						$('#dataModalLabel').html(bond_nm + '[' + bond_id + '] 转股价下修记录');
# 						$('#dataModalBody').html(data);
# 						$('#dataModal').modal('show');
# 					}
# 				}
# 			});
#         });
#     });
#
#     $('.jsl_cb_notes').each(function() {
#         var $el = $(this);
#         var bond_id = $el.attr('bond_id');
#         var bond_nm = $el.attr('bond_nm');
#         $el.click(function(){
# 			$.ajax({
# 				type: "GET",
# 				url: G_BASE_URL + '/data/cbnew/note/?bond_id=' + bond_id,
# 				success: function(data,textStatus) {
# 					if (data != null)
# 					{
# 						$('#dataModalLabel').html(bond_nm + '[' + bond_id + '] 备注');
# 						$('#dataModalBody').html(data);
# 						$('#dataModal').modal('show');
# 					}
# 				}
# 			});
#         });
#     });
#
#
#
# 	autoReloadConvertBondTable(tableConvertBond, 'auto_reload', 'auto_reload');
#
# }
#
# function convertBondNameStyler(nameVal, row){
# 	if(row.owned){
# 		return ';color:red';
# 	}
# 	return '';
# }
#
# function cbIncreaseRtformatter(nameVal, row){
#     if(row.qstatus != '00'){
#         return '停牌';
#     }
#     return row.increase_rt;
# }
#
# function cbStocknmFormatter(nameVal, row){
#     var s = '<a href="/data/stock/' + row.stock_cd + '" target="_blank">' + row.stock_nm + '</a>';
#     if('R' == row.margin_flg){
#         s += ' <sup style="font-size:10px;color:#FFA500;" title="融资融券标的">R</sup>';
#     }
#     return s;
# }
#
# is_cb_search = "N";
# bond_ids = "";
#
# function showConvertBond(){
# 	var cnd = fillConvertBondSearchCnd(is_cb_search);
# 	if(!tableConvertBond){
# 		tableConvertBond = new SimpleTableBuilder({
# 			afterShow: bindAdjCntTip,
# 			tid: 'flex_cb',
# 			async: true,
# 			rp: 50,
# 			cols: [
# 				{display: '状态', name : 'status_cd', width : 30, img : true, tooltip:'注：{{status_txt}}',hidden: true},
# 				{display: '代&nbsp;码', title:'转债代码', name : 'bond_id', width : 40,tooltip:'债项评级：{{rating_cd}}',formatter:convertBondDetailLinkFormatter, nowrap : true},
# 				{display: '转债名称', title:'转债名称', name : 'bond_nm', width : 55, nowrap : true,formatter:convertBondNameFormatter, styler:convertBondNameStyler},
# 				{display: '现&nbsp;价', title:'转债现价', name : 'price', width : 40, tooltip:'{{price_tips}}', nowrap : true, styler:convertBondPriceStyler},
# 				{display: '涨跌幅', title:'转债涨跌幅', name : 'increase_rt', width : 40, color:true, nowrap : true, formatter:cbIncreaseRtformatter, styler:convertBondPriceStyler, sorter:'percentSorter'},
# 				{display: '正股名称', title:'正股名称', name : 'stock_nm', width : 50,tooltip:'代码：{{stock_id}}', nowrap : true, formatter:cbStocknmFormatter},
# 				{display: '正股价', title:'正股现价', name : 'sprice', width : 35, nowrap : true, tooltip:'正股成交额：{{svolume}}万元'},
# 				{display: '正股<br>涨跌', title:'正股涨跌幅', name : 'sincrease_rt', width : 40, color:true, nowrap : true, sorter:'percentSorter'},
# 				//{display: '净资产', title:'正股净资产', name : 'stock_net_value', width : 40},
# 				{display: 'PB', title:'市净率', name : 'pb', width : 35, nowrap : true},
# 				{display: '转股价', title:'最新转股价', name : 'convert_price', width : 40, nowrap : true, formatter:convertPriceFormatter, styler:convertPriceStyler},
# 				{display: '转股<br>价值', name : 'convert_value', width : 40,tooltip:'转股代码：{{convert_cd_tip}}', nowrap : true, styler:convertPriceStyler},
# 				{display: '溢价率', name : 'premium_rt', width : 40,tooltip:'转股代码：{{convert_cd_tip}}', bgcolor:'yellow', nowrap : true, styler: premiumRtStyler},
# 				{display: '纯债<br>价值', title:'纯债价值，税前', name : '_bond_value', width : 35, nowrap : true, formatter:buyOptionValueFormatter},
# 				{display: '评级', name:'rating_cd', width : 35, nowrap : true, sorter:'ratingCode'},
# 				{display: '期权<br>价值', title:'转股价的看涨期权价值', name : '_option_value', width : 35, nowrap : true, formatter:buyOptionValueFormatter},
# 				{display: '回售<br>触发价', name:'put_convert_price', width:35,tooltip:'回售起始：{{next_put_dt}}', nowrap : true},
# 				{display: '强赎<br>触发价', title:'转股价*130%', name:'force_redeem_price', width:35, nowrap : true},
# 				{display: '转债<br>占比', title:'转债余额/总市值', name:'convert_amt_ratio', width:35,tooltip:'转债规模：{{curr_iss_amt}}', nowrap : true},
# 				{display: '机构<br>持仓', title:'机构持仓%', name:'fund_rt', width:35, nowrap : true, formatter:cbFundRtFormatter},
# 				{display: '到期时间', name : 'short_maturity_dt', width : 55, nowrap : true, styler:redeemStyler, sorter: 'shortDateSorter'},
# 				{display: '剩余<br>年限', name : 'year_left', width : 35, styler:redeemStyler, nowrap : true},
# 				{display: '到期<br>税前收益', title:'到期税前收益率', name : 'ytm_rt', width : 45, bgcolor:'yellow', styler:redeemStyler, nowrap : true},
# 				{display: '到期<br>税后收益', title:'到期税后收益率', name : 'ytm_rt_tax', width : 45, styler:redeemStyler, nowrap : true},
# 				{display: '回售<br>收益', title:'回售收益率', name : '_put_ytm_rt', width : 35, nowrap : true, formatter:buyOptionValueFormatter, bgcolor:'yellow'},
# 				{display: '成交额<br>(万元)', title:'成交额', name : 'volume', width : 50, nowrap : true, tooltip :'正股成交额：{{svolume}}万元'},
# 				{display: '折算<br>率', title:'标准券折算率', name : 'repo_discount_rt', width : 35,tooltip:'{{repo_valid}}', hidden : true},
# 				{display: '最后更新', title:'最后更新', name : 'last_time', width : 40, hidden: true},
# 				{display: '状态描述', name : 'status_txt',  hidden: true},
# 				{display: '安道全点评', name : 'adq_descr', width : 40, hidden: true},
# 				{display: '正股代码', name : 'stock_id',hidden: true},
# 				{display: '正股代码', name : 'stock_cd',hidden: true},
# 				{display: '预期回售', name : 'estimate_put_dt',hidden: true},
# 				{display: '回售说明', name : 'put_notes',hidden: true},
# 				{display: '转债代码', name : 'pre_bond_id',hidden: true},
# 				{display: '回售起始', name : 'next_put_dt',hidden: true},
# 				{display: '已到回售期', name : 'after_next_put_dt',hidden: true},
# 				{display: '转债规模', name : 'curr_iss_amt',hidden: true},
# 				{display: '质押代码', name : 'repo_cd',hidden: true},
# 				{display: '下修情况', name : 'adjust_tip',hidden: true},
# 				{display: '转股代码', name : 'convert_cd',hidden: true},
#                 {display: '转股代码提示', name : 'convert_cd_tip',hidden: true},
# 				{display: '价格提示', name : 'price_tips',hidden: true},
# 				{display: '正股成交额', name : 'svolume',hidden: true},
# 				{display: '折算率效期', name:'repo_valid', hidden:true},
# 				{display: '下修次数', name:'adj_cnt', hidden:true},
# 				{display: '成功下修次数', name:'adj_scnt', hidden:true},
# 				{display: '操作', name: 'cbOpt', formatter: cbOptFormatter, width:15,nowrap : true}
# 			],
# 			dataURL: '/data/cbnew/cb_list/',
# 			title:'#tableConvertBondTitle'
# 		});
# 		tableConvertBond.show(cnd);
# 	}else{
# 		tableConvertBond.reload(cnd);
# 	}
# }
#
# var tableConvertBondDelisted = null;
# function showDelistedCB(){
#     if(!tableConvertBondDelisted){
#         tableConvertBondDelisted = new SimpleTableBuilder({
#             dataURL: '/data/cbnew/delisted/',
#             title:'已退市转债',
#             tid: 'flex_delisted',
#             cols:[
#                 {display: '转债代码',     name : 'bond_id', width : 40, formatter: convertBondDetailLinkFormatter, nowrap : true},
#                 {display: '转债名称',     name : 'bond_nm', width : 55, nowrap : true,formatter: convertBondNameFormatter},
#                 {display: '最后交易价格',  name : 'price', width : 55, nowrap : true},
#                 {display: '正股代码',     name : 'stock_id', width : 55, nowrap : true,
#                     link: {
#                     url:'/data/stock/{{stock_id}}',
#                     newpage: true,
#                     type: self
#                     }
#                 },
#                 {display: '正股名称',     name : 'stock_nm', width : 50,tooltip:'代码：{{stock_id}}', nowrap : true},
#                 {display: '发行规模<br>(亿元)',     name : 'orig_iss_amt', width : 55, nowrap : true},
#                 {display: '回售规模<br>(亿元)',     name : 'put_iss_amt', width : 55, nowrap : true},
#                 {display: '剩余规模<br>(亿元)',  title:'退市时剩余规模',   name : 'curr_iss_amt', width : 55, nowrap : true},
#                 {display: '发行日期',     name : 'issue_dt', width : 85, nowrap : true},
#                 {display: '最后交易日',   name : 'delist_dt', width : 85, nowrap : true},
#                 {display: '到期日期',     name : 'maturity_dt', width : 85, nowrap : true},
#                 {display: '存续年限<br>(年)',     name : 'listed_years', width : 45, nowrap : true},
#                 {display: '退市原因',     name : 'delist_notes', width : 85, nowrap : true}
#             ]
#         });
#         tableConvertBondDelisted.show();
#     }else{
#         tableConvertBondDelisted.reload();
#     }
# }
#
# $(function(){
# 	$('.datepicker').datepicker({
#         clearBtn: true,
# 		autoclose: true,
#         toggleActive: true,
#         // todayHighlight: true,
#         //datesDisabled:[],
# 		daysOfWeekDisabled: "0,6,7",
# 		//daysOfWeekHighlighted: "1,2,3,4,5",
#         startDate: '2012-01-04',
#         endDate: new Date(new Date().getTime() - 24*60*60*1000).format('yyyy-MM-dd'),
# 		language: 'zh-CN',
# 		format: 'yyyy-mm-dd'
# 	}).on('hide', function(e) {
#         var date = $('#historySearchInput').val();
#         if(isNaN(date)&&!isNaN(Date.parse(date))) {
#             window.open("/data/cbnew/snapshot/" + date.replace(/-/g,""));
#         }
#     });
#
# 	$('#historySearchBtn').click(function(){
# 		var date = $('#historySearchInput').val();
#         if(isNaN(date)&&!isNaN(Date.parse(date))) {
#             window.open("/data/cbnew/snapshot/" + date.replace(/-/g,""));
#         }
# 	});
#
#
# });
#
# show_cbindex_quote('.index_quote_info', true, true, '转债等权指数');
#
# $('#dataModal').modal({show:false});
#
# </script>
# <script src="/static/js/app/data_cb.js?v=20191025" type="text/javascript"></script>
# <div aria-labelledby="myModalLabel" class="modal fade" id="dataModal" role="dialog" style="display: none;" tabindex="-1">
# <div class="modal-dialog" role="document">
# <div class="modal-content">
# <div class="modal-header">
# <button aria-label="Close" class="close" data-dismiss="modal" type="button"><span aria-hidden="true">×</span></button>
# <h5 class="modal-title" id="dataModalLabel"></h5>
# </div>
# <div class="modal-body" id="dataModalBody">
# </div>
# </div>
# </div>
# </div>
# <div class="footer_bg">
# <div class="grid footer_content">
# <div class="grid-row">
# <div class="grid-col-2"> </div>
# <div class="grid-col-8 footer_left">
# <div>京ICP证160493号<span class="separator">|</span>©2012-2019 - 集思录  Powered by AW</div>
# <div>
# <a href="/account/agreement/" target="_blank">用户协议</a><span class="separator">|</span>
# <a href="/question/48275" target="_blank">问题反馈</a><span class="separator">|</span>
#                     使用<a href="https://www.google.cn/chrome/" rel="noopener noreferrer" target="_blank">Chrome</a>浏览本站最佳
#                 </div>
# <div>
# <a href="http://weibo.com/jisilu" target="_blank">关注本站微博</a><span class="separator">|</span><a href="/question/10876" target="_blank">加入我们</a>
# </div>
# <div>联系电话：010-58481319</div>
# <div class="statement">声明：本站所有收费以及免费的信息和数据仅供参考，不构成投资建议，集思录不承担由此导致的任何责任。</div>
# </div>
# <div class="grid-col-4"> </div>
# <div class="grid-col-10 footer_right">
# <div class="grid-row">
# <div class="grid-col-3">微信公众号<img src="/static/css/default/img/qrcode_public.png"/></div>
# <div class="grid-col-3">APP下载<img src="/static/css/default/img/qrcode_app.png"/></div>
# <div class="grid-col-auto"> </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- DO NOT REMOVE -->
# <div class="aw-ajax-box" id="aw-ajax-box"></div>
# <div id="ajax_data" style="display:none"></div>
# <div id="__crond" style="display:none;">
# <script type="text/javascript">
#         $(document).ready(function () {
#             $('#__crond').html(unescape('%3Cimg%20src%3D%22' + G_BASE_URL + '/crond/run/1576126043%22%20width%3D%221%22%20height%3D%221%22%20/%3E'));
#         });
#     </script>
# </div>
# <!-- / DO NOT REMOVE -->
# <!-- Escape time: 0.037101984024048 --><script data="type=tools" id="bdshare_js" type="text/javascript"></script>
# <script src="/static/js/dc.js" type="text/javascript"></script>
# </body></html>

# %%
# url='https://www.jisilu.cn/data/cbnew/#cb'
# url='https://www.jisilu.cn/data/cbnew/cb_index_quote/'
url='https://www.jisilu.cn/data/cbnew/cb_list/?___jsl=LST___t=1576123233361'
req = urllib.request.Request(url)
req.add_header('User-Agent','Mozilla/5.0 (Windows NT 6.2; rv:16.0) Gecko/20100101 Firefox/16.0')

page = urllib.request.urlopen(req)

html = page.read().decode('utf-8')
# html

unicodestr=json.loads(html)

# %%
# soup =BeautifulSoup(html, 'lxml')
# soup

# unicodestr
dict_json = json.loads(html)  
dict_json
# Out:
# {'page': 1,
#  'rows': [{'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '370655',
#     'bond_id': '123031',
#     'bond_nm': '晶瑞转债',
#     'convert_amt_ratio': '3.7%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-03-05 开始转股',
#     'convert_dt': '2020-03-05',
#     'convert_price': '18.380',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '177.91',
#     'curr_iss_amt': '1.850',
#     'force_redeem': None,
#     'force_redeem_price': '23.89',
#     'full_price': '154.089',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '4.26%',
#     'issuer_rating_cd': 'A+',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2025-08-28',
#     'next_put_dt': '2023-08-28',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '1.850',
#     'owned': 0,
#     'pb': '8.85',
#     'pre_bond_id': 'sz123031',
#     'premium_rt': '-13.39%',
#     'price': '154.089',
#     'price_tips': '全价：154.089 最后更新：11:30:03',
#     'put_convert_price': '12.87',
#     'put_convert_price_ratio': '39.35',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'A+',
#     'ration': None,
#     'ration_cd': '380655',
#     'ration_rt': '8.110',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '111.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-08-28',
#     'sincrease_rt': '1.21%',
#     'sprice': '32.70',
#     'sqflg': 'Y',
#     'stock_cd': '300655',
#     'stock_id': 'sz300655',
#     'stock_net_value': '0.00',
#     'stock_nm': '晶瑞股份',
#     'svolume': '26315.06',
#     'total_shares': '151425987.0',
#     'volume': '14610.83',
#     'year_left': '5.715',
#     'ytm_rt': '-4.90%',
#     'ytm_rt_tax': '-5.36%'},
#    'id': '123031'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '754960',
#     'bond_id': '113552',
#     'bond_nm': '克来转债',
#     'convert_amt_ratio': '3.2%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-08 开始转股',
#     'convert_dt': '2020-06-08',
#     'convert_price': '27.860',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '115.43',
#     'curr_iss_amt': '1.800',
#     'force_redeem': None,
#     'force_redeem_price': '36.22',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '股份质押的担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'A+',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2025-12-01',
#     'next_put_dt': '2023-12-01',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '1.800',
#     'owned': 0,
#     'pb': '10.36',
#     'pre_bond_id': 'sh113552',
#     'premium_rt': '-13.37%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '19.50',
#     'put_convert_price_ratio': '60.64',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'A+',
#     'ration': None,
#     'ration_cd': '753960',
#     'ration_rt': '82.250',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '112.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-01',
#     'sincrease_rt': '3.54%',
#     'sprice': '32.16',
#     'sqflg': 'Y',
#     'stock_cd': '603960',
#     'stock_id': 'sh603960',
#     'stock_net_value': '0.00',
#     'stock_nm': '克来机电',
#     'svolume': '4171.70',
#     'total_shares': '175760000.0',
#     'volume': '0.00',
#     'year_left': '5.975',
#     'ytm_rt': '2.95%',
#     'ytm_rt_tax': '2.38%'},
#    'id': '113552'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072806',
#     'bond_id': '128082',
#     'bond_nm': '华锋转债',
#     'convert_amt_ratio': '14.1%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-10 开始转股',
#     'convert_dt': '2020-06-10',
#     'convert_price': '13.170',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '107.52',
#     'curr_iss_amt': '3.520',
#     'force_redeem': None,
#     'force_redeem_price': '17.12',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '土地、房产、机器设备等资产抵 押和股份质押担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'A+',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2025-12-03',
#     'next_put_dt': '2023-12-04',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '3.520',
#     'owned': 0,
#     'pb': '1.98',
#     'pre_bond_id': 'sz128082',
#     'premium_rt': '-6.99%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '9.22',
#     'put_convert_price_ratio': '65.11',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'A+',
#     'ration': None,
#     'ration_cd': '082806',
#     'ration_rt': '5.530',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '115.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-03',
#     'sincrease_rt': '10.02%',
#     'sprice': '14.16',
#     'sqflg': 'Y',
#     'stock_cd': '002806',
#     'stock_id': 'sz002806',
#     'stock_net_value': '0.00',
#     'stock_nm': '华锋股份',
#     'svolume': '3309.46',
#     'total_shares': '176239202.0',
#     'volume': '0.00',
#     'year_left': '5.981',
#     'ytm_rt': '3.46%',
#     'ytm_rt_tax': '2.80%'},
#    'id': '128082'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '754079',
#     'bond_id': '113539',
#     'bond_nm': '圣达转债',
#     'convert_amt_ratio': '6.9%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-01-09 开始转股',
#     'convert_dt': '2020-01-09',
#     'convert_price': '28.780',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '134.82',
#     'curr_iss_amt': '2.990',
#     'force_redeem': None,
#     'force_redeem_price': '37.41',
#     'full_price': '125.750',
#     'fund_rt': 'buy',
#     'guarantor': '连带责任保证担保',
#     'increase_rt': '1.22%',
#     'issuer_rating_cd': 'A+',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2025-07-02',
#     'next_put_dt': '2023-07-03',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '2.990',
#     'owned': 0,
#     'pb': '4.93',
#     'pre_bond_id': 'sh113539',
#     'premium_rt': '-6.73%',
#     'price': '125.750',
#     'price_tips': '全价：125.750 最后更新：11:30:00',
#     'put_convert_price': '20.15',
#     'put_convert_price_ratio': '51.92',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'A+',
#     'ration': None,
#     'ration_cd': '753079',
#     'ration_rt': '41.500',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '115.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-07-02',
#     'sincrease_rt': '-0.77%',
#     'sprice': '38.80',
#     'sqflg': 'Y',
#     'stock_cd': '603079',
#     'stock_id': 'sh603079',
#     'stock_net_value': '0.00',
#     'stock_nm': '圣达生物',
#     'svolume': '1345.11',
#     'total_shares': '112000000.0',
#     'volume': '2649.37',
#     'year_left': '5.559',
#     'ytm_rt': '-0.62%',
#     'ytm_rt_tax': '-1.27%'},
#    'id': '113539'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '754658',
#     'bond_id': '113538',
#     'bond_nm': '安图转债',
#     'convert_amt_ratio': '1.7%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-01-06 开始转股',
#     'convert_dt': '2020-01-06',
#     'convert_price': '64.110',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '153.67',
#     'curr_iss_amt': '6.830',
#     'force_redeem': None,
#     'force_redeem_price': '83.34',
#     'full_price': '146.540',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.68%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-06-27',
#     'next_put_dt': '2023-06-28',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '6.830',
#     'owned': 0,
#     'pb': '17.83',
#     'pre_bond_id': 'sh113538',
#     'premium_rt': '-4.64%',
#     'price': '146.540',
#     'price_tips': '全价：146.540 最后更新：11:30:00',
#     'put_convert_price': '44.88',
#     'put_convert_price_ratio': '45.55',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '753658',
#     'ration_rt': '73.650',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-06-27',
#     'sincrease_rt': '-0.98%',
#     'sprice': '98.52',
#     'sqflg': 'Y',
#     'stock_cd': '603658',
#     'stock_id': 'sh603658',
#     'stock_net_value': '0.00',
#     'stock_nm': '安图生物',
#     'svolume': '4144.96',
#     'total_shares': '420000000.0',
#     'volume': '1307.00',
#     'year_left': '5.545',
#     'ytm_rt': '-4.33%',
#     'ytm_rt_tax': '-4.78%'},
#    'id': '113538'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072376',
#     'bond_id': '128083',
#     'bond_nm': '新北转债',
#     'convert_amt_ratio': '10.8%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-18 开始转股',
#     'convert_dt': '2020-06-18',
#     'convert_price': '11.900',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '102.86',
#     'curr_iss_amt': '8.770',
#     'force_redeem': None,
#     'force_redeem_price': '15.47',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'AA',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-12-12',
#     'next_put_dt': '2023-12-12',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '8.770',
#     'owned': 0,
#     'pb': '2.48',
#     'pre_bond_id': 'sz128083',
#     'premium_rt': '-2.78%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '8.33',
#     'put_convert_price_ratio': '68.06',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '082376',
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-12',
#     'sincrease_rt': '-1.21%',
#     'sprice': '12.24',
#     'sqflg': 'Y',
#     'stock_cd': '002376',
#     'stock_id': 'sz002376',
#     'stock_net_value': '0.00',
#     'stock_nm': '新北洋',
#     'svolume': '3806.80',
#     'total_shares': '665712402.0',
#     'volume': '0.00',
#     'year_left': '6.003',
#     'ytm_rt': '2.43%',
#     'ytm_rt_tax': '1.96%'},
#    'id': '128083'},
#   {'cell': {'adj_cnt': 1,
#     'adj_scnt': '1',
#     'adjust_tip': '',
#     'apply_cd': '072273',
#     'bond_id': '128020',
#     'bond_nm': '水晶转债',
#     'convert_amt_ratio': '4.9%',
#     'convert_cd': '128020',
#     'convert_cd_tip': '128020；2018-05-23 开始转股',
#     'convert_dt': '2018-05-23',
#     'convert_price': '12.230',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-07-24',
#     'convert_value': '139.57',
#     'curr_iss_amt': '9.515',
#     'force_redeem': None,
#     'force_redeem_price': '15.90',
#     'full_price': '138.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '1.85%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2023-11-16',
#     'next_put_dt': '2021-11-17',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '11.800',
#     'owned': 0,
#     'pb': '4.59',
#     'pre_bond_id': 'sz128020',
#     'premium_rt': '-1.12%',
#     'price': '138.000',
#     'price_tips': '全价：138.000 最后更新：11:30:03',
#     'put_convert_price': '8.56',
#     'put_convert_price_ratio': '50.15',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '1.7800',
#     'ration_cd': '082273',
#     'ration_rt': '74.715',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 4,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '23-11-16',
#     'sincrease_rt': '2.40%',
#     'sprice': '17.07',
#     'sqflg': 'Y',
#     'stock_cd': '002273',
#     'stock_id': 'sz002273',
#     'stock_net_value': '0.00',
#     'stock_nm': '水晶光电',
#     'svolume': '119747.62',
#     'total_shares': '1126829050.0',
#     'volume': '15022.45',
#     'year_left': '3.932',
#     'ytm_rt': '-5.43%',
#     'ytm_rt_tax': '-5.91%'},
#    'id': '128020'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072907',
#     'bond_id': '128069',
#     'bond_nm': '华森转债',
#     'convert_amt_ratio': '3.8%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2019-12-30 开始转股',
#     'convert_dt': '2019-12-30',
#     'convert_price': '18.080',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-07-15',
#     'convert_value': '109.29',
#     'curr_iss_amt': '3.000',
#     'force_redeem': None,
#     'force_redeem_price': '23.50',
#     'full_price': '108.080',
#     'fund_rt': 'buy',
#     'guarantor': '股份质押担保',
#     'increase_rt': '-0.02%',
#     'issuer_rating_cd': 'AA-',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2025-06-24',
#     'next_put_dt': '2023-06-26',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '3.000',
#     'owned': 0,
#     'pb': '7.66',
#     'pre_bond_id': 'sz128069',
#     'premium_rt': '-1.11%',
#     'price': '108.080',
#     'price_tips': '全价：108.080 最后更新：11:30:03',
#     'put_convert_price': '12.66',
#     'put_convert_price_ratio': '64.05',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA-',
#     'ration': None,
#     'ration_cd': '082907',
#     'ration_rt': '61.340',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 30,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '115.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 15,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-06-24',
#     'sincrease_rt': '-2.52%',
#     'sprice': '19.76',
#     'sqflg': 'Y',
#     'stock_cd': '002907',
#     'stock_id': 'sz002907',
#     'stock_net_value': '0.00',
#     'stock_nm': '华森制药',
#     'svolume': '13152.85',
#     'total_shares': '401546200.0',
#     'volume': '1296.50',
#     'year_left': '5.537',
#     'ytm_rt': '2.02%',
#     'ytm_rt_tax': '1.37%'},
#    'id': '128069'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072402',
#     'bond_id': '128068',
#     'bond_nm': '和而转债',
#     'convert_amt_ratio': '4.8%',
#     'convert_cd': '128068',
#     'convert_cd_tip': '128068；2019-12-11 开始转股',
#     'convert_dt': '2019-12-11',
#     'convert_price': '9.090',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '139.49',
#     'curr_iss_amt': '5.177',
#     'force_redeem': None,
#     'force_redeem_price': '11.82',
#     'full_price': '137.990',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '3.74%',
#     'issuer_rating_cd': 'AA-',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-06-04',
#     'next_put_dt': '2023-06-05',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '5.470',
#     'owned': 0,
#     'pb': '5.79',
#     'pre_bond_id': 'sz128068',
#     'premium_rt': '-1.08%',
#     'price': '137.990',
#     'price_tips': '全价：137.990 最后更新：11:30:03',
#     'put_convert_price': '6.36',
#     'put_convert_price_ratio': '50.18',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA-',
#     'ration': None,
#     'ration_cd': '082402',
#     'ration_rt': '37.700',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 1,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-06-04',
#     'sincrease_rt': '3.76%',
#     'sprice': '12.68',
#     'sqflg': 'Y',
#     'stock_cd': '002402',
#     'stock_id': 'sz002402',
#     'stock_net_value': '0.00',
#     'stock_nm': '和而泰',
#     'svolume': '37657.73',
#     'total_shares': '855435396.0',
#     'volume': '10232.92',
#     'year_left': '5.482',
#     'ytm_rt': '-3.60%',
#     'ytm_rt_tax': '-4.01%'},
#    'id': '128068'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072002',
#     'bond_id': '128085',
#     'bond_nm': '鸿达转债',
#     'convert_amt_ratio': '23.3%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-22 开始转股',
#     'convert_dt': '2020-06-22',
#     'convert_price': '3.980',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '101.01',
#     'curr_iss_amt': '24.270',
#     'force_redeem': None,
#     'force_redeem_price': '5.17',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'AA',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-12-16',
#     'next_put_dt': '2023-12-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '24.270',
#     'owned': 0,
#     'pb': '1.59',
#     'pre_bond_id': 'sz128085',
#     'premium_rt': '-1.00%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '2.79',
#     'put_convert_price_ratio': '69.30',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '082002',
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '118.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': None,
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-16',
#     'sincrease_rt': '0.50%',
#     'sprice': '4.02',
#     'sqflg': 'Y',
#     'stock_cd': '002002',
#     'stock_id': 'sz002002',
#     'stock_net_value': '0.00',
#     'stock_nm': '鸿达兴业',
#     'svolume': '6574.35',
#     'total_shares': '2588713789.0',
#     'volume': '0.00',
#     'year_left': '6.003',
#     'ytm_rt': '3.84%',
#     'ytm_rt_tax': '3.11%'},
#    'id': '128085'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '783615',
#     'bond_id': '113029',
#     'bond_nm': '明阳转债',
#     'convert_amt_ratio': '9.7%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-22 开始转股',
#     'convert_dt': '2020-06-22',
#     'convert_price': '12.660',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '100.39',
#     'curr_iss_amt': '17.000',
#     'force_redeem': None,
#     'force_redeem_price': '16.46',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'AA',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-12-16',
#     'next_put_dt': '2023-12-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '17.000',
#     'owned': 0,
#     'pb': '2.86',
#     'pre_bond_id': 'sh113029',
#     'premium_rt': '-0.39%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '8.86',
#     'put_convert_price_ratio': '69.72',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '764615',
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': None,
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-16',
#     'sincrease_rt': '0.08%',
#     'sprice': '12.71',
#     'sqflg': 'Y',
#     'stock_cd': '601615',
#     'stock_id': 'sh601615',
#     'stock_net_value': '0.00',
#     'stock_nm': '明阳智能',
#     'svolume': '10197.51',
#     'total_shares': '1379722378.0',
#     'volume': '0.00',
#     'year_left': '6.003',
#     'ytm_rt': '2.14%',
#     'ytm_rt_tax': '1.73%'},
#    'id': '113029'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072745',
#     'bond_id': '128084',
#     'bond_nm': '木森转债',
#     'convert_amt_ratio': '16.0%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-22 开始转股',
#     'convert_dt': '2020-06-22',
#     'convert_price': '12.950',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '100.39',
#     'curr_iss_amt': '26.600',
#     'force_redeem': None,
#     'force_redeem_price': '16.84',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'AA',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-12-16',
#     'next_put_dt': '2023-12-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '26.600',
#     'owned': 0,
#     'pb': '1.66',
#     'pre_bond_id': 'sz128084',
#     'premium_rt': '-0.39%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '9.06',
#     'put_convert_price_ratio': '69.73',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '082745',
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '112.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': None,
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-12-16',
#     'sincrease_rt': '0.54%',
#     'sprice': '13.00',
#     'sqflg': 'Y',
#     'stock_cd': '002745',
#     'stock_id': 'sz002745',
#     'stock_net_value': '0.00',
#     'stock_nm': '木林森',
#     'svolume': '14152.42',
#     'total_shares': '1277168540.0',
#     'volume': '0.00',
#     'year_left': '6.003',
#     'ytm_rt': '2.74%',
#     'ytm_rt_tax': '2.22%'},
#    'id': '128084'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072446',
#     'bond_id': '128041',
#     'bond_nm': '盛路转债',
#     'convert_amt_ratio': '0.8%',
#     'convert_cd': '128041',
#     'convert_cd_tip': '128041；2019-01-23 开始转股',
#     'convert_dt': '2019-01-23',
#     'convert_price': '6.850',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-07-19',
#     'convert_value': '150.51',
#     'curr_iss_amt': '0.730',
#     'force_redeem': None,
#     'force_redeem_price': '8.90',
#     'full_price': '150.013',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.79%',
#     'issuer_rating_cd': 'AA-',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2024-07-16',
#     'next_put_dt': '2022-07-17',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '10.000',
#     'owned': 0,
#     'pb': '2.51',
#     'pre_bond_id': 'sz128041',
#     'premium_rt': '-0.33%',
#     'price': '150.013',
#     'price_tips': '全价：150.013 最后更新：11:30:03',
#     'put_convert_price': '4.79',
#     'put_convert_price_ratio': '46.51',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '1.3121',
#     'ration_cd': '082446',
#     'ration_rt': '13.900',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 29,
#     'redeem_style': 'N',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '24-07-16',
#     'sincrease_rt': '-0.67%',
#     'sprice': '10.31',
#     'sqflg': 'Y',
#     'stock_cd': '002446',
#     'stock_id': 'sz002446',
#     'stock_net_value': '0.00',
#     'stock_nm': '盛路通信',
#     'svolume': '23751.57',
#     'total_shares': '895881246.0',
#     'volume': '110.30',
#     'year_left': '4.597',
#     'ytm_rt': '-5.72%',
#     'ytm_rt_tax': '-6.25%'},
#    'id': '128041'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '370088',
#     'bond_id': '123022',
#     'bond_nm': '长信转债',
#     'convert_amt_ratio': '3.1%',
#     'convert_cd': '123022',
#     'convert_cd_tip': '123022；2019-09-23 开始转股',
#     'convert_dt': '2019-09-23',
#     'convert_price': '6.250',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-05-27',
#     'convert_value': '153.60',
#     'curr_iss_amt': '6.851',
#     'force_redeem': None,
#     'force_redeem_price': '8.12',
#     'full_price': '153.158',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '3.28%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-03-18',
#     'next_put_dt': '2023-03-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '12.300',
#     'owned': 0,
#     'pb': '4.01',
#     'pre_bond_id': 'sz123022',
#     'premium_rt': '-0.29%',
#     'price': '153.158',
#     'price_tips': '全价：153.158 最后更新：11:30:03',
#     'put_convert_price': '4.38',
#     'put_convert_price_ratio': '45.57',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.5350',
#     'ration_cd': '380088',
#     'ration_rt': '42.700',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 5,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-03-18',
#     'sincrease_rt': '2.89%',
#     'sprice': '9.60',
#     'sqflg': 'Y',
#     'stock_cd': '300088',
#     'stock_id': 'sz300088',
#     'stock_net_value': '0.00',
#     'stock_nm': '长信科技',
#     'svolume': '112370.68',
#     'total_shares': '2311974278.0',
#     'volume': '27548.01',
#     'year_left': '5.268',
#     'ytm_rt': '-5.34%',
#     'ytm_rt_tax': '-5.82%'},
#    'id': '123022'},
#   {'cell': {'adj_cnt': 3,
#     'adj_scnt': '2',
#     'adjust_tip': '',
#     'apply_cd': '370433',
#     'bond_id': '123003',
#     'bond_nm': '蓝思转债',
#     'convert_amt_ratio': '3.4%',
#     'convert_cd': '123003',
#     'convert_cd_tip': '123003；2018-06-14 开始转股',
#     'convert_dt': '2018-06-14',
#     'convert_price': '10.440',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-07-11',
#     'convert_value': '135.15',
#     'curr_iss_amt': '20.079',
#     'force_redeem': None,
#     'force_redeem_price': '13.57',
#     'full_price': '134.778',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.73%',
#     'issuer_rating_cd': 'AA+',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2023-12-08',
#     'next_put_dt': '2021-12-08',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '48.000',
#     'owned': 0,
#     'pb': '3.25',
#     'pre_bond_id': 'sz123003',
#     'premium_rt': '-0.28%',
#     'price': '134.778',
#     'price_tips': '全价：134.778 最后更新：11:30:03',
#     'put_convert_price': '7.31',
#     'put_convert_price_ratio': '51.79',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA+',
#     'ration': '1.8335',
#     'ration_cd': '380433',
#     'ration_rt': '13.540',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 20,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '106.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 17,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '23-12-08',
#     'sincrease_rt': '1.51%',
#     'sprice': '14.11',
#     'sqflg': 'Y',
#     'stock_cd': '300433',
#     'stock_id': 'sz300433',
#     'stock_net_value': '0.00',
#     'stock_nm': '蓝思科技',
#     'svolume': '45199.82',
#     'total_shares': '4154740469.0',
#     'volume': '6440.46',
#     'year_left': '3.992',
#     'ytm_rt': '-5.08%',
#     'ytm_rt_tax': '-5.50%'},
#    'id': '123003'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072783',
#     'bond_id': '128052',
#     'bond_nm': '凯龙转债',
#     'convert_amt_ratio': '1.6%',
#     'convert_cd': '128052',
#     'convert_cd_tip': '128052；2019-06-27 开始转股',
#     'convert_dt': '2019-06-27',
#     'convert_price': '6.770',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-06-12',
#     'convert_value': '178.73',
#     'curr_iss_amt': '0.718',
#     'force_redeem': None,
#     'force_redeem_price': '8.80',
#     'full_price': '178.490',
#     'fund_rt': 'buy',
#     'guarantor': '荆门市城市建设投资有限公司',
#     'increase_rt': '-0.61%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2024-12-21',
#     'next_put_dt': '2022-12-21',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '3.289',
#     'owned': 0,
#     'pb': '2.61',
#     'pre_bond_id': 'sz128052',
#     'premium_rt': '-0.13%',
#     'price': '178.490',
#     'price_tips': '全价：178.490 最后更新：11:30:03',
#     'put_convert_price': '4.74',
#     'put_convert_price_ratio': '39.17',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.9849',
#     'ration_cd': '082783',
#     'ration_rt': '19.050',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 30,
#     'redeem_style': 'N',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '24-12-21',
#     'sincrease_rt': '-0.49%',
#     'sprice': '12.10',
#     'sqflg': 'Y',
#     'stock_cd': '002783',
#     'stock_id': 'sz002783',
#     'stock_net_value': '0.00',
#     'stock_nm': '凯龙股份',
#     'svolume': '9508.26',
#     'total_shares': '370265415.0',
#     'volume': '2992.79',
#     'year_left': '5.030',
#     'ytm_rt': '-8.45%',
#     'ytm_rt_tax': '-8.92%'},
#    'id': '128052'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '370473',
#     'bond_id': '123011',
#     'bond_nm': '德尔转债',
#     'convert_amt_ratio': '8.6%',
#     'convert_cd': '123011',
#     'convert_cd_tip': '123011；2019-01-24 开始转股',
#     'convert_dt': '2019-01-24',
#     'convert_price': '34.660',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-06-14',
#     'convert_value': '121.87',
#     'curr_iss_amt': '3.908',
#     'force_redeem': None,
#     'force_redeem_price': '45.06',
#     'full_price': '121.765',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.18%',
#     'issuer_rating_cd': 'AA-',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2024-07-18',
#     'next_put_dt': '2022-07-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '5.647',
#     'owned': 0,
#     'pb': '2.25',
#     'pre_bond_id': 'sz123011',
#     'premium_rt': '-0.09%',
#     'price': '121.765',
#     'price_tips': '全价：121.765 最后更新：11:30:03',
#     'put_convert_price': '24.26',
#     'put_convert_price_ratio': '57.44',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA-',
#     'ration': '5.3822',
#     'ration_cd': '380473',
#     'ration_rt': '42.450',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '112.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '24-07-18',
#     'sincrease_rt': '-0.38%',
#     'sprice': '42.24',
#     'sqflg': 'Y',
#     'stock_cd': '300473',
#     'stock_id': 'sz300473',
#     'stock_net_value': '0.00',
#     'stock_nm': '德尔股份',
#     'svolume': '3206.28',
#     'total_shares': '107531809.0',
#     'volume': '870.58',
#     'year_left': '4.603',
#     'ytm_rt': '-0.86%',
#     'ytm_rt_tax': '-1.51%'},
#    'id': '123011'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '070070',
#     'bond_id': '127008',
#     'bond_nm': '特发转债',
#     'convert_amt_ratio': '0.8%',
#     'convert_cd': '127008',
#     'convert_cd_tip': '127008；2019-05-22 开始转股',
#     'convert_dt': '2019-05-22',
#     'convert_price': '5.610',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-05-16',
#     'convert_value': '191.98',
#     'curr_iss_amt': '0.702',
#     'force_redeem': None,
#     'force_redeem_price': '7.29',
#     'full_price': '191.810',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '1.11%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2023-11-16',
#     'next_put_dt': '2021-11-16',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '4.194',
#     'owned': 0,
#     'pb': '3.27',
#     'pre_bond_id': 'sz127008',
#     'premium_rt': '-0.09%',
#     'price': '191.810',
#     'price_tips': '全价：191.810 最后更新：11:30:03',
#     'put_convert_price': '3.93',
#     'put_convert_price_ratio': '36.46',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.6689',
#     'ration_cd': '080070',
#     'ration_rt': '45.920',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 30,
#     'redeem_style': 'N',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '23-11-16',
#     'sincrease_rt': '0.84%',
#     'sprice': '10.77',
#     'sqflg': 'Y',
#     'stock_cd': '000070',
#     'stock_id': 'sz000070',
#     'stock_net_value': '0.00',
#     'stock_nm': '特发信息',
#     'svolume': '10174.82',
#     'total_shares': '813325730.0',
#     'volume': '1205.12',
#     'year_left': '3.932',
#     'ytm_rt': '-13.10%',
#     'ytm_rt_tax': '-13.52%'},
#    'id': '127008'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '733690',
#     'bond_id': '110049',
#     'bond_nm': '海尔转债',
#     'convert_amt_ratio': '0.6%',
#     'convert_cd': '190049',
#     'convert_cd_tip': '190049；2019-06-25 开始转股',
#     'convert_dt': '2019-06-25',
#     'convert_price': '14.200',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-08-08',
#     'convert_value': '121.34',
#     'curr_iss_amt': '6.956',
#     'force_redeem': '最后交易日：2019年12月16日\r\n赎回价：100.20元/张',
#     'force_redeem_price': '17.04',
#     'full_price': '121.330',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.16%',
#     'issuer_rating_cd': 'AAA',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2024-12-17',
#     'next_put_dt': '2022-12-18',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '30.075',
#     'owned': 0,
#     'pb': '2.46',
#     'pre_bond_id': 'sh110049',
#     'premium_rt': '-0.01%',
#     'price': '121.330',
#     'price_tips': '全价：121.330 最后更新：11:30:00',
#     'put_convert_price': '9.94',
#     'put_convert_price_ratio': '57.69',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AAA',
#     'ration': '0.4930',
#     'ration_cd': '704690',
#     'ration_rt': '60.100',
#     'real_force_redeem_price': '100.200',
#     'redeem_count_days': 15,
#     'redeem_dt': '2019-12-16',
#     'redeem_flag': 'Y',
#     'redeem_icon': 'R',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '105.000',
#     'redeem_price_ratio': '120.000',
#     'redeem_real_days': 23,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.78',
#     'repo_valid': '有效期：2019-12-12 到 2019-12-12',
#     'repo_valid_from': '2019-12-12',
#     'repo_valid_to': '2019-12-12',
#     'short_maturity_dt': '24-12-17',
#     'sincrease_rt': '-0.35%',
#     'sprice': '17.23',
#     'sqflg': 'Y',
#     'stock_cd': '600690',
#     'stock_id': 'sh600690',
#     'stock_net_value': '0.00',
#     'stock_nm': '海尔智家',
#     'svolume': '34432.53',
#     'total_shares': '6414903099.0',
#     'volume': '10099.11',
#     'year_left': '5.019',
#     'ytm_rt': '-1.97%',
#     'ytm_rt_tax': '-2.33%'},
#    'id': '110049'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '754568',
#     'bond_id': '113523',
#     'bond_nm': '伟明转债',
#     'convert_amt_ratio': '1.5%',
#     'convert_cd': '191523',
#     'convert_cd_tip': '191523；2019-06-14 开始转股',
#     'convert_dt': '2019-06-14',
#     'convert_price': '17.470',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-05-17',
#     'convert_value': '126.79',
#     'curr_iss_amt': '3.152',
#     'force_redeem': None,
#     'force_redeem_price': '22.71',
#     'full_price': '126.790',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.25%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2024-12-10',
#     'next_put_dt': '2022-12-10',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '6.700',
#     'owned': 0,
#     'pb': '5.47',
#     'pre_bond_id': 'sh113523',
#     'premium_rt': '0.00%',
#     'price': '126.790',
#     'price_tips': '全价：126.790 最后更新：11:30:00',
#     'put_convert_price': '12.23',
#     'put_convert_price_ratio': '55.21',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.9740',
#     'ration_cd': '753568',
#     'ration_rt': '83.350',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '110.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '24-12-10',
#     'sincrease_rt': '0.73%',
#     'sprice': '22.15',
#     'sqflg': 'Y',
#     'stock_cd': '603568',
#     'stock_id': 'sh603568',
#     'stock_net_value': '0.00',
#     'stock_nm': '伟明环保',
#     'svolume': '2895.82',
#     'total_shares': '941729436.0',
#     'volume': '191.02',
#     'year_left': '5.000',
#     'ytm_rt': '-1.98%',
#     'ytm_rt_tax': '-2.50%'},
#    'id': '113523'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '733498',
#     'bond_id': '110062',
#     'bond_nm': '烽火转债',
#     'convert_amt_ratio': '10.2%',
#     'convert_cd': '未到转股期',
#     'convert_cd_tip': '未到转股期；2020-06-08 开始转股',
#     'convert_dt': '2020-06-08',
#     'convert_price': '25.990',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': None,
#     'convert_value': '99.85',
#     'curr_iss_amt': '30.880',
#     'force_redeem': None,
#     'force_redeem_price': '33.79',
#     'full_price': '100.000',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '0.00%',
#     'issuer_rating_cd': 'AAA',
#     'last_time': None,
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-12-01',
#     'next_put_dt': '2023-12-01',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '30.880',
#     'owned': 0,
#     'pb': '2.96',
#     'pre_bond_id': 'sh110062',
#     'premium_rt': '0.15%',
#     'price': '100.000',
#     'price_tips': '待上市',
#     'put_convert_price': '18.19',
#     'put_convert_price_ratio': '70.11',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AAA',
#     'ration': None,
#     'ration_cd': '704498',
#     'ration_rt': '33.540',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '106.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
# ...
#     'convert_price_valid_from': '2019-07-15',
#     'convert_value': '46.32',
#     'curr_iss_amt': '6.033',
#     'force_redeem': None,
#     'force_redeem_price': '10.41',
#     'full_price': '95.051',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.09%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2024-03-15',
#     'next_put_dt': '2022-03-15',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '6.037',
#     'owned': 0,
#     'pb': '1.67',
#     'pre_bond_id': 'sz128037',
#     'premium_rt': '105.21%',
#     'price': '95.051',
#     'price_tips': '全价：95.051 最后更新：11:30:03',
#     'put_convert_price': '5.61',
#     'put_convert_price_ratio': '151.13',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.3333',
#     'ration_cd': '082542',
#     'ration_rt': '13.370',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '24-03-15',
#     'sincrease_rt': '1.09%',
#     'sprice': '3.71',
#     'sqflg': 'Y',
#     'stock_cd': '002542',
#     'stock_id': 'sz002542',
#     'stock_net_value': '0.00',
#     'stock_nm': '中化岩土',
#     'svolume': '1847.24',
#     'total_shares': '1805547439.0',
#     'volume': '254.01',
#     'year_left': '4.260',
#     'ytm_rt': '4.19%',
#     'ytm_rt_tax': '3.60%'},
#    'id': '128037'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': '072370',
#     'bond_id': '128062',
#     'bond_nm': '亚药转债',
#     'convert_amt_ratio': '26.4%',
#     'convert_cd': '128062',
#     'convert_cd_tip': '128062；2019-10-09 开始转股',
#     'convert_dt': '2019-10-09',
#     'convert_price': '16.250',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-06-10',
#     'convert_value': '41.91',
#     'curr_iss_amt': '9.648',
#     'force_redeem': None,
#     'force_redeem_price': '21.12',
#     'full_price': '89.960',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.10%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2025-04-02',
#     'next_put_dt': '2023-04-03',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '9.650',
#     'owned': 0,
#     'pb': '1.35',
#     'pre_bond_id': 'sz128062',
#     'premium_rt': '114.65%',
#     'price': '89.960',
#     'price_tips': '全价：89.960 最后更新：11:30:03',
#     'put_convert_price': '11.38',
#     'put_convert_price_ratio': '167.03',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': '082370',
#     'ration_rt': '29.780',
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '115.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '25-04-02',
#     'sincrease_rt': '0.44%',
#     'sprice': '6.81',
#     'sqflg': 'Y',
#     'stock_cd': '002370',
#     'stock_id': 'sz002370',
#     'stock_net_value': '0.00',
#     'stock_nm': '亚太药业',
#     'svolume': '6203.45',
#     'total_shares': '536494456.0',
#     'volume': '485.04',
#     'year_left': '5.310',
#     'ytm_rt': '5.71%',
#     'ytm_rt_tax': '5.00%'},
#    'id': '128062'},
#   {'cell': {'adj_cnt': 1,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': None,
#     'bond_id': '110031',
#     'bond_nm': '航信转债',
#     'convert_amt_ratio': '5.9%',
#     'convert_cd': '190031',
#     'convert_cd_tip': '190031；2015-12-14 开始转股',
#     'convert_dt': '2015-12-14',
#     'convert_price': '41.940',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-06-21',
#     'convert_value': '51.98',
#     'curr_iss_amt': '23.993',
#     'force_redeem': None,
#     'force_redeem_price': '54.52',
#     'full_price': '114.100',
#     'fund_rt': 'buy',
#     'guarantor': '航天科工集团承诺对本公司本次发行可 转换公司债券的到期兑付提供全额、不可撤销的连带责任保证担保',
#     'increase_rt': '0.02%',
#     'issuer_rating_cd': 'AA+',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2021-06-12',
#     'next_put_dt': '2019-06-11',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '24.000',
#     'owned': 0,
#     'pb': '3.51',
#     'pre_bond_id': 'sh110031',
#     'premium_rt': '119.51%',
#     'price': '114.100',
#     'price_tips': '全价：114.100 最后更新：11:30:00',
#     'put_convert_price': '29.36',
#     'put_convert_price_ratio': '134.67',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 30,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AAA',
#     'ration': None,
#     'ration_cd': None,
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 20,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '107.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': '105825',
#     'repo_discount_rt': '0.59',
#     'repo_valid': '有效期：2019-12-12 到 2019-12-12；质押代码：105825',
#     'repo_valid_from': '2019-12-12',
#     'repo_valid_to': '2019-12-12',
#     'short_maturity_dt': '21-06-12',
#     'sincrease_rt': '0.46%',
#     'sprice': '21.80',
#     'sqflg': 'Y',
#     'stock_cd': '600271',
#     'stock_id': 'sh600271',
#     'stock_net_value': '0.00',
#     'stock_nm': '航天信息',
#     'svolume': '11058.09',
#     'total_shares': '1862517511.0',
#     'volume': '28.19',
#     'year_left': '1.501',
#     'ytm_rt': '-3.33%',
#     'ytm_rt_tax': '-4.34%'},
#    'id': '110031'},
#   {'cell': {'adj_cnt': 1,
#     'adj_scnt': '1',
#     'adjust_tip': '',
#     'apply_cd': '072325',
#     'bond_id': '128013',
#     'bond_nm': '洪涛转债',
#     'convert_amt_ratio': '31.4%',
#     'convert_cd': '128013',
#     'convert_cd_tip': '128013；2017-02-06 开始转股',
#     'convert_dt': '2017-02-06',
#     'convert_price': '8.000',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-11-21',
#     'convert_value': '38.25',
#     'curr_iss_amt': '12.000',
#     'force_redeem': None,
#     'force_redeem_price': '10.40',
#     'full_price': '96.949',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.19%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2022-07-29',
#     'next_put_dt': '2020-07-29',
#     'noted': 0,
#     'online_offline_ratio': '10',
#     'orig_iss_amt': '12.000',
#     'owned': 0,
#     'pb': '1.16',
#     'pre_bond_id': 'sz128013',
#     'premium_rt': '153.46%',
#     'price': '96.949',
#     'price_tips': '全价：96.949 最后更新：11:30:03',
#     'put_convert_price': '5.60',
#     'put_convert_price_ratio': '183.01',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': '0.9980',
#     'ration_cd': '082325',
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '22-07-29',
#     'sincrease_rt': '-0.33%',
#     'sprice': '3.06',
#     'sqflg': 'Y',
#     'stock_cd': '002325',
#     'stock_id': 'sz002325',
#     'stock_net_value': '0.00',
#     'stock_nm': '洪涛股份',
#     'svolume': '585.60',
#     'total_shares': '1249439441.0',
#     'volume': '787.14',
#     'year_left': '2.630',
#     'ytm_rt': '5.49%',
#     'ytm_rt_tax': '4.64%'},
#    'id': '128013'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': None,
#     'bond_id': '128010',
#     'bond_nm': '顺昌转债',
#     'convert_amt_ratio': '13.7%',
#     'convert_cd': '128010',
#     'convert_cd_tip': '128010；2016-07-29 开始转股',
#     'convert_dt': '2016-07-29',
#     'convert_price': '9.260',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-04-19',
#     'convert_value': '41.04',
#     'curr_iss_amt': '5.095',
#     'force_redeem': None,
#     'force_redeem_price': '12.04',
#     'full_price': '104.521',
#     'fund_rt': 'buy',
#     'guarantor': '澳洋集团有限公司',
#     'increase_rt': '0.02%',
#     'issuer_rating_cd': 'AA',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2022-01-22',
#     'next_put_dt': '2020-01-22',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '5.100',
#     'owned': 0,
#     'pb': '1.79',
#     'pre_bond_id': 'sz128010',
#     'premium_rt': '154.68%',
#     'price': '104.521',
#     'price_tips': '全价：104.521 最后更新：11:30:03',
#     'put_convert_price': '6.48',
#     'put_convert_price_ratio': '170.58',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'AA',
#     'ration': None,
#     'ration_cd': None,
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '108.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '22-01-22',
#     'sincrease_rt': '-1.04%',
#     'sprice': '3.80',
#     'sqflg': 'Y',
#     'stock_cd': '002245',
#     'stock_id': 'sz002245',
#     'stock_net_value': '0.00',
#     'stock_nm': '澳洋顺昌',
#     'svolume': '2115.40',
#     'total_shares': '981311778.0',
#     'volume': '50.82',
#     'year_left': '2.115',
#     'ytm_rt': '3.04%',
#     'ytm_rt_tax': '2.02%'},
#    'id': '128010'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': None,
#     'bond_id': '128012',
#     'bond_nm': '辉丰转债',
#     'convert_amt_ratio': '19.7%',
#     'convert_cd': '128012',
#     'convert_cd_tip': '128012；2016-10-28 开始转股',
#     'convert_dt': '2016-10-28',
#     'convert_price': '7.710',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2018-07-18',
#     'convert_value': '36.96',
#     'curr_iss_amt': '8.443',
#     'force_redeem': None,
#     'force_redeem_price': '10.02',
#     'full_price': '98.999',
#     'fund_rt': 'buy',
#     'guarantor': '无担保',
#     'increase_rt': '-0.24%',
#     'issuer_rating_cd': 'A+',
#     'last_time': '11:30:03',
#     'left_put_year': '-',
#     'margin_flg': '',
#     'maturity_dt': '2022-04-21',
#     'next_put_dt': '2020-04-21',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '8.450',
#     'owned': 0,
#     'pb': '1.45',
#     'pre_bond_id': 'sz128012',
#     'premium_rt': '167.85%',
#     'price': '98.999',
#     'price_tips': '全价：98.999 最后更新：11:30:03',
#     'put_convert_price': '5.40',
#     'put_convert_price_ratio': '189.37',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'n',
#     'put_notes': None,
#     'put_price': '103.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'N',
#     'qflag2': 'N',
#     'qstatus': '00',
#     'rating_cd': 'A+',
#     'ration': '2.1300',
#     'ration_cd': None,
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 15,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'n',
#     'redeem_price': '103.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': None,
#     'repo_discount_rt': '0.00',
#     'repo_valid': '有效期：-',
#     'repo_valid_from': None,
#     'repo_valid_to': None,
#     'short_maturity_dt': '22-04-21',
#     'sincrease_rt': '-1.38%',
#     'sprice': '2.85',
#     'sqflg': 'Y',
#     'stock_cd': '002496',
#     'stock_id': 'sz002496',
#     'stock_net_value': '0.00',
#     'stock_nm': '辉丰股份',
#     'svolume': '779.21',
#     'total_shares': '1507562232.0',
#     'volume': '301.75',
#     'year_left': '2.359',
#     'ytm_rt': '2.82%',
#     'ytm_rt_tax': '2.34%'},
#    'id': '128012'},
#   {'cell': {'adj_cnt': 0,
#     'adj_scnt': 0,
#     'adjust_tip': '',
#     'apply_cd': None,
#     'bond_id': '132011',
#     'bond_nm': '17浙报EB',
#     'convert_amt_ratio': '21.8%',
#     'convert_cd': '192011',
#     'convert_cd_tip': '192011；2018-08-17 开始转股',
#     'convert_dt': '2018-08-17',
#     'convert_price': '24.180',
#     'convert_price_valid': 'Y',
#     'convert_price_valid_from': '2019-06-10',
#     'convert_value': '34.99',
#     'curr_iss_amt': '24.000',
#     'force_redeem': None,
#     'force_redeem_price': '31.43',
#     'full_price': '96.443',
#     'fund_rt': 'buy',
#     'guarantor': '预备用于交换的浙数文化股票及其孳息是',
#     'increase_rt': '0.13%',
#     'issuer_rating_cd': 'AAA',
#     'last_time': '11:30:00',
#     'left_put_year': '-',
#     'margin_flg': 'R',
#     'maturity_dt': '2022-08-17',
#     'next_put_dt': '2022-05-17',
#     'noted': 0,
#     'online_offline_ratio': None,
#     'orig_iss_amt': '24.000',
#     'owned': 0,
#     'pb': '1.39',
#     'pre_bond_id': 'sh132011',
#     'premium_rt': '175.63%',
#     'price': '96.120',
#     'price_tips': '全价：96.443 最后更新：11:30:00',
#     'put_convert_price': '16.93',
#     'put_convert_price_ratio': '200.07',
#     'put_count_days': 30,
#     'put_dt': None,
#     'put_inc_cpn_fl': 'y',
#     'put_notes': None,
#     'put_price': '100.000',
#     'put_real_days': 0,
#     'put_total_days': 30,
#     'qflag': 'Q',
#     'qflag2': 'Q',
#     'qstatus': '00',
#     'rating_cd': 'AAA',
#     'ration': None,
#     'ration_cd': None,
#     'ration_rt': None,
#     'real_force_redeem_price': None,
#     'redeem_count_days': 10,
#     'redeem_dt': None,
#     'redeem_flag': 'X',
#     'redeem_icon': '',
#     'redeem_inc_cpn_fl': 'y',
#     'redeem_price': '103.000',
#     'redeem_price_ratio': '130.000',
#     'redeem_real_days': 0,
#     'redeem_style': 'Y',
#     'redeem_total_days': 30,
#     'ref_yield_info': '',
#     'repo_cd': '133011',
#     'repo_discount_rt': '0.64',
#     'repo_valid': '有效期：2019-12-12 到 2019-12-12；质押代码：133011',
#     'repo_valid_from': '2019-12-12',
#     'repo_valid_to': '2019-12-12',
#     'short_maturity_dt': '22-08-17',
#     'sincrease_rt': '-0.12%',
#     'sprice': '8.46',
#     'sqflg': 'Y',
#     'stock_cd': '600633',
#     'stock_id': 'sh600633',
#     'stock_net_value': '0.00',
#     'stock_nm': '浙数文化',
#     'svolume': '3247.92',
#     'total_shares': '1301923953.0',
#     'volume': '121.40',
#     'year_left': '2.682',
#     'ytm_rt': '3.63%',
#     'ytm_rt_tax': '3.17%'},
#    'id': '132011'}],
#  'total': 219}

# %%
total=dict_json['total']

df=pd.DataFrame(dict_json['rows'][0])
df
# Out:
#                                            cell      id
# adj_cnt                                       0  123031
# adj_scnt                                      0  123031
# adjust_tip                                       123031
# apply_cd                                 370655  123031
# bond_id                                  123031  123031
# bond_nm                                    晶瑞转债  123031
# convert_amt_ratio                          3.7%  123031
# convert_cd                                未到转股期  123031
# convert_cd_tip            未到转股期；2020-03-05 开始转股  123031
# convert_dt                           2020-03-05  123031
# convert_price                            18.380  123031
# convert_price_valid                           Y  123031
# convert_price_valid_from                   None  123031
# convert_value                            177.91  123031
# curr_iss_amt                              1.850  123031
# force_redeem                               None  123031
# force_redeem_price                        23.89  123031
# full_price                              154.089  123031
# fund_rt                                     buy  123031
# guarantor                                   无担保  123031
# increase_rt                               4.26%  123031
# issuer_rating_cd                             A+  123031
# last_time                              11:30:03  123031
# left_put_year                                 -  123031
# margin_flg                                       123031
# maturity_dt                          2025-08-28  123031
# next_put_dt                          2023-08-28  123031
# noted                                         0  123031
# online_offline_ratio                       None  123031
# orig_iss_amt                              1.850  123031
# ...                                         ...     ...
# redeem_count_days                            15  123031
# redeem_dt                                  None  123031
# redeem_flag                                   X  123031
# redeem_icon                                      123031
# redeem_inc_cpn_fl                             n  123031
# redeem_price                            111.000  123031
# redeem_price_ratio                      130.000  123031
# redeem_real_days                              0  123031
# redeem_style                                  Y  123031
# redeem_total_days                            30  123031
# ref_yield_info                                   123031
# repo_cd                                    None  123031
# repo_discount_rt                           0.00  123031
# repo_valid                                有效期：-  123031
# repo_valid_from                            None  123031
# repo_valid_to                              None  123031
# short_maturity_dt                      25-08-28  123031
# sincrease_rt                              1.21%  123031
# sprice                                    32.70  123031
# sqflg                                         Y  123031
# stock_cd                                 300655  123031
# stock_id                               sz300655  123031
# stock_net_value                            0.00  123031
# stock_nm                                   晶瑞股份  123031
# svolume                                26315.06  123031
# total_shares                        151425987.0  123031
# volume                                 14610.83  123031
# year_left                                 5.715  123031
# ytm_rt                                   -4.90%  123031
# ytm_rt_tax                               -5.36%  123031
#
# [83 rows x 2 columns]

# %%
for i in range(total):
    firstrow=dict_json['rows'][i]
    print(firstrow)
    print("\n")
# Out:
# {'cell': {'stock_cd': '300655', 'ytm_rt': '-4.90%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '晶瑞股份', 'bond_id': '123031', 'put_convert_price': '12.87', 'bond_nm': '晶瑞转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '14610.83', 'ref_yield_info': '', 'sprice': '32.70', 'repo_valid_to': None, 'increase_rt': '4.26%', 'total_shares': '151425987.0', 'sqflg': 'Y', 'convert_value': '177.91', 'apply_cd': '370655', 'price': '154.089', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '8.85', 'next_put_dt': '2023-08-28', 'ration_cd': '380655', 'orig_iss_amt': '1.850', 'curr_iss_amt': '1.850', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz123031', 'year_left': '5.715', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-08-28', 'redeem_flag': 'X', 'full_price': '154.089', 'premium_rt': '-13.39%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：154.089 最后更新：11:30:03', 'redeem_price': '111.000', 'convert_amt_ratio': '3.7%', 'convert_dt': '2020-03-05', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '39.35', 'convert_price_valid_from': None, 'convert_price': '18.380', 'redeem_total_days': 30, 'force_redeem_price': '23.89', 'stock_id': 'sz300655', 'margin_flg': '', 'sincrease_rt': '1.21%', 'convert_cd_tip': '未到转股期；2020-03-05 开始转股', 'svolume': '26315.06', 'redeem_real_days': 0, 'ration_rt': '8.110', 'put_total_days': 30, 'ytm_rt_tax': '-5.36%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'A+', 'redeem_style': 'Y', 'issuer_rating_cd': 'A+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-08-28'}, 'id': '123031'}
#
#
# {'cell': {'stock_cd': '603960', 'ytm_rt': '2.95%', 'last_time': None, 'qstatus': '00', 'stock_nm': '克来机电', 'bond_id': '113552', 'put_convert_price': '19.50', 'bond_nm': '克来转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '0.00', 'ref_yield_info': '', 'sprice': '32.16', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '175760000.0', 'sqflg': 'Y', 'convert_value': '115.43', 'apply_cd': '754960', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '10.36', 'next_put_dt': '2023-12-01', 'ration_cd': '753960', 'orig_iss_amt': '1.800', 'curr_iss_amt': '1.800', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113552', 'year_left': '5.975', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-01', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-13.37%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '112.000', 'convert_amt_ratio': '3.2%', 'convert_dt': '2020-06-08', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '60.64', 'convert_price_valid_from': None, 'convert_price': '27.860', 'redeem_total_days': 30, 'force_redeem_price': '36.22', 'stock_id': 'sh603960', 'margin_flg': '', 'sincrease_rt': '3.54%', 'convert_cd_tip': '未到转股期；2020-06-08 开始转股', 'svolume': '4171.70', 'redeem_real_days': 0, 'ration_rt': '82.250', 'put_total_days': 30, 'ytm_rt_tax': '2.38%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '股份质押的担保', 'rating_cd': 'A+', 'redeem_style': 'Y', 'issuer_rating_cd': 'A+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-01'}, 'id': '113552'}
#
#
# {'cell': {'stock_cd': '002806', 'ytm_rt': '3.46%', 'last_time': None, 'qstatus': '00', 'stock_nm': '华锋股份', 'bond_id': '128082', 'put_convert_price': '9.22', 'bond_nm': '华锋转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '0.00', 'ref_yield_info': '', 'sprice': '14.16', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '176239202.0', 'sqflg': 'Y', 'convert_value': '107.52', 'apply_cd': '072806', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.98', 'next_put_dt': '2023-12-04', 'ration_cd': '082806', 'orig_iss_amt': '3.520', 'curr_iss_amt': '3.520', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128082', 'year_left': '5.981', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-03', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-6.99%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '115.000', 'convert_amt_ratio': '14.1%', 'convert_dt': '2020-06-10', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '65.11', 'convert_price_valid_from': None, 'convert_price': '13.170', 'redeem_total_days': 30, 'force_redeem_price': '17.12', 'stock_id': 'sz002806', 'margin_flg': '', 'sincrease_rt': '10.02%', 'convert_cd_tip': '未到转股期；2020-06-10 开始转股', 'svolume': '3309.46', 'redeem_real_days': 0, 'ration_rt': '5.530', 'put_total_days': 30, 'ytm_rt_tax': '2.80%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '土地、房产、机器设备等资产抵 押和股份质押担保', 'rating_cd': 'A+', 'redeem_style': 'Y', 'issuer_rating_cd': 'A+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-03'}, 'id': '128082'}
#
#
# {'cell': {'stock_cd': '603079', 'ytm_rt': '-0.62%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '圣达生物', 'bond_id': '113539', 'put_convert_price': '20.15', 'bond_nm': '圣达转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '2649.37', 'ref_yield_info': '', 'sprice': '38.80', 'repo_valid_to': None, 'increase_rt': '1.22%', 'total_shares': '112000000.0', 'sqflg': 'Y', 'convert_value': '134.82', 'apply_cd': '754079', 'price': '125.750', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '4.93', 'next_put_dt': '2023-07-03', 'ration_cd': '753079', 'orig_iss_amt': '2.990', 'curr_iss_amt': '2.990', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113539', 'year_left': '5.559', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-07-02', 'redeem_flag': 'X', 'full_price': '125.750', 'premium_rt': '-6.73%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：125.750 最后更新：11:30:00', 'redeem_price': '115.000', 'convert_amt_ratio': '6.9%', 'convert_dt': '2020-01-09', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '51.92', 'convert_price_valid_from': None, 'convert_price': '28.780', 'redeem_total_days': 30, 'force_redeem_price': '37.41', 'stock_id': 'sh603079', 'margin_flg': '', 'sincrease_rt': '-0.77%', 'convert_cd_tip': '未到转股期；2020-01-09 开始转股', 'svolume': '1345.11', 'redeem_real_days': 0, 'ration_rt': '41.500', 'put_total_days': 30, 'ytm_rt_tax': '-1.27%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '连带责任保证担保', 'rating_cd': 'A+', 'redeem_style': 'Y', 'issuer_rating_cd': 'A+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-07-02'}, 'id': '113539'}
#
#
# {'cell': {'stock_cd': '603658', 'ytm_rt': '-4.33%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '安图生物', 'bond_id': '113538', 'put_convert_price': '44.88', 'bond_nm': '安图转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '1307.00', 'ref_yield_info': '', 'sprice': '98.52', 'repo_valid_to': None, 'increase_rt': '-0.68%', 'total_shares': '420000000.0', 'sqflg': 'Y', 'convert_value': '153.67', 'apply_cd': '754658', 'price': '146.540', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '17.83', 'next_put_dt': '2023-06-28', 'ration_cd': '753658', 'orig_iss_amt': '6.830', 'curr_iss_amt': '6.830', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113538', 'year_left': '5.545', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-06-27', 'redeem_flag': 'X', 'full_price': '146.540', 'premium_rt': '-4.64%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：146.540 最后更新：11:30:00', 'redeem_price': '110.000', 'convert_amt_ratio': '1.7%', 'convert_dt': '2020-01-06', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '45.55', 'convert_price_valid_from': None, 'convert_price': '64.110', 'redeem_total_days': 30, 'force_redeem_price': '83.34', 'stock_id': 'sh603658', 'margin_flg': 'R', 'sincrease_rt': '-0.98%', 'convert_cd_tip': '未到转股期；2020-01-06 开始转股', 'svolume': '4144.96', 'redeem_real_days': 0, 'ration_rt': '73.650', 'put_total_days': 30, 'ytm_rt_tax': '-4.78%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-06-27'}, 'id': '113538'}
#
#
# {'cell': {'stock_cd': '002376', 'ytm_rt': '2.43%', 'last_time': None, 'qstatus': '00', 'stock_nm': '新北洋', 'bond_id': '128083', 'put_convert_price': '8.33', 'bond_nm': '新北转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '0.00', 'ref_yield_info': '', 'sprice': '12.24', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '665712402.0', 'sqflg': 'Y', 'convert_value': '102.86', 'apply_cd': '072376', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.48', 'next_put_dt': '2023-12-12', 'ration_cd': '082376', 'orig_iss_amt': '8.770', 'curr_iss_amt': '8.770', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128083', 'year_left': '6.003', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-12', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-2.78%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '110.000', 'convert_amt_ratio': '10.8%', 'convert_dt': '2020-06-18', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '68.06', 'convert_price_valid_from': None, 'convert_price': '11.900', 'redeem_total_days': 30, 'force_redeem_price': '15.47', 'stock_id': 'sz002376', 'margin_flg': 'R', 'sincrease_rt': '-1.21%', 'convert_cd_tip': '未到转股期；2020-06-18 开始转股', 'svolume': '3806.80', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '1.96%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-12'}, 'id': '128083'}
#
#
# {'cell': {'stock_cd': '002273', 'ytm_rt': '-5.43%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '水晶光电', 'bond_id': '128020', 'put_convert_price': '8.56', 'bond_nm': '水晶转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '15022.45', 'ref_yield_info': '', 'sprice': '17.07', 'repo_valid_to': None, 'increase_rt': '1.85%', 'total_shares': '1126829050.0', 'sqflg': 'Y', 'convert_value': '139.57', 'apply_cd': '072273', 'price': '138.000', 'repo_valid': '有效期：-', 'ration': '1.7800', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '4.59', 'next_put_dt': '2021-11-17', 'ration_cd': '082273', 'orig_iss_amt': '11.800', 'curr_iss_amt': '9.515', 'online_offline_ratio': None, 'convert_cd': '128020', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 1, 'pre_bond_id': 'sz128020', 'year_left': '3.932', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2023-11-16', 'redeem_flag': 'X', 'full_price': '138.000', 'premium_rt': '-1.12%', 'adj_scnt': '1', 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：138.000 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '4.9%', 'convert_dt': '2018-05-23', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '50.15', 'convert_price_valid_from': '2019-07-24', 'convert_price': '12.230', 'redeem_total_days': 30, 'force_redeem_price': '15.90', 'stock_id': 'sz002273', 'margin_flg': 'R', 'sincrease_rt': '2.40%', 'convert_cd_tip': '128020；2018-05-23 开始转股', 'svolume': '119747.62', 'redeem_real_days': 4, 'ration_rt': '74.715', 'put_total_days': 30, 'ytm_rt_tax': '-5.91%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '23-11-16'}, 'id': '128020'}
#
#
# {'cell': {'stock_cd': '002907', 'ytm_rt': '2.02%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '华森制药', 'bond_id': '128069', 'put_convert_price': '12.66', 'bond_nm': '华森转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '1296.50', 'ref_yield_info': '', 'sprice': '19.76', 'repo_valid_to': None, 'increase_rt': '-0.02%', 'total_shares': '401546200.0', 'sqflg': 'Y', 'convert_value': '109.29', 'apply_cd': '072907', 'price': '108.080', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '7.66', 'next_put_dt': '2023-06-26', 'ration_cd': '082907', 'orig_iss_amt': '3.000', 'curr_iss_amt': '3.000', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128069', 'year_left': '5.537', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-06-24', 'redeem_flag': 'X', 'full_price': '108.080', 'premium_rt': '-1.11%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：108.080 最后更新：11:30:03', 'redeem_price': '115.000', 'convert_amt_ratio': '3.8%', 'convert_dt': '2019-12-30', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '64.05', 'convert_price_valid_from': '2019-07-15', 'convert_price': '18.080', 'redeem_total_days': 15, 'force_redeem_price': '23.50', 'stock_id': 'sz002907', 'margin_flg': '', 'sincrease_rt': '-2.52%', 'convert_cd_tip': '未到转股期；2019-12-30 开始转股', 'svolume': '13152.85', 'redeem_real_days': 0, 'ration_rt': '61.340', 'put_total_days': 30, 'ytm_rt_tax': '1.37%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 30, 'guarantor': '股份质押担保', 'rating_cd': 'AA-', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA-', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-06-24'}, 'id': '128069'}
#
#
# {'cell': {'stock_cd': '002402', 'ytm_rt': '-3.60%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '和而泰', 'bond_id': '128068', 'put_convert_price': '6.36', 'bond_nm': '和而转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '10232.92', 'ref_yield_info': '', 'sprice': '12.68', 'repo_valid_to': None, 'increase_rt': '3.74%', 'total_shares': '855435396.0', 'sqflg': 'Y', 'convert_value': '139.49', 'apply_cd': '072402', 'price': '137.990', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '5.79', 'next_put_dt': '2023-06-05', 'ration_cd': '082402', 'orig_iss_amt': '5.470', 'curr_iss_amt': '5.177', 'online_offline_ratio': None, 'convert_cd': '128068', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128068', 'year_left': '5.482', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-06-04', 'redeem_flag': 'X', 'full_price': '137.990', 'premium_rt': '-1.08%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：137.990 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '4.8%', 'convert_dt': '2019-12-11', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '50.18', 'convert_price_valid_from': None, 'convert_price': '9.090', 'redeem_total_days': 30, 'force_redeem_price': '11.82', 'stock_id': 'sz002402', 'margin_flg': 'R', 'sincrease_rt': '3.76%', 'convert_cd_tip': '128068；2019-12-11 开始转股', 'svolume': '37657.73', 'redeem_real_days': 1, 'ration_rt': '37.700', 'put_total_days': 30, 'ytm_rt_tax': '-4.01%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA-', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA-', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-06-04'}, 'id': '128068'}
#
#
# {'cell': {'stock_cd': '002002', 'ytm_rt': '3.84%', 'last_time': None, 'qstatus': '00', 'stock_nm': '鸿达兴业', 'bond_id': '128085', 'put_convert_price': '2.79', 'bond_nm': '鸿达转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': None, 'volume': '0.00', 'ref_yield_info': '', 'sprice': '4.02', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '2588713789.0', 'sqflg': 'Y', 'convert_value': '101.01', 'apply_cd': '072002', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.59', 'next_put_dt': '2023-12-18', 'ration_cd': '082002', 'orig_iss_amt': '24.270', 'curr_iss_amt': '24.270', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128085', 'year_left': '6.003', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-16', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-1.00%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '118.000', 'convert_amt_ratio': '23.3%', 'convert_dt': '2020-06-22', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '69.30', 'convert_price_valid_from': None, 'convert_price': '3.980', 'redeem_total_days': 30, 'force_redeem_price': '5.17', 'stock_id': 'sz002002', 'margin_flg': 'R', 'sincrease_rt': '0.50%', 'convert_cd_tip': '未到转股期；2020-06-22 开始转股', 'svolume': '6574.35', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '3.11%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-16'}, 'id': '128085'}
#
#
# {'cell': {'stock_cd': '601615', 'ytm_rt': '2.14%', 'last_time': None, 'qstatus': '00', 'stock_nm': '明阳智能', 'bond_id': '113029', 'put_convert_price': '8.86', 'bond_nm': '明阳转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': None, 'volume': '0.00', 'ref_yield_info': '', 'sprice': '12.71', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '1379722378.0', 'sqflg': 'Y', 'convert_value': '100.39', 'apply_cd': '783615', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.86', 'next_put_dt': '2023-12-18', 'ration_cd': '764615', 'orig_iss_amt': '17.000', 'curr_iss_amt': '17.000', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113029', 'year_left': '6.003', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-16', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-0.39%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '108.000', 'convert_amt_ratio': '9.7%', 'convert_dt': '2020-06-22', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '69.72', 'convert_price_valid_from': None, 'convert_price': '12.660', 'redeem_total_days': 30, 'force_redeem_price': '16.46', 'stock_id': 'sh601615', 'margin_flg': 'R', 'sincrease_rt': '0.08%', 'convert_cd_tip': '未到转股期；2020-06-22 开始转股', 'svolume': '10197.51', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '1.73%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-16'}, 'id': '113029'}
#
#
# {'cell': {'stock_cd': '002745', 'ytm_rt': '2.74%', 'last_time': None, 'qstatus': '00', 'stock_nm': '木林森', 'bond_id': '128084', 'put_convert_price': '9.06', 'bond_nm': '木森转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': None, 'volume': '0.00', 'ref_yield_info': '', 'sprice': '13.00', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '1277168540.0', 'sqflg': 'Y', 'convert_value': '100.39', 'apply_cd': '072745', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.66', 'next_put_dt': '2023-12-18', 'ration_cd': '082745', 'orig_iss_amt': '26.600', 'curr_iss_amt': '26.600', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128084', 'year_left': '6.003', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-16', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '-0.39%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '112.000', 'convert_amt_ratio': '16.0%', 'convert_dt': '2020-06-22', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '69.73', 'convert_price_valid_from': None, 'convert_price': '12.950', 'redeem_total_days': 30, 'force_redeem_price': '16.84', 'stock_id': 'sz002745', 'margin_flg': 'R', 'sincrease_rt': '0.54%', 'convert_cd_tip': '未到转股期；2020-06-22 开始转股', 'svolume': '14152.42', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '2.22%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-16'}, 'id': '128084'}
#
#
# {'cell': {'stock_cd': '002446', 'ytm_rt': '-5.72%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '盛路通信', 'bond_id': '128041', 'put_convert_price': '4.79', 'bond_nm': '盛路转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '110.30', 'ref_yield_info': '', 'sprice': '10.31', 'repo_valid_to': None, 'increase_rt': '-0.79%', 'total_shares': '895881246.0', 'sqflg': 'Y', 'convert_value': '150.51', 'apply_cd': '072446', 'price': '150.013', 'repo_valid': '有效期：-', 'ration': '1.3121', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.51', 'next_put_dt': '2022-07-17', 'ration_cd': '082446', 'orig_iss_amt': '10.000', 'curr_iss_amt': '0.730', 'online_offline_ratio': None, 'convert_cd': '128041', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128041', 'year_left': '4.597', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-07-16', 'redeem_flag': 'X', 'full_price': '150.013', 'premium_rt': '-0.33%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：150.013 最后更新：11:30:03', 'redeem_price': '110.000', 'convert_amt_ratio': '0.8%', 'convert_dt': '2019-01-23', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '46.51', 'convert_price_valid_from': '2019-07-19', 'convert_price': '6.850', 'redeem_total_days': 30, 'force_redeem_price': '8.90', 'stock_id': 'sz002446', 'margin_flg': 'R', 'sincrease_rt': '-0.67%', 'convert_cd_tip': '128041；2019-01-23 开始转股', 'svolume': '23751.57', 'redeem_real_days': 29, 'ration_rt': '13.900', 'put_total_days': 30, 'ytm_rt_tax': '-6.25%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'N', 'issuer_rating_cd': 'AA-', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-07-16'}, 'id': '128041'}
#
#
# {'cell': {'stock_cd': '300088', 'ytm_rt': '-5.34%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '长信科技', 'bond_id': '123022', 'put_convert_price': '4.38', 'bond_nm': '长信转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '27548.01', 'ref_yield_info': '', 'sprice': '9.60', 'repo_valid_to': None, 'increase_rt': '3.28%', 'total_shares': '2311974278.0', 'sqflg': 'Y', 'convert_value': '153.60', 'apply_cd': '370088', 'price': '153.158', 'repo_valid': '有效期：-', 'ration': '0.5350', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '4.01', 'next_put_dt': '2023-03-18', 'ration_cd': '380088', 'orig_iss_amt': '12.300', 'curr_iss_amt': '6.851', 'online_offline_ratio': None, 'convert_cd': '123022', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz123022', 'year_left': '5.268', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-03-18', 'redeem_flag': 'X', 'full_price': '153.158', 'premium_rt': '-0.29%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：153.158 最后更新：11:30:03', 'redeem_price': '110.000', 'convert_amt_ratio': '3.1%', 'convert_dt': '2019-09-23', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '45.57', 'convert_price_valid_from': '2019-05-27', 'convert_price': '6.250', 'redeem_total_days': 30, 'force_redeem_price': '8.12', 'stock_id': 'sz300088', 'margin_flg': 'R', 'sincrease_rt': '2.89%', 'convert_cd_tip': '123022；2019-09-23 开始转股', 'svolume': '112370.68', 'redeem_real_days': 5, 'ration_rt': '42.700', 'put_total_days': 30, 'ytm_rt_tax': '-5.82%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-03-18'}, 'id': '123022'}
#
#
# {'cell': {'stock_cd': '300433', 'ytm_rt': '-5.08%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '蓝思科技', 'bond_id': '123003', 'put_convert_price': '7.31', 'bond_nm': '蓝思转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '6440.46', 'ref_yield_info': '', 'sprice': '14.11', 'repo_valid_to': None, 'increase_rt': '0.73%', 'total_shares': '4154740469.0', 'sqflg': 'Y', 'convert_value': '135.15', 'apply_cd': '370433', 'price': '134.778', 'repo_valid': '有效期：-', 'ration': '1.8335', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '3.25', 'next_put_dt': '2021-12-08', 'ration_cd': '380433', 'orig_iss_amt': '48.000', 'curr_iss_amt': '20.079', 'online_offline_ratio': None, 'convert_cd': '123003', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 3, 'pre_bond_id': 'sz123003', 'year_left': '3.992', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2023-12-08', 'redeem_flag': 'X', 'full_price': '134.778', 'premium_rt': '-0.28%', 'adj_scnt': '2', 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：134.778 最后更新：11:30:03', 'redeem_price': '106.000', 'convert_amt_ratio': '3.4%', 'convert_dt': '2018-06-14', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '51.79', 'convert_price_valid_from': '2019-07-11', 'convert_price': '10.440', 'redeem_total_days': 30, 'force_redeem_price': '13.57', 'stock_id': 'sz300433', 'margin_flg': 'R', 'sincrease_rt': '1.51%', 'convert_cd_tip': '123003；2018-06-14 开始转股', 'svolume': '45199.82', 'redeem_real_days': 17, 'ration_rt': '13.540', 'put_total_days': 30, 'ytm_rt_tax': '-5.50%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 20, 'guarantor': '无担保', 'rating_cd': 'AA+', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '23-12-08'}, 'id': '123003'}
#
#
# {'cell': {'stock_cd': '002783', 'ytm_rt': '-8.45%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '凯龙股份', 'bond_id': '128052', 'put_convert_price': '4.74', 'bond_nm': '凯龙转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '2992.79', 'ref_yield_info': '', 'sprice': '12.10', 'repo_valid_to': None, 'increase_rt': '-0.61%', 'total_shares': '370265415.0', 'sqflg': 'Y', 'convert_value': '178.73', 'apply_cd': '072783', 'price': '178.490', 'repo_valid': '有效期：-', 'ration': '0.9849', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.61', 'next_put_dt': '2022-12-21', 'ration_cd': '082783', 'orig_iss_amt': '3.289', 'curr_iss_amt': '0.718', 'online_offline_ratio': None, 'convert_cd': '128052', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128052', 'year_left': '5.030', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-12-21', 'redeem_flag': 'X', 'full_price': '178.490', 'premium_rt': '-0.13%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：178.490 最后更新：11:30:03', 'redeem_price': '110.000', 'convert_amt_ratio': '1.6%', 'convert_dt': '2019-06-27', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '39.17', 'convert_price_valid_from': '2019-06-12', 'convert_price': '6.770', 'redeem_total_days': 30, 'force_redeem_price': '8.80', 'stock_id': 'sz002783', 'margin_flg': 'R', 'sincrease_rt': '-0.49%', 'convert_cd_tip': '128052；2019-06-27 开始转股', 'svolume': '9508.26', 'redeem_real_days': 30, 'ration_rt': '19.050', 'put_total_days': 30, 'ytm_rt_tax': '-8.92%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '荆门市城市建设投资有限公司', 'rating_cd': 'AA', 'redeem_style': 'N', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-12-21'}, 'id': '128052'}
#
#
# {'cell': {'stock_cd': '300473', 'ytm_rt': '-0.86%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '德尔股份', 'bond_id': '123011', 'put_convert_price': '24.26', 'bond_nm': '德尔转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '870.58', 'ref_yield_info': '', 'sprice': '42.24', 'repo_valid_to': None, 'increase_rt': '0.18%', 'total_shares': '107531809.0', 'sqflg': 'Y', 'convert_value': '121.87', 'apply_cd': '370473', 'price': '121.765', 'repo_valid': '有效期：-', 'ration': '5.3822', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.25', 'next_put_dt': '2022-07-18', 'ration_cd': '380473', 'orig_iss_amt': '5.647', 'curr_iss_amt': '3.908', 'online_offline_ratio': None, 'convert_cd': '123011', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz123011', 'year_left': '4.603', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-07-18', 'redeem_flag': 'X', 'full_price': '121.765', 'premium_rt': '-0.09%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：121.765 最后更新：11:30:03', 'redeem_price': '112.000', 'convert_amt_ratio': '8.6%', 'convert_dt': '2019-01-24', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '57.44', 'convert_price_valid_from': '2019-06-14', 'convert_price': '34.660', 'redeem_total_days': 30, 'force_redeem_price': '45.06', 'stock_id': 'sz300473', 'margin_flg': '', 'sincrease_rt': '-0.38%', 'convert_cd_tip': '123011；2019-01-24 开始转股', 'svolume': '3206.28', 'redeem_real_days': 0, 'ration_rt': '42.450', 'put_total_days': 30, 'ytm_rt_tax': '-1.51%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA-', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA-', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-07-18'}, 'id': '123011'}
#
#
# {'cell': {'stock_cd': '000070', 'ytm_rt': '-13.10%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '特发信息', 'bond_id': '127008', 'put_convert_price': '3.93', 'bond_nm': '特发转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '1205.12', 'ref_yield_info': '', 'sprice': '10.77', 'repo_valid_to': None, 'increase_rt': '1.11%', 'total_shares': '813325730.0', 'sqflg': 'Y', 'convert_value': '191.98', 'apply_cd': '070070', 'price': '191.810', 'repo_valid': '有效期：-', 'ration': '0.6689', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '3.27', 'next_put_dt': '2021-11-16', 'ration_cd': '080070', 'orig_iss_amt': '4.194', 'curr_iss_amt': '0.702', 'online_offline_ratio': None, 'convert_cd': '127008', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz127008', 'year_left': '3.932', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2023-11-16', 'redeem_flag': 'X', 'full_price': '191.810', 'premium_rt': '-0.09%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：191.810 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '0.8%', 'convert_dt': '2019-05-22', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '36.46', 'convert_price_valid_from': '2019-05-16', 'convert_price': '5.610', 'redeem_total_days': 30, 'force_redeem_price': '7.29', 'stock_id': 'sz000070', 'margin_flg': 'R', 'sincrease_rt': '0.84%', 'convert_cd_tip': '127008；2019-05-22 开始转股', 'svolume': '10174.82', 'redeem_real_days': 30, 'ration_rt': '45.920', 'put_total_days': 30, 'ytm_rt_tax': '-13.52%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'N', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '23-11-16'}, 'id': '127008'}
#
#
# {'cell': {'stock_cd': '600690', 'ytm_rt': '-1.97%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '海尔智家', 'bond_id': '110049', 'put_convert_price': '9.94', 'bond_nm': '海尔转债', 'force_redeem': '最后交易日：2019年12月16日\r\n赎回价：100.20元/张', 'adjust_tip': '', 'repo_discount_rt': '0.78', 'volume': '10099.11', 'ref_yield_info': '', 'sprice': '17.23', 'repo_valid_to': '2019-12-12', 'increase_rt': '-0.16%', 'total_shares': '6414903099.0', 'sqflg': 'Y', 'convert_value': '121.34', 'apply_cd': '733690', 'price': '121.330', 'repo_valid': '有效期：2019-12-12 到 2019-12-12', 'ration': '0.4930', 'real_force_redeem_price': '100.200', 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.46', 'next_put_dt': '2022-12-18', 'ration_cd': '704690', 'orig_iss_amt': '30.075', 'curr_iss_amt': '6.956', 'online_offline_ratio': None, 'convert_cd': '190049', 'repo_valid_from': '2019-12-12', 'qflag2': 'N', 'redeem_icon': 'R', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh110049', 'year_left': '5.019', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-12-17', 'redeem_flag': 'Y', 'full_price': '121.330', 'premium_rt': '-0.01%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：121.330 最后更新：11:30:00', 'redeem_price': '105.000', 'convert_amt_ratio': '0.6%', 'convert_dt': '2019-06-25', 'redeem_dt': '2019-12-16', 'redeem_price_ratio': '120.000', 'left_put_year': '-', 'put_convert_price_ratio': '57.69', 'convert_price_valid_from': '2019-08-08', 'convert_price': '14.200', 'redeem_total_days': 30, 'force_redeem_price': '17.04', 'stock_id': 'sh600690', 'margin_flg': 'R', 'sincrease_rt': '-0.35%', 'convert_cd_tip': '190049；2019-06-25 开始转股', 'svolume': '34432.53', 'redeem_real_days': 23, 'ration_rt': '60.100', 'put_total_days': 30, 'ytm_rt_tax': '-2.33%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AAA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AAA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-12-17'}, 'id': '110049'}
#
#
# {'cell': {'stock_cd': '603568', 'ytm_rt': '-1.98%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '伟明环保', 'bond_id': '113523', 'put_convert_price': '12.23', 'bond_nm': '伟明转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '191.02', 'ref_yield_info': '', 'sprice': '22.15', 'repo_valid_to': None, 'increase_rt': '0.25%', 'total_shares': '941729436.0', 'sqflg': 'Y', 'convert_value': '126.79', 'apply_cd': '754568', 'price': '126.790', 'repo_valid': '有效期：-', 'ration': '0.9740', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '5.47', 'next_put_dt': '2022-12-10', 'ration_cd': '753568', 'orig_iss_amt': '6.700', 'curr_iss_amt': '3.152', 'online_offline_ratio': None, 'convert_cd': '191523', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113523', 'year_left': '5.000', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-12-10', 'redeem_flag': 'X', 'full_price': '126.790', 'premium_rt': '0.00%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：126.790 最后更新：11:30:00', 'redeem_price': '110.000', 'convert_amt_ratio': '1.5%', 'convert_dt': '2019-06-14', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '55.21', 'convert_price_valid_from': '2019-05-17', 'convert_price': '17.470', 'redeem_total_days': 30, 'force_redeem_price': '22.71', 'stock_id': 'sh603568', 'margin_flg': 'R', 'sincrease_rt': '0.73%', 'convert_cd_tip': '191523；2019-06-14 开始转股', 'svolume': '2895.82', 'redeem_real_days': 0, 'ration_rt': '83.350', 'put_total_days': 30, 'ytm_rt_tax': '-2.50%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-12-10'}, 'id': '113523'}
#
#
# {'cell': {'stock_cd': '600498', 'ytm_rt': '1.79%', 'last_time': None, 'qstatus': '00', 'stock_nm': '烽火通信', 'bond_id': '110062', 'put_convert_price': '18.19', 'bond_nm': '烽火转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '0.00', 'ref_yield_info': '', 'sprice': '25.95', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '1170984634.0', 'sqflg': 'Y', 'convert_value': '99.85', 'apply_cd': '733498', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.96', 'next_put_dt': '2023-12-01', 'ration_cd': '704498', 'orig_iss_amt': '30.880', 'curr_iss_amt': '30.880', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh110062', 'year_left': '5.975', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-01', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '0.15%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '106.000', 'convert_amt_ratio': '10.2%', 'convert_dt': '2020-06-08', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '70.11', 'convert_price_valid_from': None, 'convert_price': '25.990', 'redeem_total_days': 30, 'force_redeem_price': '33.79', 'stock_id': 'sh600498', 'margin_flg': 'R', 'sincrease_rt': '-0.15%', 'convert_cd_tip': '未到转股期；2020-06-08 开始转股', 'svolume': '11045.61', 'redeem_real_days': 0, 'ration_rt': '33.540', 'put_total_days': 30, 'ytm_rt_tax': '1.44%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AAA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AAA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-01'}, 'id': '110062'}
#
#
# {'cell': {'stock_cd': '002822', 'ytm_rt': '-4.79%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '中装建设', 'bond_id': '128060', 'put_convert_price': '4.33', 'bond_nm': '中装转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '345.80', 'ref_yield_info': '', 'sprice': '9.02', 'repo_valid_to': None, 'increase_rt': '0.08%', 'total_shares': '676362806.0', 'sqflg': 'Y', 'convert_value': '145.72', 'apply_cd': '072822', 'price': '146.210', 'repo_valid': '有效期：-', 'ration': '0.8750', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.48', 'next_put_dt': '2023-03-27', 'ration_cd': '082822', 'orig_iss_amt': '5.250', 'curr_iss_amt': '0.770', 'online_offline_ratio': None, 'convert_cd': '128060', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128060', 'year_left': '5.290', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-03-26', 'redeem_flag': 'X', 'full_price': '146.210', 'premium_rt': '0.34%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：146.210 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '1.3%', 'convert_dt': '2019-10-08', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '48.04', 'convert_price_valid_from': '2019-09-20', 'convert_price': '6.190', 'redeem_total_days': 30, 'force_redeem_price': '8.05', 'stock_id': 'sz002822', 'margin_flg': '', 'sincrease_rt': '0.33%', 'convert_cd_tip': '128060；2019-10-08 开始转股', 'svolume': '8147.04', 'redeem_real_days': 30, 'ration_rt': '32.910', 'put_total_days': 30, 'ytm_rt_tax': '-5.21%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'N', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-03-26'}, 'id': '128060'}
#
#
# {'cell': {'stock_cd': '603733', 'ytm_rt': '2.89%', 'last_time': None, 'qstatus': '00', 'stock_nm': '仙鹤股份', 'bond_id': '113554', 'put_convert_price': '9.57', 'bond_nm': '仙鹤转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': None, 'volume': '0.00', 'ref_yield_info': '', 'sprice': '13.62', 'repo_valid_to': None, 'increase_rt': '0.00%', 'total_shares': '612000000.0', 'sqflg': 'Y', 'convert_value': '99.63', 'apply_cd': '754733', 'price': '100.000', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '2.42', 'next_put_dt': '2023-12-15', 'ration_cd': '753733', 'orig_iss_amt': '12.500', 'curr_iss_amt': '12.500', 'online_offline_ratio': None, 'convert_cd': '未到转股期', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh113554', 'year_left': '6.000', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-12-15', 'redeem_flag': 'X', 'full_price': '100.000', 'premium_rt': '0.37%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '待上市', 'redeem_price': '113.000', 'convert_amt_ratio': '15.0%', 'convert_dt': '2020-06-22', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '70.26', 'convert_price_valid_from': None, 'convert_price': '13.670', 'redeem_total_days': 30, 'force_redeem_price': '17.77', 'stock_id': 'sh603733', 'margin_flg': '', 'sincrease_rt': '0.07%', 'convert_cd_tip': '未到转股期；2020-06-22 开始转股', 'svolume': '691.36', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '2.34%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-12-15'}, 'id': '113554'}
#
#
# {'cell': {'stock_cd': '300497', 'ytm_rt': '0.07%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '富祥股份', 'bond_id': '123020', 'put_convert_price': '10.45', 'bond_nm': '富祥转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '124.19', 'ref_yield_info': '', 'sprice': '17.95', 'repo_valid_to': None, 'increase_rt': '0.32%', 'total_shares': '271343449.0', 'sqflg': 'Y', 'convert_value': '120.23', 'apply_cd': '370497', 'price': '120.684', 'repo_valid': '有效期：-', 'ration': '1.8709', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '3.55', 'next_put_dt': '2023-03-01', 'ration_cd': '380497', 'orig_iss_amt': '4.200', 'curr_iss_amt': '3.760', 'online_offline_ratio': None, 'convert_cd': '123020', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz123020', 'year_left': '5.222', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-03-01', 'redeem_flag': 'X', 'full_price': '120.684', 'premium_rt': '0.38%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：120.684 最后更新：11:30:03', 'redeem_price': '115.000', 'convert_amt_ratio': '7.7%', 'convert_dt': '2019-09-09', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '58.22', 'convert_price_valid_from': '2019-06-13', 'convert_price': '14.930', 'redeem_total_days': 30, 'force_redeem_price': '19.41', 'stock_id': 'sz300497', 'margin_flg': '', 'sincrease_rt': '0.79%', 'convert_cd_tip': '123020；2019-09-09 开始转股', 'svolume': '3170.05', 'redeem_real_days': 0, 'ration_rt': '36.570', 'put_total_days': 30, 'ytm_rt_tax': '-0.62%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA-', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA-', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-03-01'}, 'id': '123020'}
#
#
# ...
#
#
# {'cell': {'stock_cd': '002542', 'ytm_rt': '4.19%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '中化岩土', 'bond_id': '128037', 'put_convert_price': '5.61', 'bond_nm': '岩土转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '254.01', 'ref_yield_info': '', 'sprice': '3.71', 'repo_valid_to': None, 'increase_rt': '-0.09%', 'total_shares': '1805547439.0', 'sqflg': 'Y', 'convert_value': '46.32', 'apply_cd': '072542', 'price': '95.051', 'repo_valid': '有效期：-', 'ration': '0.3333', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.67', 'next_put_dt': '2022-03-15', 'ration_cd': '082542', 'orig_iss_amt': '6.037', 'curr_iss_amt': '6.033', 'online_offline_ratio': None, 'convert_cd': '128037', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128037', 'year_left': '4.260', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2024-03-15', 'redeem_flag': 'X', 'full_price': '95.051', 'premium_rt': '105.21%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：95.051 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '9.0%', 'convert_dt': '2018-09-21', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '151.13', 'convert_price_valid_from': '2019-07-15', 'convert_price': '8.010', 'redeem_total_days': 30, 'force_redeem_price': '10.41', 'stock_id': 'sz002542', 'margin_flg': '', 'sincrease_rt': '1.09%', 'convert_cd_tip': '128037；2018-09-21 开始转股', 'svolume': '1847.24', 'redeem_real_days': 0, 'ration_rt': '13.370', 'put_total_days': 30, 'ytm_rt_tax': '3.60%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '24-03-15'}, 'id': '128037'}
#
#
# {'cell': {'stock_cd': '002370', 'ytm_rt': '5.71%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '亚太药业', 'bond_id': '128062', 'put_convert_price': '11.38', 'bond_nm': '亚药转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '485.04', 'ref_yield_info': '', 'sprice': '6.81', 'repo_valid_to': None, 'increase_rt': '-0.10%', 'total_shares': '536494456.0', 'sqflg': 'Y', 'convert_value': '41.91', 'apply_cd': '072370', 'price': '89.960', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.35', 'next_put_dt': '2023-04-03', 'ration_cd': '082370', 'orig_iss_amt': '9.650', 'curr_iss_amt': '9.648', 'online_offline_ratio': None, 'convert_cd': '128062', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128062', 'year_left': '5.310', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2025-04-02', 'redeem_flag': 'X', 'full_price': '89.960', 'premium_rt': '114.65%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：89.960 最后更新：11:30:03', 'redeem_price': '115.000', 'convert_amt_ratio': '26.4%', 'convert_dt': '2019-10-09', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '167.03', 'convert_price_valid_from': '2019-06-10', 'convert_price': '16.250', 'redeem_total_days': 30, 'force_redeem_price': '21.12', 'stock_id': 'sz002370', 'margin_flg': 'R', 'sincrease_rt': '0.44%', 'convert_cd_tip': '128062；2019-10-09 开始转股', 'svolume': '6203.45', 'redeem_real_days': 0, 'ration_rt': '29.780', 'put_total_days': 30, 'ytm_rt_tax': '5.00%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '25-04-02'}, 'id': '128062'}
#
#
# {'cell': {'stock_cd': '600271', 'ytm_rt': '-3.33%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '航天信息', 'bond_id': '110031', 'put_convert_price': '29.36', 'bond_nm': '航信转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.59', 'volume': '28.19', 'ref_yield_info': '', 'sprice': '21.80', 'repo_valid_to': '2019-12-12', 'increase_rt': '0.02%', 'total_shares': '1862517511.0', 'sqflg': 'Y', 'convert_value': '51.98', 'apply_cd': None, 'price': '114.100', 'repo_valid': '有效期：2019-12-12 到 2019-12-12；质押代码：105825', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '3.51', 'next_put_dt': '2019-06-11', 'ration_cd': None, 'orig_iss_amt': '24.000', 'curr_iss_amt': '23.993', 'online_offline_ratio': None, 'convert_cd': '190031', 'repo_valid_from': '2019-12-12', 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 1, 'pre_bond_id': 'sh110031', 'year_left': '1.501', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2021-06-12', 'redeem_flag': 'X', 'full_price': '114.100', 'premium_rt': '119.51%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：114.100 最后更新：11:30:00', 'redeem_price': '107.000', 'convert_amt_ratio': '5.9%', 'convert_dt': '2015-12-14', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '134.67', 'convert_price_valid_from': '2019-06-21', 'convert_price': '41.940', 'redeem_total_days': 30, 'force_redeem_price': '54.52', 'stock_id': 'sh600271', 'margin_flg': 'R', 'sincrease_rt': '0.46%', 'convert_cd_tip': '190031；2015-12-14 开始转股', 'svolume': '11058.09', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '-4.34%', 'repo_cd': '105825', 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 20, 'guarantor': '航天科工集团承诺对本公司本次发行可 转换公司债券的到期兑付提供全额、不可撤销的连带责任保证担保', 'rating_cd': 'AAA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA+', 'put_real_days': 30, 'convert_price_valid': 'Y', 'short_maturity_dt': '21-06-12'}, 'id': '110031'}
#
#
# {'cell': {'stock_cd': '002325', 'ytm_rt': '5.49%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '洪涛股份', 'bond_id': '128013', 'put_convert_price': '5.60', 'bond_nm': '洪涛转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '787.14', 'ref_yield_info': '', 'sprice': '3.06', 'repo_valid_to': None, 'increase_rt': '-0.19%', 'total_shares': '1249439441.0', 'sqflg': 'Y', 'convert_value': '38.25', 'apply_cd': '072325', 'price': '96.949', 'repo_valid': '有效期：-', 'ration': '0.9980', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.16', 'next_put_dt': '2020-07-29', 'ration_cd': '082325', 'orig_iss_amt': '12.000', 'curr_iss_amt': '12.000', 'online_offline_ratio': '10', 'convert_cd': '128013', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 1, 'pre_bond_id': 'sz128013', 'year_left': '2.630', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2022-07-29', 'redeem_flag': 'X', 'full_price': '96.949', 'premium_rt': '153.46%', 'adj_scnt': '1', 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：96.949 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '31.4%', 'convert_dt': '2017-02-06', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '183.01', 'convert_price_valid_from': '2019-11-21', 'convert_price': '8.000', 'redeem_total_days': 30, 'force_redeem_price': '10.40', 'stock_id': 'sz002325', 'margin_flg': 'R', 'sincrease_rt': '-0.33%', 'convert_cd_tip': '128013；2017-02-06 开始转股', 'svolume': '585.60', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '4.64%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '22-07-29'}, 'id': '128013'}
#
#
# {'cell': {'stock_cd': '002245', 'ytm_rt': '3.04%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '澳洋顺昌', 'bond_id': '128010', 'put_convert_price': '6.48', 'bond_nm': '顺昌转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '50.82', 'ref_yield_info': '', 'sprice': '3.80', 'repo_valid_to': None, 'increase_rt': '0.02%', 'total_shares': '981311778.0', 'sqflg': 'Y', 'convert_value': '41.04', 'apply_cd': None, 'price': '104.521', 'repo_valid': '有效期：-', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.79', 'next_put_dt': '2020-01-22', 'ration_cd': None, 'orig_iss_amt': '5.100', 'curr_iss_amt': '5.095', 'online_offline_ratio': None, 'convert_cd': '128010', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128010', 'year_left': '2.115', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2022-01-22', 'redeem_flag': 'X', 'full_price': '104.521', 'premium_rt': '154.68%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：104.521 最后更新：11:30:03', 'redeem_price': '108.000', 'convert_amt_ratio': '13.7%', 'convert_dt': '2016-07-29', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '170.58', 'convert_price_valid_from': '2019-04-19', 'convert_price': '9.260', 'redeem_total_days': 30, 'force_redeem_price': '12.04', 'stock_id': 'sz002245', 'margin_flg': '', 'sincrease_rt': '-1.04%', 'convert_cd_tip': '128010；2016-07-29 开始转股', 'svolume': '2115.40', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '2.02%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '澳洋集团有限公司', 'rating_cd': 'AA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '22-01-22'}, 'id': '128010'}
#
#
# {'cell': {'stock_cd': '002496', 'ytm_rt': '2.82%', 'last_time': '11:30:03', 'qstatus': '00', 'stock_nm': '辉丰股份', 'bond_id': '128012', 'put_convert_price': '5.40', 'bond_nm': '辉丰转债', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.00', 'volume': '301.75', 'ref_yield_info': '', 'sprice': '2.85', 'repo_valid_to': None, 'increase_rt': '-0.24%', 'total_shares': '1507562232.0', 'sqflg': 'Y', 'convert_value': '36.96', 'apply_cd': None, 'price': '98.999', 'repo_valid': '有效期：-', 'ration': '2.1300', 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'n', 'put_notes': None, 'put_inc_cpn_fl': 'n', 'pb': '1.45', 'next_put_dt': '2020-04-21', 'ration_cd': None, 'orig_iss_amt': '8.450', 'curr_iss_amt': '8.443', 'online_offline_ratio': None, 'convert_cd': '128012', 'repo_valid_from': None, 'qflag2': 'N', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sz128012', 'year_left': '2.359', 'qflag': 'N', 'owned': 0, 'maturity_dt': '2022-04-21', 'redeem_flag': 'X', 'full_price': '98.999', 'premium_rt': '167.85%', 'adj_scnt': 0, 'put_price': '103.000', 'fund_rt': 'buy', 'price_tips': '全价：98.999 最后更新：11:30:03', 'redeem_price': '103.000', 'convert_amt_ratio': '19.7%', 'convert_dt': '2016-10-28', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '189.37', 'convert_price_valid_from': '2018-07-18', 'convert_price': '7.710', 'redeem_total_days': 30, 'force_redeem_price': '10.02', 'stock_id': 'sz002496', 'margin_flg': '', 'sincrease_rt': '-1.38%', 'convert_cd_tip': '128012；2016-10-28 开始转股', 'svolume': '779.21', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '2.34%', 'repo_cd': None, 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 15, 'guarantor': '无担保', 'rating_cd': 'A+', 'redeem_style': 'Y', 'issuer_rating_cd': 'A+', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '22-04-21'}, 'id': '128012'}
#
#
# {'cell': {'stock_cd': '600633', 'ytm_rt': '3.63%', 'last_time': '11:30:00', 'qstatus': '00', 'stock_nm': '浙数文化', 'bond_id': '132011', 'put_convert_price': '16.93', 'bond_nm': '17浙报EB', 'force_redeem': None, 'adjust_tip': '', 'repo_discount_rt': '0.64', 'volume': '121.40', 'ref_yield_info': '', 'sprice': '8.46', 'repo_valid_to': '2019-12-12', 'increase_rt': '0.13%', 'total_shares': '1301923953.0', 'sqflg': 'Y', 'convert_value': '34.99', 'apply_cd': None, 'price': '96.120', 'repo_valid': '有效期：2019-12-12 到 2019-12-12；质押代码：133011', 'ration': None, 'real_force_redeem_price': None, 'stock_net_value': '0.00', 'redeem_inc_cpn_fl': 'y', 'put_notes': None, 'put_inc_cpn_fl': 'y', 'pb': '1.39', 'next_put_dt': '2022-05-17', 'ration_cd': None, 'orig_iss_amt': '24.000', 'curr_iss_amt': '24.000', 'online_offline_ratio': None, 'convert_cd': '192011', 'repo_valid_from': '2019-12-12', 'qflag2': 'Q', 'redeem_icon': '', 'put_dt': None, 'adj_cnt': 0, 'pre_bond_id': 'sh132011', 'year_left': '2.682', 'qflag': 'Q', 'owned': 0, 'maturity_dt': '2022-08-17', 'redeem_flag': 'X', 'full_price': '96.443', 'premium_rt': '175.63%', 'adj_scnt': 0, 'put_price': '100.000', 'fund_rt': 'buy', 'price_tips': '全价：96.443 最后更新：11:30:00', 'redeem_price': '103.000', 'convert_amt_ratio': '21.8%', 'convert_dt': '2018-08-17', 'redeem_dt': None, 'redeem_price_ratio': '130.000', 'left_put_year': '-', 'put_convert_price_ratio': '200.07', 'convert_price_valid_from': '2019-06-10', 'convert_price': '24.180', 'redeem_total_days': 30, 'force_redeem_price': '31.43', 'stock_id': 'sh600633', 'margin_flg': 'R', 'sincrease_rt': '-0.12%', 'convert_cd_tip': '192011；2018-08-17 开始转股', 'svolume': '3247.92', 'redeem_real_days': 0, 'ration_rt': None, 'put_total_days': 30, 'ytm_rt_tax': '3.17%', 'repo_cd': '133011', 'noted': 0, 'put_count_days': 30, 'redeem_count_days': 10, 'guarantor': '预备用于交换的浙数文化股票及其孳息是', 'rating_cd': 'AAA', 'redeem_style': 'Y', 'issuer_rating_cd': 'AAA', 'put_real_days': 0, 'convert_price_valid': 'Y', 'short_maturity_dt': '22-08-17'}, 'id': '132011'}
